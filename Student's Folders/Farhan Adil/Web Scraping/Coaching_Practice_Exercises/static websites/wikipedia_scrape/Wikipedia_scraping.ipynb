# %% [markdown]
# ## Practice Question

# %% [markdown]
# # 1. Write a Python program to extract and display all the header tags from en.wikipedia.org/wiki/Main_Page

# %%
import requests # we use requests to fetch the content of the webpage
from bs4 import BeautifulSoup  # we use BeautifulSoup to parse the HTML content
url = "https://en.wikipedia.org/wiki/Main_Page" # URL of the webpage we want to scrape
# we use header to bypass Blocking of IP by website
headers = {
    "User-Agent": "Orthogaffe"
}
response = requests.get(url ,headers=headers) #fetching the content of the webage
soup = BeautifulSoup(response.text , 'html.parser') # parsing the HTML content

# %%
# EXtracting all headings from h1 to h7
headings = soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6' , 'h7']) # finding all heading tags
# printing the extracted headings
for heading in headings: # iterating through each heading
    print(heading.text)
# Out:
# Main Page
# Welcome to Wikipedia
# From today's featured article
# Did you know ...
# In the news
# On this day
# Today's featured picture
# Other areas of Wikipedia
# Wikipedia's sister projects
# Wikipedia languages

# %% [markdown]
# ## 2. Write a Python program to extract and display all the image links from en.wikipedia.org/wiki/Peter_Jeffrey_(RAAF_officer).

# %%
import requests # we use requests to fetch the content of the webpage
from bs4 import BeautifulSoup 
url = "https://en.wikipedia.org/wiki/Peter_Jeffrey_(RAAF_officer)" # url of the webpage we want to scrape
# we use header to bypass Blocking of IP by website
headers = {
    "User-Agent": "Orthogaffe"
}

response = requests.get(url ,headers=headers) #fetching the content of the webage
soup = BeautifulSoup(response.text , 'html.parser') # parsing the HTML content

# Extracting all image URLs from the webpage
images = soup.find_all('img')
for image in images: # iterating through each image tag
    print(image['src']) # printing the src attribute of each image tag
# Out:
# /static/images/icons/wikipedia.png
# /static/images/mobile/copyright/wikipedia-wordmark-en.svg
# /static/images/mobile/copyright/wikipedia-tagline-en.svg
# //upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/a/af/NlaJeffrey1942-43.jpg/250px-NlaJeffrey1942-43.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/c/c5/008315JeffreyTurnbull1941.jpg/330px-008315JeffreyTurnbull1941.jpg
# //upload.wikimedia.org/wikipedia/commons/e/ea/021807CameronJeffrey1941.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/9/92/AC0072JeffreyTruscottKittyhawks1942.jpg/330px-AC0072JeffreyTruscottKittyhawks1942.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/2/26/VIC1689Jeffrey1945.jpg/330px-VIC1689Jeffrey1945.jpg
# //upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/40px-Commons-logo.svg.png
# https://en.wikipedia.org/wiki/Special:CentralAutoLogin/start?useformat=desktop&type=1x1&usesul3=1
# ...

# %% [markdown]
# ## 3. Write a Python program to that retrieves an arbitary Wikipedia page of "Python" and creates a list of links on that page.

# %%
import requests # we use request library
from bs4 import BeautifulSoup # we use beautifulsoup 

url = "https://en.wikipedia.org/wiki/Python_(disambiguation)" # url of a webpage
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"} #we use bot to scrape website

response = requests.get(url, headers=headers) # response store html text of a wbpage
soup = BeautifulSoup(response.text, "html.parser") # we parse the html content

ul_par = soup.find('div', class_="mw-content-ltr mw-parser-output") # we use class to scrape of this where is Ul
Uls = ul_par.find_all( 'ul' ) # we find all ul tag in this class

links = [] # empty list to store links

for tag in Uls: # iterating through each ul tag
    for a in tag.find_all('a', href=True): # finding all anchor tags with href attribute
        full_url = "https://en.wikipedia.org" + a['href'] # constructing full URL
        links.append(full_url) # append full_url to link (list)
        print(full_url) # printing the full URL
# Out:
# https://en.wikipedia.org/wiki/Pythonidae
# https://en.wikipedia.org/wiki/Python_(genus)
# https://en.wikipedia.org/wiki/Python_(mythology)
# https://en.wikipedia.org/wiki/Python_(genus)
# https://en.wikipedia.org/wiki/Python_(programming_language)
# https://en.wikipedia.org/wiki/CMU_Common_Lisp
# https://en.wikipedia.org/wiki/PERQ#PERQ_3
# https://en.wikipedia.org/wiki/Python_(film)
# https://en.wikipedia.org/wiki/Monty_Python
# https://en.wikipedia.org/wiki/Python_(Monty)_Pictures
# https://en.wikipedia.org/wiki/Timon_of_Phlius
# https://en.wikipedia.org/wiki/Python_(Monty)_Pictures
# https://en.wikipedia.org/wiki/Python_of_Aenus
# https://en.wikipedia.org/wiki/Python_(painter)
# https://en.wikipedia.org/wiki/Python_of_Byzantium
# https://en.wikipedia.org/wiki/Python_of_Catana
# https://en.wikipedia.org/wiki/Python_Anghelo
# https://en.wikipedia.org/wiki/Python_(Efteling)
# https://en.wikipedia.org/wiki/Python_(Busch_Gardens_Tampa_Bay)
# ...

# %% [markdown]
# ## 4. Write a Python program to list all language names and number of related articles in the order they appear in wikipedia.org.

# %%
import requests # we use request library
from bs4 import BeautifulSoup # we use beautifulsoup

# Step 1: Target the main Wikipedia homepage
url = "https://www.wikipedia.org/" # url of a webpage
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

response = requests.get(url, headers=headers) # response store html text of a wbpage
soup = BeautifulSoup(response.text, "html.parser") # we parse the html content

# Step 2: Find all language boxes
languages = soup.find_all("a", class_="link-box") # finding all anchor tags with class 'link-box'

# Step 3: Extract and display names and article counts
for lang in languages: # iterating through each language box
    name = lang.find("strong").text.strip() 
    articles = lang.find("small").text.strip() 
    print(f"{name} : {articles}") # print `name` and ` articles`
# Out:
# English : 7,069,000+ articles
# æ¥æ¬èª : 1,475,000+ è¨äº
# Ð ÑÑÑÐºÐ¸Ð¹ : 2Â 065Â 000+ ÑÑÐ°ÑÐµÐ¹
# Deutsch : 3.056.000+ Artikel
# FranÃ§ais : 2â¯712â¯000+ articles
# EspaÃ±ol : 2.065.000+ artÃ­culos
# ä¸­æ : 1,503,000+ æ¡ç® / æ¢ç®
# Italiano : 1.938.000+ voci
# Polski : 1Â 670Â 000+ haseÅ
# PortuguÃªs : 1.156.000+ artigos

# %% [markdown]
# ### a4. Save all images form Wikipedia q2.

# %% [markdown]
# ### 2. Write a Python program to extract and display all the image links from en.wikipedia.org/wiki/Peter_Jeffrey_(RAAF_officer).

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Step 1: Target the main Wikipedia homepage
url = "https://en.wikipedia.org/wiki/Peter_Jeffrey_(RAAF_officer)" # url of a webpage
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

response = requests.get(url, headers=headers) # response store html text of a wbpage
soup = BeautifulSoup(response.text, "html.parser") # we parse the html content

content = soup.find("div" , id = "mw-content-text")

# %%
# Find all image links
images = content.find_all("img")[0:5]

count = 1

for img in images:
    src = img.get("src")

    if not src:
        continue

    # Build full image URL
    img_url = urljoin(url, src)

    # File name
    file_name = f"image_{count}.jpg"

    # Download image
    print("Downloading:", img_url)
    img_data = requests.get(img_url).content
    with open(file_name, "wb") as f:
        f.write(img_data)

    count += 1

print("Done. Total images downloaded:", count - 1)
# Out:
# Downloading: https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/NlaJeffrey1942-43.jpg/250px-NlaJeffrey1942-43.jpg
# Downloading: https://upload.wikimedia.org/wikipedia/commons/thumb/c/c5/008315JeffreyTurnbull1941.jpg/330px-008315JeffreyTurnbull1941.jpg
# Downloading: https://upload.wikimedia.org/wikipedia/commons/e/ea/021807CameronJeffrey1941.jpg
# Downloading: https://upload.wikimedia.org/wikipedia/commons/thumb/9/92/AC0072JeffreyTruscottKittyhawks1942.jpg/330px-AC0072JeffreyTruscottKittyhawks1942.jpg
# Downloading: https://upload.wikimedia.org/wikipedia/commons/thumb/2/26/VIC1689Jeffrey1945.jpg/330px-VIC1689Jeffrey1945.jpg
# Done. Total images downloaded: 5

# %% [markdown]
# ### another Method

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Step 1: Target the main Wikipedia homepage
url = "https://en.wikipedia.org/wiki/Peter_Jeffrey_(RAAF_officer)" # url of a webpage
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

response = requests.get(url, headers=headers) # response store html text of a wbpage
soup = BeautifulSoup(response.text, "html.parser") # we parse the html content

content = soup.find("div" , id = "mw-content-text")

# %%
dl = []
images = content.find_all("img")[0:5]
for img in images:
    img_src = img.get("src") .replace("//" , "")
    img_url = "https://" + img_src 

    data = {}
    data["Image Url"] = img_url
    dl.append(data)
dl
# Out:
# [{'Image Url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/NlaJeffrey1942-43.jpg/250px-NlaJeffrey1942-43.jpg'},
#  {'Image Url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c5/008315JeffreyTurnbull1941.jpg/330px-008315JeffreyTurnbull1941.jpg'},
#  {'Image Url': 'https://upload.wikimedia.org/wikipedia/commons/e/ea/021807CameronJeffrey1941.jpg'},
#  {'Image Url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/92/AC0072JeffreyTruscottKittyhawks1942.jpg/330px-AC0072JeffreyTruscottKittyhawks1942.jpg'},
#  {'Image Url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/26/VIC1689Jeffrey1945.jpg/330px-VIC1689Jeffrey1945.jpg'}]

# %%
img_src
# Out:
# 'upload.wikimedia.org/wikipedia/commons/thumb/2/26/VIC1689Jeffrey1945.jpg/330px-VIC1689Jeffrey1945.jpg'

# %%
df = pd.DataFrame(dl)
df
# Out:
#                                            Image Url
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...

# %%
for i in range (5):
    img_del = df["Image Url"][i]
    img_r = requests.get(img_del)

    file_name = f"image{i + 1}" + ".jpg"
    with open (file_name , "wb") as f:
        f.write(img_r.content)
