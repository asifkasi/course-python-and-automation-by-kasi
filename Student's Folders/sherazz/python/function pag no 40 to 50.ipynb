# %%
# page no 40 (function)
# num1 = 6
# num2 = 7
# total = num1 + num2
# print(total)

# usr input

# num1 = int(input("enter first num : "))
# num2 = int(input("enter second num  : "))
# total = num1 + num2
# print(total)

# num1 = int(input("enter first num : "))
# num2 = int(input("enter second num  : "))
# total = num1 * num2
# print(total)


# num1 = int(input("enter first num : "))
# num2 = int(input("enter second num  : "))
# total = num1 - num2
# print(total)


# num1 = int(input("enter first num : "))
# num2 = int(input("enter second num  : "))
# total = num1 / num2
# print(total)
# Out:
# 1.0

# %%
# define function 
def add_number():
    num1 = int(input("enter first num  : "))
    num2 = int(input("enter 2nd num  : "))
    # first_numbr = 4
    # second_number = 16
    total = num1 * num2 
    print(total)
# for calling function         
add_number()     
# important point :
# 1) function aik blok hota hai jis mai hum koi bhi program likhty hai aur usko kahi bhi call karwa sakty hai 
# 2)build im funtion usko kahty hai jo pahly sa python hamai data hai or usar dafina funtion usko kahty hai
# jo hum khud banaty hai ?
# 4)axampla of build in funtion : 1)print(),2)typa() , 4)id(to find mamory adrss of any variabla),5)len(counting
# of variabla)
# Out:
# 8

# %%
#  1)funtion using in a paramatr

# def function (msg):
#     print(msg)
# function("Hi! my nam is shraz")    

#2) usr input 

# def function (msg,mag2):
#     print(msg,mag2)
# nam =  input("ntr your santance : ")    
# nam1 =  input("ntr your santance : ")    

# function(nam,nam1)
# Out:
# shraz khan

# %%
# 4) usr input STR part 2

def usr_input (fnam ,lastnam):
    print(fnam, lastnam)
fnam = input("entr your fnam : ") 
lnam = input("ntr your lnam  : ") 
usr_input("YOUR FULL NAM IS : " , fnam + " " + lnam)
# Out:
# YOUR FULL NAM IS :  HUMA KHAN

# %%
# 5) usr input int

# def usr_input (fnum ,lastnum):
#     print(fnum, lastnum)
# num1 = int(input("ntr first numbr : "))
# num2 = int(input("ntr 2n numbr  : " ))
# rsult = num1 + num1
# usr_input(" YOUR TOTAL RSULT IS : " , rsult)
        
# 2n mthos

def usr_input (fnum ,lastnum):
    print(fnum, lastnum)
num1 = int(input("ntr first numbr : "))
num2 = int(input("ntr 2n numbr  : " ))
rsult = num1 + num1
usr_input(" YOUR TOTAL RSULT IS : " , rsult)
# Out:
#  YOUR TOTAL RSULT IS :  10

# %%
# qustion n01 

# def function (nam = "shraz"):
#     print(nam)
# function()    
# is cod ka matlab hai ka agr mai koi argumant nhi data tho to paramatr wali valua print hojaaa aagy 

# qustion no 2


# def function (aga = 20):
#     print ("YOUR AGA IS : "+ str(aga))
# function()    

# qustion no 4

def function (msg):
    for i in (msg): 
        print(i)
nam = ["shraz","ali ", "khan" ,"khani"]
function(nam)
# Out:
# shraz
# ali
# khan
# khani

# %%
#  ============if else condition==================
# -===========Qustion no 1=======================
# nam = input("ntr your nam: ")

# if nam == "shraz":
#     print("hi buyr")
# else:
#     print("who ar u")                                


# -===========Qustion no 2=======================

# nam = int(input("ntr your nam: "))
# if nam == 2:
#     print("vn numbr ")
# else:
#     print("od numbr")                                

# -===========Qustion no 4=======================

# nam = int(input("ntr any numbr : "))

# # if nam % 2 == 0 :  ====zro(0) is a rimindar 
#     print("evn numbr")
# else:
#     print("Odd numbr")                                


# -===========Qustion no 5=======================

# num = int(input("ntr any numbr : "))

# if num >= 18 :
#     print("your ar aligibla for vot")
# else:
#     print("your ar aligibla not  for vot")
# Out:
# your ar aligibla not  for vot

# %%
#  ===========Qustion no 6=======================

num = int(input("ntr any numbr  : "))
if num >= 90 : 
    print("You ar aligibla for Grade A")
elif num >= 80  :
    print("You ar aligibla for Grade B")    
elif num >= 70 :
    print("You ar aligibla for Grade c")
elif num >= 60 :
    print("You ar aligibla for Grade d")
elif num >= 50 :
    print("You ar aligibla for Grade e ")
else : 
    print("Your ar fail : " )
# Out:
# You ar aligibla for Grade B

# %%
# =========QUESTION NO 1 ==========PRACTICE QUESTION OF FUNCTIONS

def function(num1,num2):
    print(num1,num2)
number = int(input("Enter first number  :" ))
number1 = int(input("Enter a 2nd user input number : "))
result = number + number1

function("Your answer is : " , result)
# Out:
# Your answer is :  8

# %%
# ==============Question no 3 ===========

def even_odd(num1 , num2 ):
    print(num1,num2)
name = int(input("Enter any number : "))

if name % 2 == 0:
    print("It is even numbers")
else: 
    print("its is  odd number ")    

even_odd("",name)
# Out:
# its is  odd number
#  7

# %%
# ========Question no 05===========

table = int(input("Enter anay number :"))
def function (table):
    for i in range(1,11):
        print(table ,"X", i ," = ",table * i)

function(table)
# Out:
# 12 X 1  =  12
# 12 X 2  =  24
# 12 X 3  =  36
# 12 X 4  =  48
# 12 X 5  =  60
# 12 X 6  =  72
# 12 X 7  =  84
# 12 X 8  =  96
# 12 X 9  =  108
# 12 X 10  =  120

# %%
# ==========Question no 8 ==============
# 8. Write a function that finds the factorial of a number .


user = int(input("Enter any number : "))
def function ():
    for i in range(user, 0,-1):
        print(i)


function()
# Out:
# 0
# 1
# 2

# %%
# 6. Write a function that takes a list of numbers and returns only the even numbers

var = [1,10,3,9.18]

def function (var):
