# %%
fav=5
num = 1
for i in range(num,0,-1):
    num = num * i
    print(num)

# %%
#Q 14
dic1={'a':200,
      'b':200,
      'c':200
      }
dic2={'b':200,
      'd':200,
      'a':200,
      }
dic3= dic2
for key in dic1.keys():
    if key in dic2.keys():
        dic3[key]=dic1[key]+dic2[key]
    else:
        dic3[key]=dic1[key]
print(dic3)

# %%
num = 5
for i in range(1,num * 4 + 1 ,4):
    print(f"{i},{i+1},{i+2},{i+3}1")

# %%
# num=5
sum = 0
sum2 = 0
for i in range(num):
    sum = 10**i + sum
    print(sum,end='+')
    sum2 = sum + sum2
print(sum)
print(sum2)

# %%
#nsd loop sheraz
# for i in range(5):
#     for j in range(i):
#         print(i,end="")
#     print() for line break 



# for i in range(5,0,-1):
#     for j in range(i):
#         print(i,end="")
#     print()

# %%
# col = int(input("Enter col : "))
# row = int(input("Enter row : "))

for i in range(0,3,1):
    for j in range(0,3,1):
        print(f"({i} , {j})", end= " ")
    print()

# %%
for i in range(1,4,1):
    for j in range(1,i+1):
        print(f"({i} , {j})", end= " ")  
    print()

# %%
#sheraz

for i in range(1,4,1):
    for j in range(1,4,1):
        print(i*j , end=" ")
    print()
# Out:
# 1 2 3
# 2 4 6
# 3 6 9

# %%
row = 5
num = 1
for i in range(1,row):
    for j in range(i):
        print(num , end=" ")
        num = num + 2
    print()

# %%
#Question 22
 
print(chr(97))
print(chr(65))
print(chr(66))
print(chr(67))
#Question 23

# %%
row = 5
num = 2
for i in range(1,row):
    for j in range(i):
        print(num , end=" ")
        num = num + 2
    print()

# %%
# nested loop 

# question 23
for i in range(65, 69):        
    for j in range(65, i+1):   
        print(chr(j), end="")
    print()

n = 3
for i in range(n, 0, -1):         
    for j in range(n, n - i, -1): 
        print(chr(64 + j), end="")
    print()
# Out:
# A
# AB
# ABC
# ABCD
# CBA
# CB
# C

# %%
# qustion non 4
n=4
odd_num=1
for i in range(1,n+1):
    for j in range(n-i,0,-1):
        print(" ",end="")
    for k in range(odd_num):
         print("*",end="")
    print()
    odd_num+=2

# %%
n=10
odd_num=1
for i in range(1,n+1):
    for j in range(n-i,0,-1):
        print(" ",end="")
    for k in range(odd_num):
         print("*",end="")
    print()
    odd_num+=2
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************

# %%
n = 4
odd_num = 2*n - 1  

for i in range(n, 0, -1):    
    for j in range(n-i):
        print(" ", end="")
    for k in range(odd_num):
        print("*", end="")
    
    print()  
    odd_num -= 2
# Out:
# *******
#  *****
#   ***
#    *

# %%
#qustion no 5
#  
n = 3  # middle width

# Top half including middle
for i in range(1, n + 1):
    print(" " * (n - i) + "*" * (2 * i - 1))

# Bottom half
for i in range(n - 1, 0, -1):
    print(" " * (n - i) + "*" * (2 * i - 1))
# Out:
#   *
#  ***
# *****
#  ***
#   *

# %%
usr_nam = int(input("ntr nam : "))
for i in range(usr_nam):
    print("opp")
# Out:
# opp
# opp

# %%
# pag no 41 in slide

num1 = 4
num2 = 8
total = num1 + num2
print(total)
# Out:
# 12

# %%
# requests + BeautifulSoup


r = url = "https://lms.kiet.edu.pk/kietlms/my/Student_Portal.php"
r
# Out:
# 'https://lms.kiet.edu.pk/kietlms/my/Student_Portal.php'
