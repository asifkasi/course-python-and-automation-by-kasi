# %%
# =============================NAME : SHERAZ ===================================

# %%
# =========QUESTION NO 1 ==========PRACTICE QUESTION OF FUNCTIONS

# 1. Write a function that takes two numbers as input and returns their sum.


def function():
    # print()
    number = int(input("Enter first number  :" ))
    number1 = int(input("Enter a 2nd user input number : "))
    result = number + number1
    return result

function()
Sum1 = function()
print(Sum1)
# Out:
# 11

# %%
print(Sum1)
# Out:
# 9

# %%
# 2. Write a function that takes a string and returns it in uppercase.

# upper ka matlab hota sare alphabat capital mei aajaee 

def function(var1):  
    return var1.upper()
var = input("Enter a any name : ")
function(var)
# Out:
# 'SHEHZAD'

# %%
# 3. Create a function that checks if a number is even or odd.

# ==============Question no 3 ===========

def even_odd(num1 , num2 ):
    print(num1,num2)
name = int(input("Enter any number : "))

if name % 2 == 0:
    print("It is even numbers")
else: 
    print("its is  odd number ")    

even_odd("",name)
# Out:
# its is  odd number
#  5

# %%
# 4. Write a function that takes a list and returns the maximum value.
