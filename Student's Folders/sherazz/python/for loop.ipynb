# %%
#============for loop===================

name = input("enter name :")
for i in name:
    print(i, end="")

# note : str keliye hum for loop mei koi range nhi lety bss uske simple for loop mei likh lety hai

# %%
# num = int(input("Enter any number  : "))

# for i in range(0,10,1): 
#     print(i,end="  ")
# note : range mei (start,end,increment(its mean 1 number ko bara kar show kry ga))


for i in range(0,10,2): 
    print(i,end="  ")
# note : agar 2 ka inceament karty ha to 2 number ko skip karke chalaee ga
# Out:
# 0  2  4  6  8

# %%
# for i in range(10,0,-1):
#     print(i,end="  ")

#note : agr range ulta chalala hai to increment -1 karty  hai  

for i in range(10,0,-2): 
    print(i,end="  ")
# Out:
# 10  8  6  4  2

# %%
# ===========for loop user input ================

start =int(input("Enter any number : ")) 
end   =int(input("Enter any number : "))
incr  =int(input("Enter any number : "))

for i in range(start, end + 1 ,incr):
    print(i , end="  ")

# note : end + 1 ka matlab hai ke agar end 9 hai to ismei 1 plus hojaeega aur 10 print kar dega
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 # ===========for loop user input ================
# ----> 3 start =int(input("Enter any number : "))
#       4 end   =int(input("Enter any number : "))
#       5 incr  =int(input("Enter any number : "))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.0
# blinker                 1.9.0
# certifi                 2025.10.5
# charset-normalizer      3.4.3
# click                   8.2.1
# colorama                0.4.6
# comm                    0.2.3
# debugpy                 1.8.16
# decorator               5.2.1
# executing               2.2.0
# Flask                   3.1.2
# idna                    3.11
# ipykernel               6.30.1
# ipython                 9.5.0
# ipython_pygments_lexers 1.1.1
# itsdangerous            2.2.0
# jedi                    0.19.2
# Jinja2                  3.1.6
# jupyter_client          8.6.3
# jupyter_core            5.8.1
# MarkupSafe              3.0.2
# matplotlib-inline       0.1.7
# mss                     10.1.0
# nest-asyncio            1.6.0
# packaging               25.0
# parso                   0.8.5
# pillow                  11.3.0
# pip                     24.0
# ...

# %%
pip show requests
# Out:
# Name: requests
# Version: 2.32.5
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: c:\Users\SHERAZ\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: certifi, charset_normalizer, idna, urllib3
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
