# %%
print("""   ____ _ _   _   _             
  / ___(_) |_| | | |_   _ _ __  
 | |  _| | __| |_| | | | | '_ \ 
 | |_| | | |_|  _  | |_| | |_) |
  \____|_|\__|_| |_|\__,_| .__/ 
                         |_|     """)


# definition : website that allow developer to store and manage their code using Git.
#
# Out:
#    ____ _ _   _   _
#   / ___(_) |_| | | |_   _ _ __
#  | |  _| | __| |_| | | | | '_ \
#  | |_| | | |_|  _  | |_| | |_) |
#   \____|_|\__|_| |_|\__,_| .__/
#                          |_|
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\SHERAZ\AppData\Local\Temp\ipykernel_19968\209105534.py:1: SyntaxWarning: invalid escape sequence '\ '
#   print("""   ____ _ _   _   _
