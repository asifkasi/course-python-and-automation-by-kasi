# %% [markdown]
# # 3.1 Extract first Testudines details save into csv file. e.g# Carettochelyidae

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import pandas as pd

driver = webdriver.Chrome()
url = "https://www.scrapethissite.com/pages/frames/"
driver.get(url)




driver.switch_to.frame(0)


driver.find_element(By.XPATH, "//h3").text

soup = BeautifulSoup(driver.page_source , "html")
soup

soup = BeautifulSoup(driver.page_source,"html")
divs = soup.find_all("div",class_="col-md-4 turtle-family-card")
# div = divs[0]
list = []
print(divs[0].prettify())
div = divs[0]
for div in divs[:3]:
    dict = {
        "Name" : "",
        "url" : "",
        "Image_url" : "",
    }

    base_url = "https://www.scrapethissite.com"
    dict["Name"] = div.find("h3").text.strip()
    dict["url"] = base_url + div.find("a")["href"]
    dict["Image_url"] = base_url + div.find("img")["src"]
    list.append(dict)

dict

df = pd.DataFrame(list)
df
df.to_csv("question_no_2.2(frames).csv", index=False)    
df

# %%
driver.switch_to.frame(0)
driver.find_element(By.XPATH, "//div/a").text

# soup = BeautifulSoup(driver.page_source , "html")
# soup
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 driver.switch_to.frame(0)
#       2 driver.find_element(By.XPATH, "//div/a").text
#       4 # soup = BeautifulSoup(driver.page_source , "html")
#       5 # soup
#
# File c:\Users\SHERAZ\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\switch_to.py:83, in SwitchTo.frame(self, frame_reference)
#      80         except NoSuchElementException as exc:
#      81             raise NoSuchFrameException(frame_reference) from exc
# ---> 83 self._driver.execute(Command.SWITCH_TO_FRAME, {"id": frame_reference})
#
# File c:\Users\SHERAZ\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File c:\Users\SHERAZ\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff7776ba235
# 	0x7ff777412630
# 	0x7ff7771a14e5
# 	0x7ff7771ea151
# 	0x7ff777222a12
# 	0x7ff77721d27c
# 	0x7ff77721c46a
# 	0x7ff77716acb5
# 	0x7ff7776e5d60
# 	0x7ff7776dfe8a
# 	0x7ff777701005
# 	0x7ff77742d71e
# 	0x7ff777434e1f
# 	0x7ff77716977b
# 	0x7ff7778345f8
# 	0x7ffd41ebe8d7
# 	0x7ffd42bec53c
