# %% [markdown]
# 	# 2.3 Extract all Testudines family details save into csv file.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import pandas as pd

driver = webdriver.Chrome()
url = "https://www.scrapethissite.com/pages/frames/"
driver.get(url)




driver.switch_to.frame(0)


driver.find_element(By.XPATH, "//h3").text

soup = BeautifulSoup(driver.page_source , "html")
soup

soup = BeautifulSoup(driver.page_source,"html")
divs = soup.find_all("div",class_="col-md-4 turtle-family-card")
# div = divs[0]
list = []
print(divs[0].prettify())
div = divs[0]
for div in divs:
    dict = {
        "Name" : "",
        "url" : "",
        "Image_url" : "",
    }

    base_url = "https://www.scrapethissite.com"
    dict["Name"] = div.find("h3").text.strip()
    dict["url"] = base_url + div.find("a")["href"]
    dict["Image_url"] = base_url + div.find("img")["src"]
    list.append(dict)

dict

df = pd.DataFrame(list)
df
df.to_csv("question_no_2.3(frames).csv", index=False)    
df
# Out:
# <div class="col-md-4 turtle-family-card">
#  <img class="turtle-image" src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b3/Carettochelys_insculpta.jpg/200px-Carettochelys_insculpta.jpg"/>
#  <h3 class="family-name">
#   Carettochelyidae
#  </h3>
#  <a class="btn btn-default btn-xs" href="/pages/frames/?frame=i&amp;family=Carettochelyidae">
#   Learn more →
#  </a>
# </div>
#                 Name                                                url  \
# 0   Carettochelyidae  https://www.scrapethissite.com/pages/frames/?f...
# 1        Cheloniidae  https://www.scrapethissite.com/pages/frames/?f...
# 2        Chelydridae  https://www.scrapethissite.com/pages/frames/?f...
# 3     Dermatemydidae  https://www.scrapethissite.com/pages/frames/?f...
# 4     Dermochelyidae  https://www.scrapethissite.com/pages/frames/?f...
# 5           Emydidae  https://www.scrapethissite.com/pages/frames/?f...
# 6        Geoemydidae  https://www.scrapethissite.com/pages/frames/?f...
# 7      Kinosternidae  https://www.scrapethissite.com/pages/frames/?f...
# 8     Platysternidae  https://www.scrapethissite.com/pages/frames/?f...
# 9       Testudinidae  https://www.scrapethissite.com/pages/frames/?f...
# 10      Trionychidae  https://www.scrapethissite.com/pages/frames/?f...
# 11          Chelidae  https://www.scrapethissite.com/pages/frames/?f...
# 12     Pelomedusidae  https://www.scrapethissite.com/pages/frames/?f...
# 13    Podocnemididae  https://www.scrapethissite.com/pages/frames/?f...
#
#                                             Image_url
# 0   https://www.scrapethissite.comhttps://upload.w...
# 1   https://www.scrapethissite.comhttps://upload.w...
# 2   https://www.scrapethissite.comhttps://upload.w...
# 3   https://www.scrapethissite.comhttps://upload.w...
# 4   https://www.scrapethissite.comhttps://upload.w...
# 5   https://www.scrapethissite.comhttps://upload.w...
# 6   https://www.scrapethissite.comhttps://upload.w...
# 7   https://www.scrapethissite.comhttps://upload.w...
# 8   https://www.scrapethissite.comhttps://upload.w...
# 9   https://www.scrapethissite.comhttps://upload.w...
# 10  https://www.scrapethissite.comhttps://upload.w...
# 11  https://www.scrapethissite.comhttps://upload.w...
# 12  https://www.scrapethissite.comhttps://upload.w...
# 13  https://www.scrapethissite.comhttps://upload.w...
