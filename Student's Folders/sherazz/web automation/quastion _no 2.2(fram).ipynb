# %% [markdown]
# 	# 2.2 Extract Testudines family details save into csv file. e.g# Carettochelyidae, Cheloniidae, Chelydridae

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import pandas as pd

driver = webdriver.Chrome()
url = "https://www.scrapethissite.com/pages/frames/"
driver.get(url)




driver.switch_to.frame(0)


driver.find_element(By.XPATH, "//h3").text

soup = BeautifulSoup(driver.page_source , "html")
soup

soup = BeautifulSoup(driver.page_source,"html")
divs = soup.find_all("div",class_="col-md-4 turtle-family-card")
# div = divs[0]
list = []
print(divs[0].prettify())
div = divs[0]
for div in divs[:3]:
    dict = {
        "Name" : "",
        "url" : "",
        "Image_url" : "",
    }

    base_url = "https://www.scrapethissite.com"
    dict["Name"] = div.find("h3").text.strip()
    dict["url"] = base_url + div.find("a")["href"]
    dict["Image_url"] = base_url + div.find("img")["src"]
    list.append(dict)

dict

df = pd.DataFrame(list)
df
df.to_csv("question_no_2.2(frames).csv", index=False)    
df
# Out:
# <div class="col-md-4 turtle-family-card">
#  <img class="turtle-image" src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b3/Carettochelys_insculpta.jpg/200px-Carettochelys_insculpta.jpg"/>
#  <h3 class="family-name">
#   Carettochelyidae
#  </h3>
#  <a class="btn btn-default btn-xs" href="/pages/frames/?frame=i&amp;family=Carettochelyidae">
#   Learn more →
#  </a>
# </div>
#                Name                                                url  \
# 0  Carettochelyidae  https://www.scrapethissite.com/pages/frames/?f...
# 1       Cheloniidae  https://www.scrapethissite.com/pages/frames/?f...
# 2       Chelydridae  https://www.scrapethissite.com/pages/frames/?f...
#
#                                            Image_url
# 0  https://www.scrapethissite.comhttps://upload.w...
# 1  https://www.scrapethissite.comhttps://upload.w...
# 2  https://www.scrapethissite.comhttps://upload.w...

# %%
# soup = BeautifulSoup(driver.page_source,"html")
# divs = soup.find_all("div",class_="col-md-4 turtle-family-card")
# # div = divs[0]
# list = []
# for div in divs[:3]:
#     dict = {
#         "name":"",
#         "url":"",
#         "img_url":""
#     }
#     base_url = "https://www.scrapethissite.com/"
#     dict["img_url"] = div.find("img")["src"]
#     dict["url"] = div.find("a")["href"]
#     dict["name"] = div.find("h3").text
#     list.append(dict)
# df = pd.DataFrame(list)
# df.to_csv("ifrmaes_ques_2_2.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 soup = BeautifulSoup(driver.page_source,"html")
#       2 divs = soup.find_all("div",class_="col-md-4 turtle-family-card")
#       3 # div = divs[0]
#
# NameError: name 'BeautifulSoup' is not defined

# %%
soup = BeautifulSoup(driver.page_source,"html")
divs = soup.find_all("div",class_="col-md-4 turtle-family-card")
# div = divs[0]
list = []
for div in divs[:3]:
    dict = {
        "name":"",
        "url":"",
        "img_url":""
    }
    base_url = "https://www.scrapethissite.com/"
    dict["img_url"] = div.find("img")["src"]
    dict["url"] = div.find("a")["href"]
    dict["name"] = div.find("h3").text
    list.append(dict)
df = pd.DataFrame(list)
df.to_csv("ifrmaes_ques_2_2.csv",index=False)
