# %%
'''
1. Write a python program that reads an integer between 1 and 12 and prints the month of the year in English.
Test Data :
Input a number between 1 to 12 to get the month name: 8
Expected Output:
August
'''

print("  ")

# %%
# unblock my IP
# method 1 : using robot.txt file
import requests
headers = {
    "User-Agent": "IsraBot"
}
response = requests.get("https://lms.kiet.edu.pk/kietlms/my/Student_Portal.php",headers=headers)

print(response.text)
# Out:
# <!DOCTYPE html>
#
# <html  dir="ltr" lang="en-us" xml:lang="en-us">
# <head>
#     <title>KIET Learning Management System: Log in to the site</title>
#     <link rel="shortcut icon" href="https://lms.kiet.edu.pk/kietlms/theme/image.php/moove/theme/1760517713/favicon" />
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta name="keywords" content="moodle, KIET Learning Management System: Log in to the site" />
# <link rel="stylesheet" type="text/css" href="https://lms.kiet.edu.pk/kietlms/theme/yui_combo.php?rollup/3.17.2/yui-moodlesimple-min.css" /><script id="firstthemesheet" type="text/css">/** Required in order to fix style inclusion problems in IE with YUI **/</script><link rel="stylesheet" type="text/css" href="https://lms.kiet.edu.pk/kietlms/theme/styles.php/moove/1760517713_1/all" />
# <script>
# //<![CDATA[
# var M = {}; M.yui = {};
# M.pageloadstarttime = new Date();
# ...

# %%
# unblock my IP
# method 1 : using robot.txt file
import requests
headers = {
    "User-Agent": "IsraBot"
}
response = requests.get("https://lms.kiet.edu.pk/kietlms/my/Student_reports/Test_Results.php?session_id=23bcae328920dc310197db5ef9491c18501e35b11761910143)",headers=headers)

print(response.text)
# Out:
# <!DOCTYPE html>
#
# <html  dir="ltr" lang="en-us" xml:lang="en-us">
# <head>
#     <title>KIET Learning Management System: Log in to the site</title>
#     <link rel="shortcut icon" href="https://lms.kiet.edu.pk/kietlms/theme/image.php/moove/theme/1760517713/favicon" />
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta name="keywords" content="moodle, KIET Learning Management System: Log in to the site" />
# <link rel="stylesheet" type="text/css" href="https://lms.kiet.edu.pk/kietlms/theme/yui_combo.php?rollup/3.17.2/yui-moodlesimple-min.css" /><script id="firstthemesheet" type="text/css">/** Required in order to fix style inclusion problems in IE with YUI **/</script><link rel="stylesheet" type="text/css" href="https://lms.kiet.edu.pk/kietlms/theme/styles.php/moove/1760517713_1/all" />
# <script>
# //<![CDATA[
# var M = {}; M.yui = {};
# M.pageloadstarttime = new Date();
# ...
