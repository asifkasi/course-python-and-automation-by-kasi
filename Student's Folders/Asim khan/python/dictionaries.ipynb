# %%
student={
    "01":{
        "name":"shariq shah",
        "f.name":"zahid",
        "class":"12",
        "subjects":["math","physics","english","chemistry"]

    },
    "02":{
        "name":"asim shah",
        "f.name":"farooq",
        "class":"12",
        "subjects":["math","urdu","english","science"]
    },
        "03":{
        "name":"asim shah",
        "f.name":"farooq",
        "class":"12",
        "subjects":["sindhi","urdu","english","islamiat"]
    }
}
print(student["01"]["subjects"])
print(len((student)["01"]["subjects"]))
print(student["01"]["subjects"][0])
"03" in student.keys()
if "03" in student.keys():
    print("available")
else:
    print("N.available")
# Out:
# ['math', 'physics', 'english', 'chemistry']
# 4
# math
# available

# %%
var="asifkasi"
if "" in var:
    print("available")
else:
    print("not available")
# Out:
# not available

# %%
var="asif kasi"
var=var + " s/o qasim kasi"
print(var)
# Out:
# asif kasi s/o qasim kasi

# %%
#how to find count of "kasi"
var="asif kasi"
var=var.replace(" ","")
var=var+" s/o qasim kasi"
print(var)
# Out:
#   Cell In[41], line 2
#     var="asif kasi
#         ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
var="asif kasi s/o qasim kasi"
print(var.startswith("asif"))
print(var.endswith("kasi"))
# Out:
# True
# True

# %%
var="asif kasi s/o qasim kasi"
varindex=var.index(" ")
print(var[ :varindex])
print(var[varindex+1:])
newvar=var[ :varindex]+ var[varindex+1: ]
print(newvar)
# newvar=var[ :4] + var[5: ]
# print(newvar)
# Out:
# asif
# kasi s/o qasim kasi
# asifkasi s/o qasim kasi

# %%
var="asif kasi s/o qasim kasi"

newvar=var[ :4] + var[5: ]
print(newvar)
# Out:
# asifkasi s/o qasim kasi

# %%
var="asif kasi s/o qasim kasi"
var=var.replace(" ","_")
print(var)
# Out:
# asif_kasi_s/o_qasim_kasi

# %%
var=" asif kasi "
newvar=var[1:10]
print(newvar)
print(var.strip())
# Out:
# asif kasi
# asif kasi

# %%
# Question 01
man1={
    "shariq":21,
    "asim":20,
    "ijaz":80,
    "rehan":25,
    "answer":33
}
print(max(man1,key=man1.get))
# Out:
# ijaz

# %%
# Question 02
dic={
    "name":"Asim",
    "F.name":"zahid",
    "class":"12th",
}
dic["phone no"]="03490349203"
print(dic)
# Out:
# {'name': 'Asim', 'F.name': 'zahid', 'class': '12th', 'phone no': '03490349203'}

# %%
# Question 03
dic={
    "01":{
    "name":"Asim",
    "F.name":"zahid",
    "class":"12th",
    "subjects":["math","physics","chemistry"],
},
    "02":{
    "name":"shariq",
    "F.name":"zahid",
    "class":"12th",
    "subjects":["urdu","computer science","islamiat"],
    },
    "03":{
    "name":"shariq",
    "F.name":"zahid",
    "class":"12th",
    "subjects":["singhi maro","science","pak study"],
    }
}
print(dic["03"]["F.name"])
# Out:
# zahid
