# %%
age1=int(input("enter your age"))
age2=int(input("enter your friend age"))
sum=age1+age2
print(sum)
# Out:
# 99

# %%
print(35+35,35-35,35*2,35/2,35//2,3**2,35%2)
print(35-35)
print(35*2)
print(35/2)
print(35//2)
print(3**2)
print(35%2)
# Out:
# 70 0 70 17.5 17 9 1
# 0
# 70
# 17.5
# 17
# 9
# 1

# %%
scard= input("do you have std card")
if scard=="y" or scard=="Y":
    print("Allowed")
else:
    ncard= input("do you have CNIC")
    if ncard=="y" or ncard=="Y":
        print("Allowed")
    else:
        print("not Allowed")
# Out:
# Allowed

# %%
scard=input("enter your scard")
ncard=input("enter your ncard")
if scard=="y" or scard=="Y"and ncard=="y" or ncard=="Y":
    print("allowed")
else:
    print("NOT ALLOWED")
# Out:
# NOT ALLOWED

# %%
marks=int(input("enter your marks"))
if marks==100:
    print("pass")
elif marks>=60:
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
userinput=int(input("enter your marks"))
if userinput>=80 and userinput <=100:
    print("A grade")
elif userinput>=70 and userinput<=80:
    print("B grade")
elif userinput>=60 and userinput<=70:
    print("C grade")
elif userinput>0 and userinput<=50:
    print("fail")
else:
    print("undefined")
# Out:
# fail

# %%
userinput=(input("enter your marks"))
if userinput.isdigit():
    marks=int(userinput)
    if marks>=80 and marks <=100:
        print("A grade")
    elif marks<0 or marks>100:
        print("undefined")
    elif marks>=70 and marks<=80:
        print("B grade")
    elif marks>=60 and marks<=70:
        print("C grade")
    elif marks>0 and marks<=50:
        print("fail")
else:
    print("undefined")
# Out:
# undefined

# %%
a= int(input("enter first number"))
b= int(input("enter second numbeer"))
c= int(input("enter third number"))
if a>=b and a>=c:
    maximum=a
elif b>=c and b>=c:
    maximum=b
else:
    maximum=c

print("maximum number is:",maximum)
# Out:
# maximum number is: 2

# %%
a=int(input("enter X quadrant"))
if a%3==0 and a%5==0 and a!=0:
    print("divisible by 3 and 5")
elif a%3==0 and a!=0:
    print("givig number only divisible by 3 not divisible by 5") 
elif a%5==0 and a!=0:
    print("give number only divisible by 5 not by 3") 
else:
    print("not divisible")
# Out:
# givig number only divisible by 3 not divisible by 5

# %%
minutes = int(input("Kitne minutes hain? "))

remaining_minutes = minutes % 60
hours = minutes // 60

print(f"{hours} hour(s) aur {remaining_minutes} minute(s)")
# Out:
# 2 hour(s) aur 13 minute(s)

# %%
amount = int(input("Raqam (Amount) daalein: "))

note100 = amount // 100
amount %= 100

note50 = amount // 50
amount %=  50

note20 = amount // 20
amount = amount % 20

note10 = amount // 10
amount = amount % 10

note5 = amount // 5
amount = amount % 5

note2 = amount // 2
amount = amount % 2

note1 = amount

if note100 > 0:
    print("100 rupees ke notes:", note100)
if note50 > 0:
    print("50 rupees ka note:", note50)
if note20 > 0:
    print("20 rupees ka note:", note20)
if note10 > 0:
    print("10 rupees ka note:", note10)
if note5 > 0:
    print("5 rupees ka note:", note5)
if note2 > 0:
    print("2 rupees ka note:", note2)
if note1 > 0:
    print("1 rupee ka note:", note1)
# Out:
# 100 rupees ke notes: 10

# %%
days=(int(input("enter the value")))

year=days//365
days=days%365

months=days//30
days=days%30

weeks=days//7
days=days%7

day=days

if year>0:
    print("year",year)
if months>0:
    print("months",months)
if weeks>0:
    print("weeks",weeks)
if day>0:
    print("days",day)
# Out:
# year 2
# months 9
