# %%
import pandas as pd
students=[
    {
        "roll no":"oo1",
        "name":"shariq",
        "last name":"shah",
        "f.name":"farooq shah",
        "class":"python"
    },
    {
        "roll no":"oo2",
        "name":"sheeraz",
        "last name":"khan",
        "f.name":"muhammad khan",
        "class":"python"
    },
    {
        "roll no":"oo3",
        "name":"maaz",
        "last name":"khan",
        "f.name":"muhammad naeem",
        "class":"python"
    },
    {
        "roll no":"oo4",
        "name":"Abdul",
        "last name":"rehman",
        "f.name":"shakir khan",
        "class":"python"
    },
    {
        "roll no":"oo5",
        "name":"farhan",
        "last name":"khan",
        "f.name":"adil khan",
        "class":"python"
    },
    {
        "roll no":"oo6",
        "name":"Abdul",
        "last name":"Wahab",
        "f.name":"Abdul sattar",
        "class":"python"
    }
]
students
# Out:
# [{'roll no': 'oo1',
#   'name': 'shariq',
#   'last name': 'shah',
#   'f.name': 'farooq shah',
#   'class': 'python'},
#  {'roll no': 'oo2',
#   'name': 'sheeraz',
#   'last name': 'khan',
#   'f.name': 'muhammad khan',
#   'class': 'python'},
#  {'roll no': 'oo3',
#   'name': 'maaz',
#   'last name': 'khan',
#   'f.name': 'muhammad naeem',
#   'class': 'python'},
#  {'roll no': 'oo4',
#   'name': 'Abdul',
#   'last name': 'rehman',
#   'f.name': 'shakir khan',
#   'class': 'python'},
#  {'roll no': 'oo5',
#   'name': 'farhan',
#   'last name': 'khan',
#   'f.name': 'adil khan',
#   'class': 'python'},
#  {'roll no': 'oo6',
#   'name': 'Abdul',
#   'last name': 'Wahab',
#   'f.name': 'Abdul sattar',
#   'class': 'python'}]

# %%
df=pd.DataFrame(students)
df
# Out:
#   roll no     name last name          f.name   class
# 0     oo1   shariq      shah     farooq shah  python
# 1     oo2  sheeraz      khan   muhammad khan  python
# 2     oo3     maaz      khan  muhammad naeem  python
# 3     oo4    Abdul    rehman     shakir khan  python
# 4     oo5   farhan      khan       adil khan  python
# 5     oo6    Abdul     Wahab    Abdul sattar  python

# %%
df.to_csv("data.csv",index=False)
