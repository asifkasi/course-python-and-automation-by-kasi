# %% [markdown]
# # Practice Questions

# %% [markdown]
# ## 1. Write a Python program to get the number of followers of a given twitter account.

# %%
import requests
from bs4 import BeautifulSoup
web1=requests.get('https://x.com/asifokasi')
web1.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(web1.text,'html.parser')
followers=soup.find('div',class_='css-175oi2r')
value=followers.find('span',class_='css-1jxf684 r-bcqeeo r-1ttztb7 r-qvutc0 r-poiln3')
value
# Out:
# <span class="css-1jxf684 r-bcqeeo r-1ttztb7 r-qvutc0 r-poiln3">Something went wrong, but don’t fret — let’s give it another shot.</span>
