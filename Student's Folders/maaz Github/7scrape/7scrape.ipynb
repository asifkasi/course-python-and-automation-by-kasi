# %% [markdown]
# ## 7. https://webscraper.io/test-sites/e-commerce/static/computers/laptops

# %% [markdown]
# ## 7.1 Extract first product details save into csv file.

# %% [markdown]
# ## 7.2 Extract product details from first row & save into csv file.

# %% [markdown]
# ## 7.3 Extract all product details from first page & save into csv file.

# %% [markdown]
# ## 7.4 Extract all product details from second page & save into another csv file.

# %% [markdown]
# ## 7.5 Extract all product details from first page to fifth page & save into single csv file.
