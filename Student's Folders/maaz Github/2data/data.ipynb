# %% [markdown]
# ##  1. Write a Python program to get the number of datasets currently listed on data.gov.

# %%
import requests
from bs4 import BeautifulSoup
headers = {
    "User-Agent": "IsraBot"
}
response = requests.get("https://data.gov", headers=headers)
# print(response.text)
soup = BeautifulSoup(response.text, 'html.parser')
dataset = soup.find('span', class_='text-color-red')
# for label in dataset:
#     print(label.gtext)
dataset
# Out:
# <span class="text-color-red">364,175</span>

# %% [markdown]
# ## 2. Write a Python program to display the name of the most recently added dataset on data.gov.

# %%
import requests

url = "https://catalog.data.gov/api/3/action/package_search"
params = {"sort": "metadata_created desc", "rows": 1}

response = requests.get(url, params=params)
data = response.json()

dataset = data["result"]["results"][0]

print("Most recently added dataset:")
print("Title:", dataset["title"])
print("Date added:", dataset["metadata_created"])
# Out:
# Most recently added dataset:
# Title: Field station locations and magnetic susceptibility data for the Yukon River Crossing Project, Alaska, collected June-July 2016
# Date added: 2025-11-08T22:36:51.189170
