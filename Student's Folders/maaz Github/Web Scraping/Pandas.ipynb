# %%
import pandas as pd

# %%
var_data = [
    {
        "Full Name": "Maaz Ahmed",
        "Father Name": "Muhammad Naeem",
        "Roll No.": "0031",
        "Class": "Python"
    },
      {
        "Full Name": "Osama Ahmed",
        "Father Name": "Muhammad ",
        "Roll No.": "001",
        "Class": "Python"
    },
    
        {
        "Full Name": "saad Ahmed",
        "Father Name": "Muhammad Faheem",
        "Roll No.": "0021",
        "Class": "Python"
    },
        {
        "Full Name": "Bilal Ahmed",
        "Father Name": "Muhammad Aslam",
        "Roll No.": "0033",
        "Class": "Python"
    },
        {
        "Full Name": "Usman Ahmed",
        "Father Name": "Muhammad Akram",
        "Roll No.": "0041",
        "Class": "Python"
    }
]
print(var_data)
# Out:
# [{'Full Name': 'Maaz Ahmed', 'Father Name': 'Muhammad Naeem', 'Roll No.': '0031', 'Class': 'Python'}, {'Full Name': 'Osama Ahmed', 'Father Name': 'Muhammad ', 'Roll No.': '001', 'Class': 'Python'}, {'Full Name': 'saad Ahmed', 'Father Name': 'Muhammad Faheem', 'Roll No.': '0021', 'Class': 'Python'}, {'Full Name': 'Bilal Ahmed', 'Father Name': 'Muhammad Aslam', 'Roll No.': '0033', 'Class': 'Python'}, {'Full Name': 'Usman Ahmed', 'Father Name': 'Muhammad Akram', 'Roll No.': '0041', 'Class': 'Python'}]

# %%
df = pd.DataFrame(var_data)
print(df)
# Out:
#      Full Name      Father Name Roll No.   Class
# 0   Maaz Ahmed   Muhammad Naeem     0031  Python
# 1  Osama Ahmed        Muhammad       001  Python
# 2   saad Ahmed  Muhammad Faheem     0021  Python
# 3  Bilal Ahmed   Muhammad Aslam     0033  Python
# 4  Usman Ahmed   Muhammad Akram     0041  Python

# %%
df.to_csv("Maaz_data.csv", index=False)

# %%
var_data = [
    {
        "Full Name": "Maaz Ahmed",
        "Father Name": "Muhammad Naeem",
        "Roll No.": "0031",
        "Class": "Python"}
]
