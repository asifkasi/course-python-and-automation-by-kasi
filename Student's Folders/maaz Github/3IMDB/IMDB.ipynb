# %% [markdown]
# ## 2.1 Extract First movie details and save into csv

# %%
import requests
from bs4 import BeautifulSoup


header={
    "User-Agent": "Baiduspider"
}

response = requests.get('https://www.imdb.com/chart/top/',headers=header)
response.status_code

soup = BeautifulSoup(response.text, 'html.parser')

print(soup.prettify())

# %% [markdown]
# ## 2.2 Extract All 250 movies details and save into csv.

# %%
import requests
from bs4 import BeautifulSoup


header={
    "User-Agent": "Baiduspider"
}

response = requests.get('https://www.imdb.com/chart/top/',headers=header)
response.status_code

soup = BeautifulSoup(response.text, 'html.parser')

print(soup.prettify())

var = soup.find("div",class_='ipc-metadata-list ipc-metadata-list--dividers-none sc-d24d5d37-0 hDHQeM alt_item_colors compact-list-view ipc-metadata-list--base')# imdb sarei li find khar taha ha 

var1 = soup.find_all("li",class_='ipc-metadata-list-summary-item')
print(var1)



# dict1={
#     'movie name': '',
#     'movie index': '',
#     'movie url': '',
#     'rating': '',
#     'year':'',
#     'movie hours': '',
#     'movie vote': '',

# }

# dict1['moviename']= var1[0].find('h3').text.strip().split(". ")[1]
# dict1['movieindex']=var1[0].find('h3').text.strip().split(". ")[0]
# dict1['movieurl'] =var1[0].find('a')['href']
# dict1['year']=var1[0].find_all("span",class_= "sc-caa65599-7 eeMIpC cli-title-metadata-item")[0].text.strip()
# dict1['movie =hours']=var1[0].find_all("span",class_= "sc-caa65599-7 eeMIpC cli-title-metadata-item")[1].text.strip()
# dict1['rating']=var1[0].find("span",class_= "ipc-rating-star--rating").text.strip()
# dict1['movievote']=var1[0].find("span",class_= "ipc-rating-star--voteCount").text.strip()[1:-1]
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <script>
#    if(typeof uet === 'function'){ uet('bb', 'LoadTitle', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1762792657040);
#         }
#     })
#   </script>
#   <title>
#    IMDb Top 250 movies
#   </title>
#   <meta content="As rated by regular IMDb voters." data-id="main" name="description"/>
# ...

# %%
dict1={
    'movie name': '',
    'movie index': '',
    'movie url': '',
    'rating': '',
    'year':'',
    'movie hours': '',
    'movie vote': '',

}


dict1['moviename']= var1[0].find('h3').text.strip().split(". ")[1]
dict1['movieindex']=var1[0].find('h3').text.strip().split(". ")[0]
dict1['movieurl'] =var1[0].find('a')['href']
dict1['year']=var1[0].find_all("span",class_= "sc-caa65599-7 eeMIpC cli-title-metadata-item")[0].text.strip()
dict1['moviehours']=var1[0].find_all("span",class_= "sc-caa65599-7 eeMIpC cli-title-metadata-item")[1].text.strip()
dict1['rating']=var1[0].find("span",class_= "ipc-rating-star--rating").text.strip()
dict1['movievote']=var1[0].find("span",class_= "ipc-rating-star--voteCount").text.strip()[1:-1]

print(dict)
# Out:
# <class 'dict'>
