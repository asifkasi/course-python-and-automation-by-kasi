# %% [markdown]
# ## https://www.accuweather.com/en/search-locations?query=karachi
# ## 1.1 will show the list of cities

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get("https://www.accuweather.com/en/search-locations")
response.status_code 
soup= BeautifulSoup(response.text,('html.parser'))
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Access Denied
#   </title>
#  </head>
#  <body>
#   <h1>
#    Access Denied
#   </h1>
#   You don't have permission to access "http://www.accuweather.com/en/search-locations" on this server.
#   <p>
#    Reference #18.d67d117.1763045806.769c8cf7
#    <p>
#     https://errors.edgesuite.net/18.d67d117.1763045806.769c8cf7
#    </p>
#   </p>
#  </body>
# </html>
