# %% [markdown]
# # 1 medium
# # https://www.cisa.gov/news-events/cybersecurity-advisories

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get("https://www.cisa.gov/news-events/cybersecurity-advisories")
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en" prefix="og: https://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Advisory DefinitionsCybersecurity AdvisoriesIndustrial Control Systems Advisories" name="description"/>
#   <link href="https://www.cisa.gov/news-events/cybersecurity-advisories" rel="canonical"/>
#   <meta content="Cybersecurity and Infrastructure Security Agency CISA" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.cisa.gov/news-events/cybersecurity-advisories" property="og:url"/>
#   <meta content="Cybersecurity Alerts &amp; Advisories | CISA" property="og:title"/>
#   <meta content="Advisory DefinitionsCybersecurity AdvisoriesIndustrial Control Systems Advisories" property="og:description"/>
#   <meta content="Drupal 11 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
# ...

# %%
complete_data = []
def scrape_complete_website(url):
    # response = requests.get(url)
    # response.raise_for_status()
    # soup = BeautifulSoup(response.content, 'html.parser')
    # header_info = {}
    products = []
    all_products = soup.find_all('article', class_='product_pod')
    
    for idx, product in enumerate(all_products, 1):
        # Product name
        product_name = product.find('h3').find('a')['title']
        
        # Product URL
        product_link = product.find('h3').find('a')['href']
        product_url = f"https://www.cisa.gov/news-events/cybersecurity-advisories/{product_link}"
        
        # Image URL
        img_tag = product.find('img')
        img_url = f"https://www.cisa.gov/news-events/cybersecurity-advisories/{img_tag['src']}"
        # img_alt = img_tag.get('alt', 'N/A')

        # # Date
        date = product.find('p', class_='date').text.strip()
        products.append({
            'product_index': idx,
            'product_name': product_name,
            'date': date,
            'product_url': product_url,
            'img_url': img_url,
        })
#         complete_data = {
#             'website_url': url,
#             'header': header_info,
#             'total_products': len(products),
#             'products': products,
#         }
#     return complete_data
# if __name__ == "__main__":
#     url = "https://www.cisa.gov/news-events/cybersecurity-advisories"
    
    
    
#     # Scrape complete data
#     complete_data = scrape_complete_website(url)
    
#     # Print in readable format
    print(complete_data)

    # Optionally save to CSV file
    df = pd.DataFrame(complete_data['products'])
    df.to_csv('toscrape.csv', mode='a+', index=False, encoding='utf-8')

# %%
url = "https://www.cisa.gov/news-events/cybersecurity-advisories?page="
response = requests.get(url)

# %%
var = soup.find('div', class_='c-view c-view--index-advisory-listing c-view--display-block_1 view js-view-dom-id-00cdff2999fd3de8919f971270894f90acf8d56017bc2b2308c6524dc357408e')
# print(var)
div = soup.find_all('div', class_='c-view__row')
print(div)
# Out:
# [<div class="c-view__row">
# <article class="is-promoted c-teaser c-teaser--horizontal" role="article">
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2025-11-04T12:00:00Z">Nov 04, 2025</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/alerts/2025/11/04/cisa-releases-five-industrial-control-systems-advisories" target="_self">
# <span>CISA Releases Five Industrial Control Systems Advisories</span>
# </a> </h3>
# </div>
# </div>
# </article>
# </div>, <div class="c-view__row">
# <article class="is-promoted c-teaser c-teaser--horizontal" role="article">
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2025-11-04T12:00:00Z">Nov 04, 2025</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# ...

# %%
dict={
    "header":div[0].find('h3').text.strip(),
    "link":div[0].find('a')['href'],
    "date":div[0].find('div',class_='c-teaser__date').text.strip()
}

div[0].find('h3').text.strip()

div[0].find('a')['href']
div[0].find('div',class_='c-teaser__date').text.strip()
print(dict)
# Out:
# {'header': 'CISA Releases Five Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/11/04/cisa-releases-five-industrial-control-systems-advisories', 'date': 'Nov 04, 2025'}

# %%
list= []
for i in div:
    dict={
    "header":i.find('h3').text.strip(),
    "link":i.find('a')['href'],
    "date":i.find('div',class_='c-teaser__date').text.strip()
    }
    print(dict)
    list.append(dict)
# Out:
# {'header': 'CISA Releases Five Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/11/04/cisa-releases-five-industrial-control-systems-advisories', 'date': 'Nov 04, 2025'}
# {'header': 'CISA Adds Two Known Exploited Vulnerabilities to Catalog', 'link': '/news-events/alerts/2025/11/04/cisa-adds-two-known-exploited-vulnerabilities-catalog', 'date': 'Nov 04, 2025'}
# {'header': 'CISA Adds Two Known Exploited Vulnerabilities to Catalog', 'link': '/news-events/alerts/2025/10/30/cisa-adds-two-known-exploited-vulnerabilities-catalog', 'date': 'Oct 30, 2025'}
# {'header': 'CISA Releases Two Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/10/30/cisa-releases-two-industrial-control-systems-advisories', 'date': 'Oct 30, 2025'}
# ...

# %%
import pandas as pd

df = pd.DataFrame(list)
df
df.to_csv('cybersecurity.csv',index=False)

# %% [markdown]
# # 2

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.cisa.gov/news-events/cybersecurity-advisories?page=1"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en" prefix="og: https://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Advisory DefinitionsCybersecurity AdvisoriesIndustrial Control Systems Advisories" name="description"/>
#   <link href="https://www.cisa.gov/news-events/cybersecurity-advisories" rel="canonical"/>
#   <meta content="Cybersecurity and Infrastructure Security Agency CISA" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.cisa.gov/news-events/cybersecurity-advisories" property="og:url"/>
#   <meta content="Cybersecurity Alerts &amp; Advisories | CISA" property="og:title"/>
#   <meta content="Advisory DefinitionsCybersecurity AdvisoriesIndustrial Control Systems Advisories" property="og:description"/>
#   <meta content="Drupal 11 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
# ...

# %%
var = soup.find('div', class_='c-view c-view--index-advisory-listing c-view--display-block_1 view js-view-dom-id-4a1ae272ad4971d675d8b5af8b9ca1487a49a818c1be071d9419130397fe32d0')
# print(var)
div = soup.find_all('div', class_='c-view__row')
print(div)
# Out:
# [<div class="c-view__row">
# <article class="is-promoted c-teaser c-teaser--horizontal" role="article">
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2025-10-22T12:00:00Z">Oct 22, 2025</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/alerts/2025/10/22/cisa-adds-one-known-exploited-vulnerability-catalog" target="_self">
# <span>CISA Adds One Known Exploited Vulnerability to Catalog</span>
# </a> </h3>
# </div>
# </div>
# </article>
# </div>, <div class="c-view__row">
# <article class="is-promoted c-teaser c-teaser--horizontal" role="article">
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2025-10-21T12:00:00Z">Oct 21, 2025</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# ...

# %%
dic1={
    "header":div[0].find('h3').text.strip(),
    "link":div[0].find('a')['href'],
    "date":div[0].find('div',class_='c-teaser__date').text.strip()
}

div[0].find('h3').text.strip()

div[0].find('a')['href']
div[0].find('div',class_='c-teaser__date').text.strip()
print(dic1)
# Out:
# {'header': 'CISA Adds One Known Exploited Vulnerability to Catalog', 'link': '/news-events/alerts/2025/10/22/cisa-adds-one-known-exploited-vulnerability-catalog', 'date': 'Oct 22, 2025'}

# %%
list= []
for i in div:
    dict={
    "header":i.find('h3').text.strip(),
    "link":i.find('a')['href'],
    "date":i.find('div',class_='c-teaser__date').text.strip()
    }
    print(dict)
    list.append(dict)
# Out:
# {'header': 'CISA Adds One Known Exploited Vulnerability to Catalog', 'link': '/news-events/alerts/2025/10/22/cisa-adds-one-known-exploited-vulnerability-catalog', 'date': 'Oct 22, 2025'}
# {'header': 'CISA Releases 10 Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/10/21/cisa-releases-10-industrial-control-systems-advisories', 'date': 'Oct 21, 2025'}
# {'header': 'CISA Adds Five Known Exploited Vulnerabilities to Catalog', 'link': '/news-events/alerts/2025/10/20/cisa-adds-five-known-exploited-vulnerabilities-catalog', 'date': 'Oct 20, 2025'}
# {'header': 'CISA Releases Thirteen Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/10/16/cisa-releases-thirteen-industrial-control-systems-advisories', 'date': 'Oct 16, 2025'}
# {'header': 'CISA Directs Federal Agencies to Mitigate Vulnerabilities in F5 Devices', 'link': '/news-events/alerts/2025/10/15/cisa-directs-federal-agencies-mitigate-vulnerabilities-f5-devices', 'date': 'Oct 15, 2025'}
# ...

# %%
import pandas as pd

df = pd.DataFrame(list)
df
df.to_csv('cybersecurity.csv',mode ='a+',index=False)

# %%
var = soup.find('div', class_='c-view c-view--index-advisory-listing c-view--display-attachment_1 view js-view-dom-id-cd300881f02f6ff17970fba4322c9c0c5be01174a16ea59d2ccb5be780654459')
# print(var)
div = soup.find_all('div', class_='c-view__row')
print(div)
# Out:
# [<div class="c-view__row">
# <article class="is-promoted c-teaser c-teaser--horizontal" role="article">
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2025-10-07T12:00:00Z">Oct 07, 2025</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/alerts/2025/10/07/cisa-releases-two-industrial-control-systems-advisories" target="_self">
# <span>CISA Releases Two Industrial Control Systems Advisories</span>
# </a> </h3>
# </div>
# </div>
# </article>
# </div>, <div class="c-view__row">
# <article class="is-promoted c-teaser c-teaser--horizontal" role="article">
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2025-10-07T12:00:00Z">Oct 07, 2025</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# ...

# %% [markdown]
# # 3

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.cisa.gov/news-events/cybersecurity-advisories?page=2"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en" prefix="og: https://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Advisory DefinitionsCybersecurity AdvisoriesIndustrial Control Systems Advisories" name="description"/>
#   <link href="https://www.cisa.gov/news-events/cybersecurity-advisories" rel="canonical"/>
#   <meta content="Cybersecurity and Infrastructure Security Agency CISA" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.cisa.gov/news-events/cybersecurity-advisories" property="og:url"/>
#   <meta content="Cybersecurity Alerts &amp; Advisories | CISA" property="og:title"/>
#   <meta content="Advisory DefinitionsCybersecurity AdvisoriesIndustrial Control Systems Advisories" property="og:description"/>
#   <meta content="Drupal 11 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
# ...

# %%
dict={
    "header":div[0].find('h3').text.strip(),
    "link":div[0].find('a')['href'],
    "date":div[0].find('div',class_='c-teaser__date').text.strip()
}

div[0].find('h3').text.strip()

div[0].find('a')['href']
div[0].find('div',class_='c-teaser__date').text.strip()
print(dict)
# Out:
# {'header': 'CISA Releases Two Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/10/07/cisa-releases-two-industrial-control-systems-advisories', 'date': 'Oct 07, 2025'}

# %%
list= []
for i in div:
    dict={
    "header":i.find('h3').text.strip(),
    "link":i.find('a')['href'],
    "date":i.find('div',class_='c-teaser__date').text.strip()
    }
    print(dict)
    list.append(dict)
# Out:
# {'header': 'CISA Releases Two Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/10/07/cisa-releases-two-industrial-control-systems-advisories', 'date': 'Oct 07, 2025'}
# {'header': 'CISA Adds One Known Exploited Vulnerability to Catalog', 'link': '/news-events/alerts/2025/10/07/cisa-adds-one-known-exploited-vulnerability-catalog', 'date': 'Oct 07, 2025'}
# {'header': 'CISA Adds Seven Known Exploited Vulnerabilities to Catalog', 'link': '/news-events/alerts/2025/10/06/cisa-adds-seven-known-exploited-vulnerabilities-catalog', 'date': 'Oct 06, 2025'}
# {'header': 'CISA Releases Two Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/10/02/cisa-releases-two-industrial-control-systems-advisories', 'date': 'Oct 02, 2025'}
# {'header': 'CISA Adds Five Known Exploited Vulnerabilities to Catalog', 'link': '/news-events/alerts/2025/10/02/cisa-adds-five-known-exploited-vulnerabilities-catalog', 'date': 'Oct 02, 2025'}
# ...

# %%
import pandas as pd

df = pd.DataFrame(list)
df
df.to_csv('cybersecurity.csv',mode ='a+',index=False)

# %% [markdown]
# # 4

# %%
import requests
from bs4 import BeautifulStoneSoup
url = "https://www.cisa.gov/news-events/cybersecurity-advisories?page=3"
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en" prefix="og: https://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Advisory DefinitionsCybersecurity AdvisoriesIndustrial Control Systems Advisories" name="description"/>
#   <link href="https://www.cisa.gov/news-events/cybersecurity-advisories" rel="canonical"/>
#   <meta content="Cybersecurity and Infrastructure Security Agency CISA" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.cisa.gov/news-events/cybersecurity-advisories" property="og:url"/>
#   <meta content="Cybersecurity Alerts &amp; Advisories | CISA" property="og:title"/>
#   <meta content="Advisory DefinitionsCybersecurity AdvisoriesIndustrial Control Systems Advisories" property="og:description"/>
#   <meta content="Drupal 11 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
# ...

# %%
var = soup.find('div', class_='c-view c-view--index-advisory-listing c-view--display-block_1 view js-view-dom-id-4a1ae272ad4971d675d8b5af8b9ca1487a49a818c1be071d9419130397fe32d0')
# print(var)
div = soup.find_all('div', class_='c-view__row')
print(div)
# Out:
# [<div class="c-view__row">
# <article class="is-promoted c-teaser c-teaser--horizontal" role="article">
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2025-09-25T12:00:00Z">Sep 25, 2025</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/alerts/2025/09/25/cisa-releases-one-industrial-control-systems-advisory" target="_self">
# <span>CISA Releases One Industrial Control Systems Advisory</span>
# </a> </h3>
# </div>
# </div>
# </article>
# </div>, <div class="c-view__row">
# <article class="is-promoted c-teaser c-teaser--horizontal" role="article">
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2025-09-23T12:00:00Z">Sep 23, 2025</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# ...

# %%
div[0]
# Out:
# <div class="c-view__row">
# <article class="is-promoted c-teaser c-teaser--horizontal" role="article">
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2025-09-25T12:00:00Z">Sep 25, 2025</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/alerts/2025/09/25/cisa-releases-one-industrial-control-systems-advisory" target="_self">
# <span>CISA Releases One Industrial Control Systems Advisory</span>
# </a> </h3>
# </div>
# </div>
# </article>
# </div>

# %%
dict={
    "header":div[0].find('h3').text.strip(),
    "link":div[0].find('a')['href'],
    "date":div[0].find('div',class_='c-teaser__date').text.strip()
}

div[0].find('h3').text.strip()

div[0].find('a')['href']
div[0].find('div',class_='c-teaser__date').text.strip()
print(dict)
# Out:
# {'header': 'CISA Releases One Industrial Control Systems Advisory', 'link': '/news-events/alerts/2025/09/25/cisa-releases-one-industrial-control-systems-advisory', 'date': 'Sep 25, 2025'}

# %%
list= []
for i in div:
    dict={
    "header":i.find('h3').text.strip(),
    "link":i.find('a')['href'],
    "date":i.find('div',class_='c-teaser__date').text.strip()
    }
    print(dict)
    list.append(dict)
# Out:
# {'header': 'CISA Releases One Industrial Control Systems Advisory', 'link': '/news-events/alerts/2025/09/25/cisa-releases-one-industrial-control-systems-advisory', 'date': 'Sep 25, 2025'}
# {'header': 'Widespread Supply Chain Compromise Impacting npm Ecosystem', 'link': '/news-events/alerts/2025/09/23/widespread-supply-chain-compromise-impacting-npm-ecosystem', 'date': 'Sep 23, 2025'}
# {'header': 'CISA Releases Advisory on Lessons Learned from an Incident Response Engagement', 'link': '/news-events/alerts/2025/09/23/cisa-releases-advisory-lessons-learned-incident-response-engagement', 'date': 'Sep 23, 2025'}
# {'header': 'CISA Releases Six Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/09/23/cisa-releases-six-industrial-control-systems-advisories', 'date': 'Sep 23, 2025'}
# ...

# %%
import pandas as pd 

df = pd.DataFrame(list)
df
df.to_csv('cybersecurity.csv',mode ='a+',index=False)

# %% [markdown]
# # 5

# %%
import requests
from bs4 import BeautifulStoneSoup
url = "https://www.cisa.gov/news-events/cybersecurity-advisories?page=4"
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en" prefix="og: https://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Advisory DefinitionsCybersecurity AdvisoriesIndustrial Control Systems Advisories" name="description"/>
#   <link href="https://www.cisa.gov/news-events/cybersecurity-advisories" rel="canonical"/>
#   <meta content="Cybersecurity and Infrastructure Security Agency CISA" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.cisa.gov/news-events/cybersecurity-advisories" property="og:url"/>
#   <meta content="Cybersecurity Alerts &amp; Advisories | CISA" property="og:title"/>
#   <meta content="Advisory DefinitionsCybersecurity AdvisoriesIndustrial Control Systems Advisories" property="og:description"/>
#   <meta content="Drupal 11 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
# ...

# %%
var = soup.find('div', class_='c-view c-view--index-advisory-listing c-view--display-block_1 view js-view-dom-id-4a1ae272ad4971d675d8b5af8b9ca1487a49a818c1be071d9419130397fe32d0')
# print(var)
div = soup.find_all('div', class_='c-view__row')
print(div)
# Out:
# [<div class="c-view__row">
# <article class="is-promoted c-teaser c-teaser--horizontal" role="article">
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2025-09-16T12:00:00Z">Sep 16, 2025</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/alerts/2025/09/16/cisa-releases-eight-industrial-control-systems-advisories" target="_self">
# <span>CISA Releases Eight Industrial Control Systems Advisories</span>
# </a> </h3>
# </div>
# </div>
# </article>
# </div>, <div class="c-view__row">
# <article class="is-promoted c-teaser c-teaser--horizontal" role="article">
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2025-09-11T12:00:00Z">Sep 11, 2025</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# ...

# %%
dict={
    "header":div[0].find('h3').text.strip(),
    "link":div[0].find('a')['href'],
    "date":div[0].find('div',class_='c-teaser__date').text.strip()
}

div[0].find('h3').text.strip()

div[0].find('a')['href']
div[0].find('div',class_='c-teaser__date').text.strip()
print(dict)
# Out:
# {'header': 'CISA Releases Eight Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/09/16/cisa-releases-eight-industrial-control-systems-advisories', 'date': 'Sep 16, 2025'}

# %%
list= []
for i in div:
    dict={
    "header":i.find('h3').text.strip(),
    "link":i.find('a')['href'],
    "date":i.find('div',class_='c-teaser__date').text.strip()
    }
    print(dict)
    list.append(dict)
# Out:
# {'header': 'CISA Releases Eight Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/09/16/cisa-releases-eight-industrial-control-systems-advisories', 'date': 'Sep 16, 2025'}
# {'header': 'CISA Adds One Known Exploited Vulnerability to Catalog', 'link': '/news-events/alerts/2025/09/11/cisa-adds-one-known-exploited-vulnerability-catalog', 'date': 'Sep 11, 2025'}
# {'header': 'CISA Releases Eleven Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/09/11/cisa-releases-eleven-industrial-control-systems-advisories', 'date': 'Sep 11, 2025'}
# {'header': 'CISA Releases Fourteen Industrial Control Systems Advisories', 'link': '/news-events/alerts/2025/09/09/cisa-releases-fourteen-industrial-control-systems-advisories', 'date': 'Sep 09, 2025'}
# {'header': 'CISA Adds Three Known Exploited Vulnerabilities to Catalog', 'link': '/news-events/alerts/2025/09/04/cisa-adds-three-known-exploited-vulnerabilities-catalog', 'date': 'Sep 04, 2025'}
# ...

# %%
import pandas as pd

df = pd.DataFrame(list)
df
df.to_csv('cybersecurity.csv',mode ='a+',index=False)
