# %% [markdown]
# # 3.1 Extract Table of first page & save into csv file.

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://www.scrapethissite.com/pages/forms/')
response.status_code

soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
var = soup.find('table',class_='table')

var1= soup.find_all('table',class_='table')
var1
# Out:
# [<table class="table">
#  <tr>
#  <th>
#                              Team Name
#                          </th>
#  <th>
#                              Year
#                          </th>
#  <th>
#                              Wins
#                          </th>
#  <th>
#                              Losses
#                          </th>
#  <th>
#                              OT Losses
#                          </th>
#  <th>
#                              Win %
#                          </th>
#  <th>
#                              Goals For (GF)
#                          </th>
#  <th>
#                              Goals Against (GA)
#                          </th>
#  <th>
#                              + / -
#                          </th>
#  </tr>
#  <tr class="team">
#  <td class="name">
#                              Boston Bruins
#                          </td>
#  <td class="year">
#                              1990
#                          </td>
# ...

# %%
len(var1)
# Out:
# 1

# %%
len(tr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 len(tr)
#
# NameError: name 'tr' is not defined

# %%
len(trs)
# Out:
# 26

# %%
trs =var1[0].find_all('tr')

# %%
tr = trs[1]

# %%
for tr

# %%
dict['name']= tr.find('td',class_='name').text.strip()
dict['year']=tr.find('td',class_='year').text.strip()
dict['wins']=tr.find('td',class_='wins').text.strip()
dict['losses']=tr.find('td',class_='losses').text.strip()
dict['ot-losses']=tr.find('td',class_='ot-losses').text.strip()
# dict['pct text-success']=tr.find('td',class_='pct text-success').text.strip()
dict['pct text-success']=tr.find('td',class_='pct').text.strip()

dict['gf']=tr.find('td',class_='gf').text.strip()
dict['ga']=tr.find('td',class_='ga').text.strip()
dict['diff text-success']=tr.find('td',class_='diff').text.strip()
# dict['diff text-success']=tr.find('td',class_='diff text-success').text.strip()

print(dict)
# Out:
# {'name': 'Los Angeles Kings', 'year': '1992', 'wins': '39', 'losses': '35', 'ot-losses': '', 'pct text-success': '0.464', 'gf': '338', 'ga': '340', 'diff text-success': '-2'}

# %%
list = []
for i in trs[1:]:
        dict={
            'name':'',
            'year':'',
            'wins':'',
            'losses':'',
            'ot-losses':'',
            'pct text-success':'',
            'gf':'',
            'ga':'',
            'diff text-success':''


        }
    # print(dict)
        dict['name']= i.find('td',class_='name').text.strip()
        dict['year']=i.find('td',class_='year').text.strip()
        dict['wins']=i.find('td',class_='wins').text.strip()
        dict['losses']=i.find('td',class_='losses').text.strip()
        dict['ot-losses']=i.find('td',class_='ot-losses').text.strip()
        # dict['pct text-success']=i.find('td',class_='pct text-success').text.strip() # 
        dict['pct text-success']=i.find('td',class_='pct').text.strip()

        dict['gf']=i.find('td',class_='gf').text.strip()
        dict['ga']=i.find('td',class_='ga').text.strip()
        # dict['diff text-success']=i.find('td',class_='diff text-success').text.strip()
        dict['diff text-success']=tr.find('td',class_='diff').text.strip()

        list.append(dict.copy())

# %%
import pandas as pd
# list = []
# list.append(dict)
df = pd.DataFrame(list)
df
df.to_csv('scrapethissite q3_3.csv',index=False)

# %% [markdown]
# # 3.2 Extract Table of second page & save into another csv file.

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://www.scrapethissite.com/pages/forms/?page_num=2')
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
trs = soup.find_all('table',class_='table')
trs
# Out:
# [<table class="table">
#  <tr>
#  <th>
#                              Team Name
#                          </th>
#  <th>
#                              Year
#                          </th>
#  <th>
#                              Wins
#                          </th>
#  <th>
#                              Losses
#                          </th>
#  <th>
#                              OT Losses
#                          </th>
#  <th>
#                              Win %
#                          </th>
#  <th>
#                              Goals For (GF)
#                          </th>
#  <th>
#                              Goals Against (GA)
#                          </th>
#  <th>
#                              + / -
#                          </th>
#  </tr>
#  <tr class="team">
#  <td class="name">
#                              Detroit Red Wings
#                          </td>
#  <td class="year">
#                              1991
#                          </td>
# ...

# %%
trs.find_all('tr')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 trs.find_all('tr')
#
# File c:\Users\T460\AppData\Local\Programs\Python\Python312\Lib\site-packages\bs4\element.py:2902, in ResultSet.__getattr__(self, key)
#    2900 def __getattr__(self, key: str) -> None:
#    2901     """Raise a helpful exception to explain a common code fix."""
# -> 2902     raise AttributeError(
#    2903         f"""ResultSet object has no attribute "{key}". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?"""
#    2904     )
#
# AttributeError: ResultSet object has no attribute "find_all". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
len(trs)
# Out:
# 26

# %%
va = trs[0].find_all('tr')

# %%
va= trs[0]

# %%
len(va)
# Out:
# 53

# %%
len(va)
# Out:
# 53

# %%
len(trs)
# Out:
# 26

# %%
trs[0].find_all('tr')
# Out:
# [<tr>
#  <th>
#                              Team Name
#                          </th>
#  <th>
#                              Year
#                          </th>
#  <th>
#                              Wins
#                          </th>
#  <th>
#                              Losses
#                          </th>
#  <th>
#                              OT Losses
#                          </th>
#  <th>
#                              Win %
#                          </th>
#  <th>
#                              Goals For (GF)
#                          </th>
#  <th>
#                              Goals Against (GA)
#                          </th>
#  <th>
#                              + / -
#                          </th>
#  </tr>,
#  <tr class="team">
#  <td class="name">
#                              Detroit Red Wings
#                          </td>
#  <td class="year">
#                              1991
#                          </td>
#  <td class="wins">
# ...

# %%
va[1].find_all('tr')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 va[1].find_all('tr')
#
# File c:\Users\T460\AppData\Local\Programs\Python\Python312\Lib\site-packages\bs4\element.py:2215, in Tag.__getitem__(self, key)
#    2212 def __getitem__(self, key: str) -> _AttributeValue:
#    2213     """tag[key] returns the value of the 'key' attribute for the Tag,
#    2214     and throws an exception if it's not there."""
# -> 2215     return self.attrs[key]
#
# KeyError: 1

# %%
dict['name']= tr.find('td',class_='name').text.strip()
dict['year']=tr.find('td',class_='year').text.strip()
dict['wins']=tr.find('td',class_='wins').text.strip()
dict['losses']=tr.find('td',class_='losses').text.strip()
dict['ot-losses']=tr.find('td',class_='ot-losses').text.strip()
# dict['pct text-success']=tr.find('td',class_='pct text-success').text.strip()
dict['pct text-success']=tr.find('td',class_='pct').text.strip()

dict['gf']=tr.find('td',class_='gf').text.strip()
dict['ga']=tr.find('td',class_='ga').text.strip()
dict['diff text-success']=tr.find('td',class_='diff').text.strip()
# dict['diff text-success']=tr.find('td',class_='diff text-success').text.strip()

print(dict)
# Out:
# {'name': 'Los Angeles Kings', 'year': '1992', 'wins': '39', 'losses': '35', 'ot-losses': '', 'pct text-success': '0.464', 'gf': '338', 'ga': '340', 'diff text-success': '-2'}

# %%
list = []
for i in trs[1:]:
        dict={
            'name':'',
            'year':'',
            'wins':'',
            'losses':'',
            'ot-losses':'',
            'pct text-success':'',
            'gf':'',
            'ga':'',
            'diff text-success':''


        }
    # print(dict)
        dict['name']= i.find('td',class_='name').text.strip()
        dict['year']=i.find('td',class_='year').text.strip()
        dict['wins']=i.find('td',class_='wins').text.strip()
        dict['losses']=i.find('td',class_='losses').text.strip()
        dict['ot-losses']=i.find('td',class_='ot-losses').text.strip()
        # dict['pct text-success']=i.find('td',class_='pct text-success').text.strip() # 
        dict['pct text-success']=i.find('td',class_='pct').text.strip()

        dict['gf']=i.find('td',class_='gf').text.strip()
        dict['ga']=i.find('td',class_='ga').text.strip()
        # dict['diff text-success']=i.find('td',class_='diff text-success').text.strip()
        dict['diff text-success']=tr.find('td',class_='diff').text.strip()

        list.append(dict.copy())

# %%
import pandas as pd
df = pd.DataFrame(list)
df
df.to_csv('scrapethissite q3_2.csv',index=False)
df
# Out:
#                        name  year wins losses ot-losses pct text-success   gf  \
# 0         Los Angeles Kings  1992   39     35                      0.464  338
# 1     Minnesota North Stars  1992   36     38                      0.429  272
# 2        Montreal Canadiens  1992   48     30                      0.571  326
# 3         New Jersey Devils  1992   40     37                      0.476  308
# 4        New York Islanders  1992   40     37                      0.476  335
# 5          New York Rangers  1992   34     39                      0.405  304
# 6           Ottawa Senators  1992   10     70                      0.119  202
# 7       Philadelphia Flyers  1992   36     37                      0.429  319
# 8       Pittsburgh Penguins  1992   56     21                      0.667  367
# 9          Quebec Nordiques  1992   47     27                       0.56  351
# 10          San Jose Sharks  1992   11     71                      0.131  218
# ...

# %% [markdown]
# # 3.3 Extract Table of fist five pages & save into single csv file.

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://www.scrapethissite.com/pages/forms/?page_num=3')
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
var1= soup.find_all('table',class_='table')
var1
# Out:
# [<table class="table">
#  <tr>
#  <th>
#                              Team Name
#                          </th>
#  <th>
#                              Year
#                          </th>
#  <th>
#                              Wins
#                          </th>
#  <th>
#                              Losses
#                          </th>
#  <th>
#                              OT Losses
#                          </th>
#  <th>
#                              Win %
#                          </th>
#  <th>
#                              Goals For (GF)
#                          </th>
#  <th>
#                              Goals Against (GA)
#                          </th>
#  <th>
#                              + / -
#                          </th>
#  </tr>
#  <tr class="team">
#  <td class="name">
#                              Los Angeles Kings
#                          </td>
#  <td class="year">
#                              1992
#                          </td>
# ...

# %%
dict['name']= tr.find('td',class_='name').text.strip()
dict['year']=tr.find('td',class_='year').text.strip()
dict['wins']=tr.find('td',class_='wins').text.strip()
dict['losses']=tr.find('td',class_='losses').text.strip()
dict['ot-losses']=tr.find('td',class_='ot-losses').text.strip()
# dict['pct text-success']=tr.find('td',class_='pct text-success').text.strip()
dict['pct text-success']=tr.find('td',class_='pct').text.strip()

dict['gf']=tr.find('td',class_='gf').text.strip()
dict['ga']=tr.find('td',class_='ga').text.strip()
dict['diff text-success']=tr.find('td',class_='diff').text.strip()
# dict['diff text-success']=tr.find('td',class_='diff text-success').text.strip()

print(dict)
# Out:
# {'name': 'Los Angeles Kings', 'year': '1992', 'wins': '39', 'losses': '35', 'ot-losses': '', 'pct text-success': '0.464', 'gf': '338', 'ga': '340', 'diff text-success': '-2'}

# %%
list = []
for i in trs[1:]:
        dict={
            'name':'',
            'year':'',
            'wins':'',
            'losses':'',
            'ot-losses':'',
            'pct text-success':'',
            'gf':'',
            'ga':'',
            'diff text-success':''


        }
    # print(dict)
        dict['name']= i.find('td',class_='name').text.strip()
        dict['year']=i.find('td',class_='year').text.strip()
        dict['wins']=i.find('td',class_='wins').text.strip()
        dict['losses']=i.find('td',class_='losses').text.strip()
        dict['ot-losses']=i.find('td',class_='ot-losses').text.strip()
        # dict['pct text-success']=i.find('td',class_='pct text-success').text.strip() # 
        dict['pct text-success']=i.find('td',class_='pct').text.strip()

        dict['gf']=i.find('td',class_='gf').text.strip()
        dict['ga']=i.find('td',class_='ga').text.strip()
        # dict['diff text-success']=i.find('td',class_='diff text-success').text.strip()
        dict['diff text-success']=tr.find('td',class_='diff').text.strip()

        list.append(dict.copy())

# %%
import pandas as pd
df = pd.DataFrame(list)
df
df.to_csv('scrapethissite q3_3.csv',index=False)
df
# Out:
#                        name  year wins losses ot-losses pct text-success   gf  \
# 0         Los Angeles Kings  1992   39     35                      0.464  338
# 1     Minnesota North Stars  1992   36     38                      0.429  272
# 2        Montreal Canadiens  1992   48     30                      0.571  326
# 3         New Jersey Devils  1992   40     37                      0.476  308
# 4        New York Islanders  1992   40     37                      0.476  335
# 5          New York Rangers  1992   34     39                      0.405  304
# 6           Ottawa Senators  1992   10     70                      0.119  202
# 7       Philadelphia Flyers  1992   36     37                      0.429  319
# 8       Pittsburgh Penguins  1992   56     21                      0.667  367
# 9          Quebec Nordiques  1992   47     27                       0.56  351
# 10          San Jose Sharks  1992   11     71                      0.131  218
# ...

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://www.scrapethissite.com/pages/forms/?page_num=4')
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
trs = soup.find_all('table',class_='table')
trs
# Out:
# [<table class="table">
#  <tr>
#  <th>
#                              Team Name
#                          </th>
#  <th>
#                              Year
#                          </th>
#  <th>
#                              Wins
#                          </th>
#  <th>
#                              Losses
#                          </th>
#  <th>
#                              OT Losses
#                          </th>
#  <th>
#                              Win %
#                          </th>
#  <th>
#                              Goals For (GF)
#                          </th>
#  <th>
#                              Goals Against (GA)
#                          </th>
#  <th>
#                              + / -
#                          </th>
#  </tr>
#  <tr class="team">
#  <td class="name">
#                              Florida Panthers
#                          </td>
#  <td class="year">
#                              1993
#                          </td>
# ...

# %%
dict['name']= tr.find('td',class_='name').text.strip()
dict['year']=tr.find('td',class_='year').text.strip()
dict['wins']=tr.find('td',class_='wins').text.strip()
dict['losses']=tr.find('td',class_='losses').text.strip()
dict['ot-losses']=tr.find('td',class_='ot-losses').text.strip()
# dict['pct text-success']=tr.find('td',class_='pct text-success').text.strip()
dict['pct text-success']=tr.find('td',class_='pct').text.strip()

dict['gf']=tr.find('td',class_='gf').text.strip()
dict['ga']=tr.find('td',class_='ga').text.strip()
dict['diff text-success']=tr.find('td',class_='diff').text.strip()
# dict['diff text-success']=tr.find('td',class_='diff text-success').text.strip()

print(dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dict['name']= tr.find('td',class_='name').text.strip()
#       2 dict['year']=tr.find('td',class_='year').text.strip()
#       3 dict['wins']=tr.find('td',class_='wins').text.strip()
#
# NameError: name 'tr' is not defined
