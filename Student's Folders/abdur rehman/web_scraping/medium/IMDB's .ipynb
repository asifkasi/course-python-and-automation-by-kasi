# %% [markdown]
# # 2. Write a Python program to download IMDB's Top 250 data (movie name, Initial release, director name and stars).
# # movie_title, index_no, year, place, ratings, votes, link

# %%
import requests
from bs4 import BeautifulStoneSoup
url = "https://www.imdb.com/"
response = requests.get(url)
response.status_code
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\T460\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# ...
