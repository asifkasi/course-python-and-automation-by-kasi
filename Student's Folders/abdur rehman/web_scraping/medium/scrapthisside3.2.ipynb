# %% [markdown]
# ## 3.1 Extract Table of first page & save into csv file.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.scrapethissite.com/pages/forms/"
r = requests.get(url); r.raise_for_status()
soup = BeautifulSoup(r.text, "html.parser")

table = soup.find("table")


headers = [th.get_text(strip=True) for th in table.find_all("th")]
rows = []
for tr in table.find_all("tr")[1:]:
    cols = [td.get_text(strip=True) for td in tr.find_all("td")]
    if cols:
        rows.append(cols)

df = pd.DataFrame(rows, columns=headers)
df.to_csv("scrapthisside q3__1.csv", index=False, encoding="utf-8")
df
# Out:
#                 Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0           Boston Bruins  1990   44     24             0.55            299
# 1          Buffalo Sabres  1990   31     30            0.388            292
# 2          Calgary Flames  1990   46     26            0.575            344
# 3      Chicago Blackhawks  1990   49     23            0.613            284
# 4       Detroit Red Wings  1990   34     38            0.425            273
# 5         Edmonton Oilers  1990   37     37            0.463            272
# 6        Hartford Whalers  1990   31     38            0.388            238
# 7       Los Angeles Kings  1990   46     24            0.575            340
# 8   Minnesota North Stars  1990   27     39            0.338            256
# 9      Montreal Canadiens  1990   39     30            0.487            273
# 10      New Jersey Devils  1990   32     33              0.4            272
# ...

# %% [markdown]
# ## 3.2 Extract Table of second page & save into another csv file.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.scrapethissite.com/pages/forms/?page_num=2"
r = requests.get(url); r.raise_for_status()
soup = BeautifulSoup(r.text, "html.parser")

table = soup.find("table")


headers = [th.get_text(strip=True) for th in table.find_all("th")]
rows = []
for tr in table.find_all("tr")[1:]:
    cols = [td.get_text(strip=True) for td in tr.find_all("td")]
    if cols:
        rows.append(cols)

df = pd.DataFrame(rows, columns=headers)
df.to_csv("scrapthisside q3_2.csv",index=False, encoding="utf-8")
df
# Out:
#                 Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0       Detroit Red Wings  1991   43     25            0.537            320
# 1         Edmonton Oilers  1991   36     34             0.45            295
# 2        Hartford Whalers  1991   26     41            0.325            247
# 3       Los Angeles Kings  1991   35     31            0.438            287
# 4   Minnesota North Stars  1991   32     42              0.4            246
# 5      Montreal Canadiens  1991   41     28            0.512            267
# 6       New Jersey Devils  1991   38     31            0.475            289
# 7      New York Islanders  1991   34     35            0.425            291
# 8        New York Rangers  1991   50     25            0.625            321
# 9     Philadelphia Flyers  1991   32     37              0.4            252
# 10    Pittsburgh Penguins  1991   39     32            0.487            343
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.scrapethissite.com/pages/forms/?page_num=2"
r = requests.get(url); r.raise_for_status()
soup = BeautifulSoup(r.text, "html.parser")

table = soup.find("table")


headers = [th.get_text(strip=True) for th in table.find_all("th")]
rows = []
for tr in table.find_all("tr")[1:]:
    cols = [td.get_text(strip=True) for td in tr.find_all("td")]
    if cols:
        rows.append(cols)

df = pd.DataFrame(rows, columns=headers)
df.to_csv("scrapthisside q3_1.csv",mode='a+',index=False, encoding="utf-8")
df
# Out:
#                 Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0       Detroit Red Wings  1991   43     25            0.537            320
# 1         Edmonton Oilers  1991   36     34             0.45            295
# 2        Hartford Whalers  1991   26     41            0.325            247
# 3       Los Angeles Kings  1991   35     31            0.438            287
# 4   Minnesota North Stars  1991   32     42              0.4            246
# 5      Montreal Canadiens  1991   41     28            0.512            267
# 6       New Jersey Devils  1991   38     31            0.475            289
# 7      New York Islanders  1991   34     35            0.425            291
# 8        New York Rangers  1991   50     25            0.625            321
# 9     Philadelphia Flyers  1991   32     37              0.4            252
# 10    Pittsburgh Penguins  1991   39     32            0.487            343
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.scrapethissite.com/pages/forms/?page_num=3"
r = requests.get(url); r.raise_for_status()
soup = BeautifulSoup(r.text, "html.parser")

table = soup.find("table")


headers = [th.get_text(strip=True) for th in table.find_all("th")]
rows = []
for tr in table.find_all("tr")[1:]:
    cols = [td.get_text(strip=True) for td in tr.find_all("td")]
    if cols:
        rows.append(cols)

df = pd.DataFrame(rows, columns=headers)
df.to_csv("scrapthisside q3_1.csv",mode='a+', index=False, encoding="utf-8")
df
# Out:
#                   Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0         Los Angeles Kings  1992   39     35            0.464            338
# 1     Minnesota North Stars  1992   36     38            0.429            272
# 2        Montreal Canadiens  1992   48     30            0.571            326
# 3         New Jersey Devils  1992   40     37            0.476            308
# 4        New York Islanders  1992   40     37            0.476            335
# 5          New York Rangers  1992   34     39            0.405            304
# 6           Ottawa Senators  1992   10     70            0.119            202
# 7       Philadelphia Flyers  1992   36     37            0.429            319
# 8       Pittsburgh Penguins  1992   56     21            0.667            367
# 9          Quebec Nordiques  1992   47     27             0.56            351
# 10          San Jose Sharks  1992   11     71            0.131            218
# ...

# %% [markdown]
# ## 3.3 Extract Table of fist five pages & save into single csv file.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.scrapethissite.com/pages/forms/?page_num=4"
r = requests.get(url); r.raise_for_status()
soup = BeautifulSoup(r.text, "html.parser")

table = soup.find("table")


headers = [th.get_text(strip=True) for th in table.find_all("th")]
rows = []
for tr in table.find_all("tr")[1:]:
    cols = [td.get_text(strip=True) for td in tr.find_all("td")]
    if cols:
        rows.append(cols)

df = pd.DataFrame(rows, columns=headers)
df.to_csv("scrapthisside q3_1.csv",mode='a+', index=False, encoding="utf-8")
df
# Out:
#                   Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0          Florida Panthers  1993   33     34            0.393            233
# 1          Hartford Whalers  1993   27     48            0.321            227
# 2         Los Angeles Kings  1993   27     45            0.321            294
# 3        Montreal Canadiens  1993   41     29            0.488            283
# 4         New Jersey Devils  1993   47     25             0.56            306
# 5        New York Islanders  1993   36     36            0.429            282
# 6          New York Rangers  1993   52     24            0.619            299
# 7           Ottawa Senators  1993   14     61            0.167            201
# 8       Philadelphia Flyers  1993   35     39            0.417            294
# 9       Pittsburgh Penguins  1993   44     27            0.524            299
# 10         Quebec Nordiques  1993   34     42            0.405            277
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.scrapethissite.com/pages/forms/?page_num=5"
r = requests.get(url); r.raise_for_status()
soup = BeautifulSoup(r.text, "html.parser")

table = soup.find("table")


headers = [th.get_text(strip=True) for th in table.find_all("th")]
rows = []
for tr in table.find_all("tr")[1:]:
    cols = [td.get_text(strip=True) for td in tr.find_all("td")]
    if cols:
        rows.append(cols)

df = pd.DataFrame(rows, columns=headers)
df.to_csv("scrapthisside q3_1.csv",mode='a+', index=False, encoding="utf-8")
df
# Out:
#                   Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0           Edmonton Oilers  1994   17     27            0.354            136
# 1          Florida Panthers  1994   20     22            0.417            115
# 2          Hartford Whalers  1994   19     24            0.396            127
# 3         Los Angeles Kings  1994   16     23            0.333            142
# 4        Montreal Canadiens  1994   18     23            0.375            125
# 5         New Jersey Devils  1994   22     18            0.458            136
# 6        New York Islanders  1994   15     28            0.312            126
# 7          New York Rangers  1994   22     23            0.458            139
# 8           Ottawa Senators  1994    9     34            0.188            117
# 9       Philadelphia Flyers  1994   28     16            0.583            150
# 10      Pittsburgh Penguins  1994   29     16            0.604            181
# ...

# %% [markdown]
# ## 3.4 Extract Table of first page of 100 records/rows & save into another csv file.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.scrapethissite.com/pages/forms/?per_page=100"
r = requests.get(url); r.raise_for_status()
soup = BeautifulSoup(r.text, "html.parser")

table = soup.find("table")


headers = [th.get_text(strip=True) for th in table.find_all("th")]
rows = []
for tr in table.find_all("tr")[1:]:
    cols = [td.get_text(strip=True) for td in tr.find_all("td")]
    if cols:
        rows.append(cols)

df = pd.DataFrame(rows, columns=headers)
df.to_csv("scrapthisside q3_4.csv", index=False, encoding="utf-8")
df
# Out:
#              Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0        Boston Bruins  1990   44     24             0.55            299
# 1       Buffalo Sabres  1990   31     30            0.388            292
# 2       Calgary Flames  1990   46     26            0.575            344
# 3   Chicago Blackhawks  1990   49     23            0.613            284
# 4    Detroit Red Wings  1990   34     38            0.425            273
# ..                 ...   ...  ...    ...       ...    ...            ...
# 95      Buffalo Sabres  1994   22     19            0.458            130
# 96      Calgary Flames  1994   24     17              0.5            163
# 97  Chicago Blackhawks  1994   24     19              0.5            156
# 98        Dallas Stars  1994   17     23            0.354            136
# 99   Detroit Red Wings  1994   33     11            0.688            180
#
#    Goals Against (GA) + / -
# 0                 264    35
# 1                 278    14
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd 
c_url = 'https://www.scrapethissite.com/pages/forms/?per_page='

# %%
data = []
for i in range(1,6):
    url= c_url + str(i)
    r= requests.get(url)

# %% [markdown]
# ## 5.1 Extract first country details of a page & save into csv file. e.g# Andorra
# ## https://www.scrapethissite.com/pages/simple/

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://www.scrapethissite.com/pages/simple/')
response.status_code
soup =  BeautifulSoup(response.text,'html')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Countries of the World: A Simple Example | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="A single page that lists information about all the countries in the world. Good for those just get started with web scraping." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
var = soup.find('div',class_='col-md-4 country')
var
# Out:
# <div class="col-md-4 country">
# <h3 class="country-name">
# <i class="flag-icon flag-icon-ad"></i>
#                             Andorra
#                         </h3>
# <div class="country-info">
# <strong>Capital:</strong> <span class="country-capital">Andorra la Vella</span><br/>
# <strong>Population:</strong> <span class="country-population">84000</span><br/>
# <strong>Area (km<sup>2</sup>):</strong> <span class="country-area">468.0</span><br/>
# </div>
# </div>

# %%
list = []
dictionary={
        'country name':'',
        'capital':'',
        'Population':'',
        'area':'',

    }

# %%
dictionary['country name']=var.find('h3').text.strip()
dictionary['capital']=var.find('span',class_='country-capital').text
dictionary['Population']=var.find('span',class_='country-population').text
dictionary['area']=var.find('span',class_='country-area').text
print(dictionary)
list.append(dictionary)
# Out:
# {'country name': 'Andorra', 'capital': 'Andorra la Vella', 'Population': '84000', 'area': '468.0'}

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
# Out:
#   country name           capital Population   area
# 0      Andorra  Andorra la Vella      84000  468.0

# %%
df.to_csv('scrapthisside q5_1.csv',index=False)

# %% [markdown]
# ## 5.2 Extract country details of a first row of a page & save into csv file. e.g# Andorra, United Arab Emirates, Afghanistan

# %%
var = soup.find_all('div',class_='col-md-4 country')
var
# Out:
# [<div class="col-md-4 country">
#  <h3 class="country-name">
#  <i class="flag-icon flag-icon-ad"></i>
#                              Andorra
#                          </h3>
#  <div class="country-info">
#  <strong>Capital:</strong> <span class="country-capital">Andorra la Vella</span><br/>
#  <strong>Population:</strong> <span class="country-population">84000</span><br/>
#  <strong>Area (km<sup>2</sup>):</strong> <span class="country-area">468.0</span><br/>
#  </div>
#  </div>,
#  <div class="col-md-4 country">
#  <h3 class="country-name">
#  <i class="flag-icon flag-icon-ae"></i>
#                              United Arab Emirates
#                          </h3>
#  <div class="country-info">
#  <strong>Capital:</strong> <span class="country-capital">Abu Dhabi</span><br/>
#  <strong>Population:</strong> <span class="country-population">4975593</span><br/>
#  <strong>Area (km<sup>2</sup>):</strong> <span class="country-area">82880.0</span><br/>
#  </div>
#  </div>,
# ...

# %%
list = []
for vars in var[0:3]:
    dictionary={
        'country name':'',
        'capital':'',
        'Population':'',
        'area':'',

    }
    # print(dictionary)
    dictionary['country name']=vars.find('h3').text.strip()
    dictionary['capital']=vars.find('span',class_='country-capital').text
    dictionary['Population']=vars.find('span',class_='country-population').text
    dictionary['area']=vars.find('span',class_='country-area').text
    list.append(dictionary)

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
# Out:
#            country name           capital Population      area
# 0               Andorra  Andorra la Vella      84000     468.0
# 1  United Arab Emirates         Abu Dhabi    4975593   82880.0
# 2           Afghanistan             Kabul   29121286  647500.0

# %%
df.to_csv('scrapthisside q5_2.csv',index=False)

# %% [markdown]
# ## 5.3 Extract all country details of a page & save into csv file.

# %%
var = soup.find_all('div',class_='col-md-4 country')
var
# Out:
# [<div class="col-md-4 country">
#  <h3 class="country-name">
#  <i class="flag-icon flag-icon-ad"></i>
#                              Andorra
#                          </h3>
#  <div class="country-info">
#  <strong>Capital:</strong> <span class="country-capital">Andorra la Vella</span><br/>
#  <strong>Population:</strong> <span class="country-population">84000</span><br/>
#  <strong>Area (km<sup>2</sup>):</strong> <span class="country-area">468.0</span><br/>
#  </div>
#  </div>,
#  <div class="col-md-4 country">
#  <h3 class="country-name">
#  <i class="flag-icon flag-icon-ae"></i>
#                              United Arab Emirates
#                          </h3>
#  <div class="country-info">
#  <strong>Capital:</strong> <span class="country-capital">Abu Dhabi</span><br/>
#  <strong>Population:</strong> <span class="country-population">4975593</span><br/>
#  <strong>Area (km<sup>2</sup>):</strong> <span class="country-area">82880.0</span><br/>
#  </div>
#  </div>,
# ...

# %%
list = []
for vars in var[0:250]:
    dictionary={
        'country name':'',
        'capital':'',
        'Population':'',
        'area':'',

    }
    # print(dictionary)
    dictionary['country name']=vars.find('h3').text.strip()
    dictionary['capital']=vars.find('span',class_='country-capital').text
    dictionary['Population']=vars.find('span',class_='country-population').text
    dictionary['area']=vars.find('span',class_='country-area').text
    list.append(dictionary)

# %%
list
# Out:
# [{'country name': 'Andorra',
#   'capital': 'Andorra la Vella',
#   'Population': '84000',
#   'area': '468.0'},
#  {'country name': 'United Arab Emirates',
#   'capital': 'Abu Dhabi',
#   'Population': '4975593',
#   'area': '82880.0'},
#  {'country name': 'Afghanistan',
#   'capital': 'Kabul',
#   'Population': '29121286',
#   'area': '647500.0'},
#  {'country name': 'Antigua and Barbuda',
#   'capital': "St. John's",
#   'Population': '86754',
#   'area': '443.0'},
#  {'country name': 'Anguilla',
#   'capital': 'The Valley',
#   'Population': '13254',
#   'area': '102.0'},
#  {'country name': 'Albania',
#   'capital': 'Tirana',
#   'Population': '2986952',
#   'area': '28748.0'},
#  {'country name': 'Armenia',
#   'capital': 'Yerevan',
#   'Population': '2968000',
#   'area': '29800.0'},
#  {'country name': 'Angola',
#   'capital': 'Luanda',
#   'Population': '13068161',
#   'area': '1246700.0'},
#  {'country name': 'Antarctica',
#   'capital': 'None',
#   'Population': '0',
# ...

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
# Out:
#              country name           capital Population       area
# 0                 Andorra  Andorra la Vella      84000      468.0
# 1    United Arab Emirates         Abu Dhabi    4975593    82880.0
# 2             Afghanistan             Kabul   29121286   647500.0
# 3     Antigua and Barbuda        St. John's      86754      443.0
# 4                Anguilla        The Valley      13254      102.0
# ..                    ...               ...        ...        ...
# 245                 Yemen             Sanaa   23495361   527970.0
# 246               Mayotte         Mamoudzou     159042      374.0
# 247          South Africa          Pretoria   49000000  1219912.0
# 248                Zambia            Lusaka   13460305   752614.0
# 249              Zimbabwe            Harare   11651858   390580.0
#
# [250 rows x 4 columns]

# %%
df.to_csv('scrapthisside1 q5_3.csv',index=False)

# %% [markdown]
# ## 	5.4 Extract country details of a first column of a page & save into csv file.

# %%
var = soup.find_all('div',class_='col-md-4 country')
var
# Out:
# [<div class="col-md-4 country">
#  <h3 class="country-name">
#  <i class="flag-icon flag-icon-ad"></i>
#                              Andorra
#                          </h3>
#  <div class="country-info">
#  <strong>Capital:</strong> <span class="country-capital">Andorra la Vella</span><br/>
#  <strong>Population:</strong> <span class="country-population">84000</span><br/>
#  <strong>Area (km<sup>2</sup>):</strong> <span class="country-area">468.0</span><br/>
#  </div>
#  </div>,
#  <div class="col-md-4 country">
#  <h3 class="country-name">
#  <i class="flag-icon flag-icon-ae"></i>
#                              United Arab Emirates
#                          </h3>
#  <div class="country-info">
#  <strong>Capital:</strong> <span class="country-capital">Abu Dhabi</span><br/>
#  <strong>Population:</strong> <span class="country-population">4975593</span><br/>
#  <strong>Area (km<sup>2</sup>):</strong> <span class="country-area">82880.0</span><br/>
#  </div>
#  </div>,
# ...

# %%
list = []
for vars in var[0:250:3]:
    dictionary={
        'country name':'',
        'capital':'',
        'Population':'',
        'area':'',

    }
    # print(dictionary)
    dictionary['country name']=vars.find('h3').text.strip()
    dictionary['capital']=vars.find('span',class_='country-capital').text
    dictionary['Population']=vars.find('span',class_='country-population').text
    dictionary['area']=vars.find('span',class_='country-area').text
    list.append(dictionary)

# %%
list
# Out:
# [{'country name': 'Andorra',
#   'capital': 'Andorra la Vella',
#   'Population': '84000',
#   'area': '468.0'},
#  {'country name': 'Antigua and Barbuda',
#   'capital': "St. John's",
#   'Population': '86754',
#   'area': '443.0'},
#  {'country name': 'Armenia',
#   'capital': 'Yerevan',
#   'Population': '2968000',
#   'area': '29800.0'},
#  {'country name': 'Argentina',
#   'capital': 'Buenos Aires',
#   'Population': '41343201',
#   'area': '2766890.0'},
#  {'country name': 'Australia',
#   'capital': 'Canberra',
#   'Population': '21515754',
#   'area': '7686850.0'},
#  {'country name': 'Azerbaijan',
#   'capital': 'Baku',
#   'Population': '8303512',
#   'area': '86600.0'},
#  {'country name': 'Bangladesh',
#   'capital': 'Dhaka',
#   'Population': '156118464',
#   'area': '144000.0'},
#  {'country name': 'Bulgaria',
#   'capital': 'Sofia',
#   'Population': '7148785',
#   'area': '110910.0'},
#  {'country name': 'Benin',
#   'capital': 'Porto-Novo',
# ...

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('scrapthisside1 q5_4.csv',index=False)

# %% [markdown]
# ## 5.5 Extract country details of a Second column of a page & save into csv file.

# %%
var = soup.find_all('div',class_='col-md-4 country')
var
# Out:
# [<div class="col-md-4 country">
#  <h3 class="country-name">
#  <i class="flag-icon flag-icon-ad"></i>
#                              Andorra
#                          </h3>
#  <div class="country-info">
#  <strong>Capital:</strong> <span class="country-capital">Andorra la Vella</span><br/>
#  <strong>Population:</strong> <span class="country-population">84000</span><br/>
#  <strong>Area (km<sup>2</sup>):</strong> <span class="country-area">468.0</span><br/>
#  </div>
#  </div>,
#  <div class="col-md-4 country">
#  <h3 class="country-name">
#  <i class="flag-icon flag-icon-ae"></i>
#                              United Arab Emirates
#                          </h3>
#  <div class="country-info">
#  <strong>Capital:</strong> <span class="country-capital">Abu Dhabi</span><br/>
#  <strong>Population:</strong> <span class="country-population">4975593</span><br/>
#  <strong>Area (km<sup>2</sup>):</strong> <span class="country-area">82880.0</span><br/>
#  </div>
#  </div>,
# ...

# %%
list = []
for vars in var[1:250:3]:
    dictionary={
        'country name':'',
        'capital':'',
        'Population':'',
        'area':'',

    }
    # print(dictionary)
    dictionary['country name']=vars.find('h3').text.strip()
    dictionary['capital']=vars.find('span',class_='country-capital').text
    dictionary['Population']=vars.find('span',class_='country-population').text
    dictionary['area']=vars.find('span',class_='country-area').text
    list.append(dictionary)

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('scrapthisside1 q5_5.csv',index=False)

# %% [markdown]
# ## 5.6 Extract country details of a Third column of a page & save into csv file.

# %%
var = soup.find_all('div',class_='col-md-4 country')
var
# Out:
# [<div class="col-md-4 country">
#  <h3 class="country-name">
#  <i class="flag-icon flag-icon-ad"></i>
#                              Andorra
#                          </h3>
#  <div class="country-info">
#  <strong>Capital:</strong> <span class="country-capital">Andorra la Vella</span><br/>
#  <strong>Population:</strong> <span class="country-population">84000</span><br/>
#  <strong>Area (km<sup>2</sup>):</strong> <span class="country-area">468.0</span><br/>
#  </div>
#  </div>,
#  <div class="col-md-4 country">
#  <h3 class="country-name">
#  <i class="flag-icon flag-icon-ae"></i>
#                              United Arab Emirates
#                          </h3>
#  <div class="country-info">
#  <strong>Capital:</strong> <span class="country-capital">Abu Dhabi</span><br/>
#  <strong>Population:</strong> <span class="country-population">4975593</span><br/>
#  <strong>Area (km<sup>2</sup>):</strong> <span class="country-area">82880.0</span><br/>
#  </div>
#  </div>,
# ...

# %%
list = []
for vars in var[2:250:3]:
    dictionary={
        'country name':'',
        'capital':'',
        'Population':'',
        'area':'',

    }
    # print(dictionary)
    dictionary['country name']=vars.find('h3').text.strip()
    dictionary['capital']=vars.find('span',class_='country-capital').text
    dictionary['Population']=vars.find('span',class_='country-population').text
    dictionary['area']=vars.find('span',class_='country-area').text
    list.append(dictionary)

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('scrapthisside1 q5_6.csv',index=False)
