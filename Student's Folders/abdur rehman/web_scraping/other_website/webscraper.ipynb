# %% [markdown]
# ##	1.1 extract first product of a page. (product_name,product_index,product_desc,product_url,img_url)
#
# ##  1 https://webscraper.io/test-sites

# %%
import requests
from bs4 import BeautifulSoup

respose = requests.get("https://webscraper.io/test-sites")
respose.status_code
soup = BeautifulSoup (respose.text,('html.parser'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Google Tag Manager -->
#   <script nonce="2ch1dDVxKD3FUIMBGonJyquN6vi423Fl">
#    (function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <title>
#    Test Sites | Web Scraper
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords">
# ...

# %%
link = soup.find_all('a')
# link
for l in link:
    print(l,['href'])
# Out:
# <a data-bs-target=".side-collapse" data-bs-target-2=".side-collapse-container" data-bs-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggler float-end collapsed" data-bs-target="#navbar" data-bs-target-2=".side-collapse-container" data-bs-target-3=".side-collapse" data-bs-toggle="collapse" type="button">
# <span class="visually-hidden">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# <span class="icon-bar extra-bottom-bar"></span>
# </button>
# </a> ['href']
# <a href="/"><img alt="Web Scraper" height="50px" src="/img/logo_white.svg" width="150px"/></a> ['href']
# <a class="nav-link menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a> ['href']
# <a class="nav-link menuitm" href="/cloud-scraper" id="cloud-nav-link">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a> ['href']
# ...

# %%
header = soup.find_all(['h1','h2','h3','h4','h5','h6','h7'])
header
# Out:
# [<h1>Test Sites</h1>,
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/allinone">
#  						E-commerce site
#  					</a>
#  </h2>,
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/static">
#  						E-commerce site with pagination links
#  					</a>
#  </h2>,
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/ajax">
#  						E-commerce site with AJAX pagination links
#  					</a>
#  </h2>,
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/more">
#  						E-commerce site with "Load more" buttons
#  					</a>
#  </h2>,
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/scroll">
#  						E-commerce site that loads items while scrolling
#  					</a>
#  </h2>,
#  <h2 class="site-heading">
#  <a href="/test-sites/tables">Table playground
#  					</a>
#  </h2>]

# %%
products = {
     'product name': '',
     'product description': '',
     'product-link': '',
     'image url': ''

}
products
# Out:
# {'product name': '',
#  'product description': '',
#  'product-link': '',
#  'image url': ''}

# %%
products['product name'] = soup.find('h2').text.strip()

# %%
div = soup.find("div",class_="row test-site")

# %%
products['product name'] = div.find('h2').text.strip()
products['product description'] = div.find('p').text.strip().replace('\n',' ').replace('\t','')

products['product-link'] = div.find('a')['href']
products['image url'] = div.find('img')['src']
products
# Out:
# {'product name': 'E-commerce site',
#  'product description': 'E-commerce site with multiple categories, subcategories. All items are loaded in one page.',
#  'product-link': '/test-sites/e-commerce/allinone',
#  'image url': '/images/test-sites/screens/test-sites-ecommerce-allinone.png'}

# %%
import pandas as pd
list =[]
products = {
     'product name': '',
     'product description': '',
     'product-link': '',
     'image url': ''

}
products['product name'] = div.find('h2').text.strip()
products['product description'] = div.find('p').text.strip().replace('\n',' ').replace('\t','')

products['product-link'] = div.find('a')['href']
products['image url'] = div.find('img')['src']
products
list.append(products)
# df = pd.DataFrame(products)
# df
# df.to_csv('webscraper.csv',index=False)
df = pd.DataFrame(list)
df
df.to_csv('webscraper.csv',index=False)

# %% [markdown]
# # 	1.2 extract first product of a page. (product_name,product_index,product_desc,product_url,img_url)

# %%
import requests
from bs4 import BeautifulSoup
respose = requests.get("https://webscraper.io/test-sites")
respose.status_code
soup = BeautifulSoup (respose.text,('html.parser'))

# %%
products = {
     'product name': '',
     'product description': '',
     'product-link': '',
     'image url': ''

}
print(products)
# Out:
# {'product name': '', 'product description': '', 'product-link': '', 'image url': ''}

# %%
var2 = soup.find_all("div",class_="row test-site")
type(var2)
# Out:
# bs4.element.ResultSet

# %%
var2[1]
# Out:
# <div class="row test-site">
# <div class="col-lg-7 order-lg-2">
# <h2 class="site-heading">
# <a href="/test-sites/e-commerce/static">
# 						E-commerce site with pagination links
# 					</a>
# </h2>
# <p class="lead">
# 					E-commerce site with multiple categories, subcategories.
# 					Standard links are used for pagination.
# 				</p>
# </div>
# <div class="col-lg-5 order-lg-1">
# <img alt="E-commerce site" src="/images/test-sites/screens/test-sites-ecommerce-static.png"/>
# </div>
# </div>

# %%
var2[1].find('h2').text.strip()

var2[1].find('p').text.strip().replace('\n',' ').replace('\t','')
var2[1].find('img')['src']
var2[1].find('a')['href']
var2
# Out:
# [<div class="row test-site">
#  <div class="col-lg-7 order-lg-2">
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/allinone">
#  						E-commerce site
#  					</a>
#  </h2>
#  <p class="lead">
#  					E-commerce site with multiple categories, subcategories.
#  					All items are loaded in one page.
#  				</p>
#  </div>
#  <div class="col-lg-5 order-lg-1">
#  <img alt="E-commerce site" src="/images/test-sites/screens/test-sites-ecommerce-allinone.png"/>
#  </div>
#  </div>,
#  <div class="row test-site">
#  <div class="col-lg-7 order-lg-2">
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/static">
#  						E-commerce site with pagination links
#  					</a>
#  </h2>
#  <p class="lead">
#  					E-commerce site with multiple categories, subcategories.
#  					Standard links are used for pagination.
#  				</p>
#  </div>
#  <div class="col-lg-5 order-lg-1">
#  <img alt="E-commerce site" src="/images/test-sites/screens/test-sites-ecommerce-static.png"/>
# ...

# %%
import pandas as pd
list =[]

products['product name'] = var2[1].find('h2').text.strip()
products['product description'] = var2[1].find('p').text.strip().replace('\n',' ').replace('\t','')
products['product-link'] = var2[1].find('a')['href']
products['image url'] = var2[1].find('img')['src']
# var1
list.append(products)

df = pd.DataFrame(list)
df
df.to_csv('webscraper.csv',mode='a+',index=False)

# %% [markdown]
# # 	1.1  all extract first product of a page. (product_name,product_index,product_desc,product_url,img_url)

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://webscraper.io/test-sites'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
data_list = []  

var_all = soup.find_all("div", class_="row test-site")
for div in var_all:
    var_dec = {
         'product name': '',
         'product description': '',
         'product-link': '',
         'image url': ''
    }
    var_dec['product name'] = div.find('h2').text.strip()
    var_dec['product description'] = div.find('p').text.strip().replace('\n',' ').replace('\t','')
    var_dec['product-link'] = div.find('a')['href']
    var_dec['image url'] = div.find('img')['src']
    data_list.append(var_dec)
df = pd.DataFrame(data_list)
df
# Out:
#                                        product name  \
# 0                                   E-commerce site
# 1             E-commerce site with pagination links
# 2        E-commerce site with AJAX pagination links
# 3          E-commerce site with "Load more" buttons
# 4  E-commerce site that loads items while scrolling
# 5                                  Table playground
#
#                                  product description  \
# 0  E-commerce site with multiple categories, subc...
# 1  E-commerce site with multiple categories, subc...
# 2  E-commerce site with multiple categories, subc...
# 3  E-commerce site with multiple categories, subc...
# 4  E-commerce site with multiple categories, subc...
# 5  This page contains multiple tables. You can tr...
#
#                       product-link  \
# 0  /test-sites/e-commerce/allinone
# 1    /test-sites/e-commerce/static
# 2      /test-sites/e-commerce/ajax
# 3      /test-sites/e-commerce/more
# 4    /test-sites/e-commerce/scroll
# ...

# %%
import pandas as pd

df = pd.DataFrame(data_list)
df.to_csv('webscraper.csv',mode='a+',index=False)

# %% [markdown]
# # 4.1 Extract first Table of a page & save into csv file.
# # https://webscraper.io/test-sites/tables

# %%
import requests 
from bs4 import BeautifulSoup
response = requests.get('https://webscraper.io/test-sites/tables')
response.status_code
soup = BeautifulSoup(response.text,('html.parser'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Google Tag Manager -->
#   <script nonce="zbKBiZamIF0pOgQl4g2EnKTE9TNQRSLV">
#    (function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <title>
#    Table Playground | Web Scraper Test Sites
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords">
# ...

# %%
var = soup.find_all('table','table table-bordered')
var
# Out:
# [<table class="table table-bordered">
#  <thead>
#  <tr>
#  <th>#</th>
#  <th>First Name</th>
#  <th>Last Name</th>
#  <th>Username</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>1</td>
#  <td>Mark</td>
#  <td>Otto</td>
#  <td>@mdo</td>
#  </tr>
#  <tr>
#  <td>2</td>
#  <td>Jacob</td>
#  <td>Thornton</td>
#  <td>@fat</td>
#  </tr>
#  <tr>
#  <td>3</td>
#  <td>Larry</td>
#  <td>the Bird</td>
#  <td>@twitter</td>
#  </tr>
#  </tbody>
#  </table>]

# %%
row = var[0].find_all('tr')[1]
cells = row.find_all('td')

number = cells[0].text.strip()      # '1'
first_name = cells[1].text.strip()  # 'Mark'
last_name = cells[2].text.strip()   # 'Otto'
username = cells[3].text.strip()    # '@mdo'

print(f"{number} {first_name} {last_name} {username}")
# Out:
# 1 Mark Otto @mdo

# %%
from bs4 import BeautifulSoup

# row = var[0].find_all('tr')[1]   # tumhara row object
row = var[0].find_all('tr')[1]

# agar table cells <td> mein hain:
cols = [td.get_text(strip=True) for td in row.find_all('td')]
print(cols)   # e.g. ['1', 'Mark Otto', '@mdo']

rank = cols[0]
name = cols[1]
handle = cols[2].lstrip('@')   # agar @ hataana ho
print(rank, name, handle)
# Out:
# ['1', 'Mark', 'Otto', '@mdo']
# 1 Mark Otto

# %%
row = var[0].find_all('th')[1].text
row = var[0].find_all('th')[2].text
row = var[0].find_all('th')[3].text
row
# Out:
# 'Username'

# %%
row = var[0].find_all('th')[2].text
row
# Out:
# 'Last Name'

# %%
dict ['index']= row = var[0].find_all('tr')[0].text.strip().replace('\n',' ')
dict ['frist name']=row = var[0].find_all('tr')[1].text.strip().replace('\n',' ')
dict ['last name']=row = var[0].find_all('tr')[2].text.strip().replace('\n',' ')
dict ['user name']=row = var[0].find_all('tr')[3].text.strip().replace('\n',' ')

print(dict)
# Out:
# {'index': '# First Name Last Name Username', 'frist name': '1 Mark Otto @mdo', 'last name': '2 Jacob Thornton @fat', 'user name': '3 Larry the Bird @twitter'}

# %%
row = var[0].find_all('th')[3].text
row
# Out:
# 'Username'

# %%
rows = table.find_all('tr')

# %%
# Extract data
data = []
for row in rows[0:4]:  # Skip header row
    cells = row.find_all('td')
    dict={
    'index':'',
    'frist name':'',
    'last name':'',
    'user name':'',
    }
    if cells:
        row_data = [cell.text.strip() for cell in cells]
        data.append(row_data)

# %%
import pandas as pd 

df = pd.DataFrame(data)
df
df.to_csv('table q4_1.csv',index=False)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dict={
    'index':'',
    'name':'',
    'last name':'',
    'user name':'',
}

# %%
table=soup.find_all('table',class_='table table-bordered table-bordered2')
table
# Out:
# [<table class="table table-bordered table-bordered2">
#  <thead>
#  <tr>
#  <th>#</th>
#  <th>First Name</th>
#  <th>Last Name</th>
#  <th>Username</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>4</td>
#  <td>Harry</td>
#  <td>Potter</td>
#  <td>@hp</td>
#  </tr>
#  <tr>
#  <td>5</td>
#  <td>John</td>
#  <td>Snow</td>
#  <td>@dunno</td>
#  </tr>
#  <tr>
#  <td>6</td>
#  <td>Tim</td>
#  <td>Bean</td>
#  <td>@timbean</td>
#  </tr>
#  </tbody>
#  </table>]

# %%
data = []
for row in rows[0:4]:  # Skip header row
    table = row.find_all('tr')
    dict={
    'index':'',
    'name':'',
    'last name':'',
    'user name':'',
    }
    if table:
        row_data = [cell.text.strip() for cell in table]
        data.append(row_data)

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []
