# %% [markdown]
# ##	1.1 extract first product of a page. (product_name,product_index,product_desc,product_url,img_url)
#
# ##  1 https://webscraper.io/test-sites

# %%
import requests
from bs4 import BeautifulSoup

respose = requests.get("https://webscraper.io/test-sites")
respose.status_code
soup = BeautifulSoup (respose.text,('html.parser'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Google Tag Manager -->
#   <script nonce="2ch1dDVxKD3FUIMBGonJyquN6vi423Fl">
#    (function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <title>
#    Test Sites | Web Scraper
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords">
# ...

# %%
link = soup.find_all('a')
# link
for l in link:
    print(l,['href'])
# Out:
# <a data-bs-target=".side-collapse" data-bs-target-2=".side-collapse-container" data-bs-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggler float-end collapsed" data-bs-target="#navbar" data-bs-target-2=".side-collapse-container" data-bs-target-3=".side-collapse" data-bs-toggle="collapse" type="button">
# <span class="visually-hidden">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# <span class="icon-bar extra-bottom-bar"></span>
# </button>
# </a> ['href']
# <a href="/"><img alt="Web Scraper" height="50px" src="/img/logo_white.svg" width="150px"/></a> ['href']
# <a class="nav-link menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a> ['href']
# <a class="nav-link menuitm" href="/cloud-scraper" id="cloud-nav-link">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a> ['href']
# ...

# %%
header = soup.find_all(['h1','h2','h3','h4','h5','h6','h7'])
header
# Out:
# [<h1>Test Sites</h1>,
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/allinone">
#  						E-commerce site
#  					</a>
#  </h2>,
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/static">
#  						E-commerce site with pagination links
#  					</a>
#  </h2>,
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/ajax">
#  						E-commerce site with AJAX pagination links
#  					</a>
#  </h2>,
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/more">
#  						E-commerce site with "Load more" buttons
#  					</a>
#  </h2>,
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/scroll">
#  						E-commerce site that loads items while scrolling
#  					</a>
#  </h2>,
#  <h2 class="site-heading">
#  <a href="/test-sites/tables">Table playground
#  					</a>
#  </h2>]

# %%
products = {
     'product name': '',
     'product description': '',
     'product-link': '',
     'image url': ''

}
products
# Out:
# {'product name': '',
#  'product description': '',
#  'product-link': '',
#  'image url': ''}

# %%
products['product name'] = soup.find('h2').text.strip()

# %%
div = soup.find("div",class_="row test-site")

# %%
products['product name'] = div.find('h2').text.strip()
products['product description'] = div.find('p').text.strip().replace('\n',' ').replace('\t','')

products['product-link'] = div.find('a')['href']
products['image url'] = div.find('img')['src']
products
# Out:
# {'product name': 'E-commerce site',
#  'product description': 'E-commerce site with multiple categories, subcategories. All items are loaded in one page.',
#  'product-link': '/test-sites/e-commerce/allinone',
#  'image url': '/images/test-sites/screens/test-sites-ecommerce-allinone.png'}

# %%
import pandas as pd
list =[]
products = {
     'product name': '',
     'product description': '',
     'product-link': '',
     'image url': ''

}
products['product name'] = div.find('h2').text.strip()
products['product description'] = div.find('p').text.strip().replace('\n',' ').replace('\t','')

products['product-link'] = div.find('a')['href']
products['image url'] = div.find('img')['src']
products
list.append(products)
# df = pd.DataFrame(products)
# df
# df.to_csv('webscraper.csv',index=False)
df = pd.DataFrame(list)
df
df.to_csv('webscraper.csv',index=False)

# %% [markdown]
# # 	1.2 extract first product of a page. (product_name,product_index,product_desc,product_url,img_url)

# %%
import requests
from bs4 import BeautifulSoup
respose = requests.get("https://webscraper.io/test-sites")
respose.status_code
soup = BeautifulSoup (respose.text,('html.parser'))

# %%
products = {
     'product name': '',
     'product description': '',
     'product-link': '',
     'image url': ''

}
print(products)
# Out:
# {'product name': '', 'product description': '', 'product-link': '', 'image url': ''}

# %%
var2 = soup.find_all("div",class_="row test-site")
type(var2)
# Out:
# bs4.element.ResultSet

# %%
var2[1]
# Out:
# <div class="row test-site">
# <div class="col-lg-7 order-lg-2">
# <h2 class="site-heading">
# <a href="/test-sites/e-commerce/static">
# 						E-commerce site with pagination links
# 					</a>
# </h2>
# <p class="lead">
# 					E-commerce site with multiple categories, subcategories.
# 					Standard links are used for pagination.
# 				</p>
# </div>
# <div class="col-lg-5 order-lg-1">
# <img alt="E-commerce site" src="/images/test-sites/screens/test-sites-ecommerce-static.png"/>
# </div>
# </div>

# %%
var2[1].find('h2').text.strip()

var2[1].find('p').text.strip().replace('\n',' ').replace('\t','')
var2[1].find('img')['src']
var2[1].find('a')['href']
var2
# Out:
# [<div class="row test-site">
#  <div class="col-lg-7 order-lg-2">
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/allinone">
#  						E-commerce site
#  					</a>
#  </h2>
#  <p class="lead">
#  					E-commerce site with multiple categories, subcategories.
#  					All items are loaded in one page.
#  				</p>
#  </div>
#  <div class="col-lg-5 order-lg-1">
#  <img alt="E-commerce site" src="/images/test-sites/screens/test-sites-ecommerce-allinone.png"/>
#  </div>
#  </div>,
#  <div class="row test-site">
#  <div class="col-lg-7 order-lg-2">
#  <h2 class="site-heading">
#  <a href="/test-sites/e-commerce/static">
#  						E-commerce site with pagination links
#  					</a>
#  </h2>
#  <p class="lead">
#  					E-commerce site with multiple categories, subcategories.
#  					Standard links are used for pagination.
#  				</p>
#  </div>
#  <div class="col-lg-5 order-lg-1">
#  <img alt="E-commerce site" src="/images/test-sites/screens/test-sites-ecommerce-static.png"/>
# ...

# %%
import pandas as pd
list =[]

products['product name'] = var2[1].find('h2').text.strip()
products['product description'] = var2[1].find('p').text.strip().replace('\n',' ').replace('\t','')
products['product-link'] = var2[1].find('a')['href']
products['image url'] = var2[1].find('img')['src']
# var1
list.append(products)

df = pd.DataFrame(list)
df
df.to_csv('webscraper.csv',mode='a+',index=False)

# %% [markdown]
# # 	1.1  all extract first product of a page. (product_name,product_index,product_desc,product_url,img_url)

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://webscraper.io/test-sites'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
data_list = []  

var_all = soup.find_all("div", class_="row test-site")
for div in var_all:
    var_dec = {
         'product name': '',
         'product description': '',
         'product-link': '',
         'image url': ''
    }
    var_dec['product name'] = div.find('h2').text.strip()
    var_dec['product description'] = div.find('p').text.strip().replace('\n',' ').replace('\t','')
    var_dec['product-link'] = div.find('a')['href']
    var_dec['image url'] = div.find('img')['src']
    data_list.append(var_dec)
df = pd.DataFrame(data_list)
df
# Out:
#                                        product name  \
# 0                                   E-commerce site
# 1             E-commerce site with pagination links
# 2        E-commerce site with AJAX pagination links
# 3          E-commerce site with "Load more" buttons
# 4  E-commerce site that loads items while scrolling
# 5                                  Table playground
#
#                                  product description  \
# 0  E-commerce site with multiple categories, subc...
# 1  E-commerce site with multiple categories, subc...
# 2  E-commerce site with multiple categories, subc...
# 3  E-commerce site with multiple categories, subc...
# 4  E-commerce site with multiple categories, subc...
# 5  This page contains multiple tables. You can tr...
#
#                       product-link  \
# 0  /test-sites/e-commerce/allinone
# 1    /test-sites/e-commerce/static
# 2      /test-sites/e-commerce/ajax
# 3      /test-sites/e-commerce/more
# 4    /test-sites/e-commerce/scroll
# ...

# %%
import pandas as pd

df = pd.DataFrame(data_list)
df.to_csv('webscraper.csv',mode='a+',index=False)

# %% [markdown]
# # 4.1 Extract first Table of a page & save into csv file.
# # https://webscraper.io/test-sites/tables

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://webscraper.io/test-sites/tables"
resp = requests.get(url)
soup = BeautifulSoup(resp.text, "html.parser")

table = soup.find("table")

headers = [th.get_text(strip=True) for th in table.find_all("th")]
print("Headers:", headers)
row= []

for tr in table.find_all("tr")[1:]:
    cells = [td.get_text(strip=True) for td in tr.find_all(["td","th"])]
    print(cells)
    row.append(cells)
    
df = pd.DataFrame(row)
df.to_csv("webscraper q4_1.csv", index=False, encoding="utf-8")
df
# Out:
# Headers: ['#', 'First Name', 'Last Name', 'Username']
# ['1', 'Mark', 'Otto', '@mdo']
# ['2', 'Jacob', 'Thornton', '@fat']
# ['3', 'Larry', 'the Bird', '@twitter']
#    0      1         2         3
# 0  1   Mark      Otto      @mdo
# 1  2  Jacob  Thornton      @fat
# 2  3  Larry  the Bird  @twitter

# %%
import requests 
from bs4 import BeautifulSoup
response = requests.get('https://webscraper.io/test-sites/tables')
response.status_code
soup = BeautifulSoup(response.text,('html.parser'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Google Tag Manager -->
#   <script nonce="zbKBiZamIF0pOgQl4g2EnKTE9TNQRSLV">
#    (function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <title>
#    Table Playground | Web Scraper Test Sites
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords">
# ...

# %%
var = soup.find_all('table','table table-bordered')
var
# Out:
# [<table class="table table-bordered">
#  <thead>
#  <tr>
#  <th>#</th>
#  <th>First Name</th>
#  <th>Last Name</th>
#  <th>Username</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>1</td>
#  <td>Mark</td>
#  <td>Otto</td>
#  <td>@mdo</td>
#  </tr>
#  <tr>
#  <td>2</td>
#  <td>Jacob</td>
#  <td>Thornton</td>
#  <td>@fat</td>
#  </tr>
#  <tr>
#  <td>3</td>
#  <td>Larry</td>
#  <td>the Bird</td>
#  <td>@twitter</td>
#  </tr>
#  </tbody>
#  </table>]

# %%
row = var[0].find_all('tr')[1]
cells = row.find_all('td')

number = cells[0].text.strip()      # '1'
first_name = cells[1].text.strip()  # 'Mark'
last_name = cells[2].text.strip()   # 'Otto'
username = cells[3].text.strip()    # '@mdo'

print(f"{number} {first_name} {last_name} {username}")
# Out:
# 1 Mark Otto @mdo

# %%
from bs4 import BeautifulSoup

# row = var[0].find_all('tr')[1]   # tumhara row object
row = var[0].find_all('tr')[1]

# agar table cells <td> mein hain:
cols = [td.get_text(strip=True) for td in row.find_all('td')]
print(cols)   # e.g. ['1', 'Mark Otto', '@mdo']

rank = cols[0]
name = cols[1]
handle = cols[2].lstrip('@')   # agar @ hataana ho
print(rank, name, handle)
# Out:
# ['1', 'Mark', 'Otto', '@mdo']
# 1 Mark Otto

# %%
row = var[0].find_all('th')[1].text
row = var[0].find_all('th')[2].text
row = var[0].find_all('th')[3].text
row
# Out:
# 'Username'

# %%
row = var[0].find_all('th')[2].text
row
# Out:
# 'Last Name'

# %%
dict ['index']= row = var[0].find_all('tr')[0].text.strip().replace('\n',' ')
dict ['frist name']=row = var[0].find_all('tr')[1].text.strip().replace('\n',' ')
dict ['last name']=row = var[0].find_all('tr')[2].text.strip().replace('\n',' ')
dict ['user name']=row = var[0].find_all('tr')[3].text.strip().replace('\n',' ')

print(dict)
# Out:
# {'index': '# First Name Last Name Username', 'frist name': '1 Mark Otto @mdo', 'last name': '2 Jacob Thornton @fat', 'user name': '3 Larry the Bird @twitter'}

# %%
row = var[0].find_all('th')[3].text
row
# Out:
# 'Username'

# %%
rows = table.find_all('tr')

# %%
# Extract data
data = []
for row in rows[0:4]:  # Skip header row
    cells = row.find_all('td')
    dict={
    'index':'',
    'frist name':'',
    'last name':'',
    'user name':'',
    }
    if cells:
        row_data = [cell.text.strip() for cell in cells]
        data.append(row_data)

# %%
import pandas as pd 

df = pd.DataFrame(data)
df
df.to_csv('table q4_1.csv',index=False)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dict={
    'index':'',
    'name':'',
    'last name':'',
    'user name':'',
}

# %%
table=soup.find_all('table',class_='table table-bordered table-bordered2')
table
# Out:
# [<table class="table table-bordered table-bordered2">
#  <thead>
#  <tr>
#  <th>#</th>
#  <th>First Name</th>
#  <th>Last Name</th>
#  <th>Username</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>4</td>
#  <td>Harry</td>
#  <td>Potter</td>
#  <td>@hp</td>
#  </tr>
#  <tr>
#  <td>5</td>
#  <td>John</td>
#  <td>Snow</td>
#  <td>@dunno</td>
#  </tr>
#  <tr>
#  <td>6</td>
#  <td>Tim</td>
#  <td>Bean</td>
#  <td>@timbean</td>
#  </tr>
#  </tbody>
#  </table>]

# %%
data = []
for row in rows[0:4]:  # Skip header row
    table = row.find_all('tr')
    dict={
    'index':'',
    'name':'',
    'last name':'',
    'user name':'',
    }
    if table:
        row_data = [cell.text.strip() for cell in table]
        data.append(row_data)

# %% [markdown]
# ## 6.1 Extract first product details save into csv file. e.g# Asus VivoBook...
# ## https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops')
response.status_code
soup = BeautifulSoup(response.text,('html'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Google Tag Manager -->
#   <script nonce="20Uu5iaai4c5tIT44tE3kPKNoVML6zr1">
#    (function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <title>
#    Allinone | Web Scraper Test Sites
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# ...

# %%
product = soup.find('div',class_='product-wrapper card-body')
product
# Out:
# <div class="product-wrapper card-body">
# <img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="price float-end card-title pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
# <span itemprop="price">$295.99</span>
# <meta content="USD" itemprop="priceCurrency"/>
# </h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/60" itemprop="name" title="Asus VivoBook X441NA-GA190">
# 						Asus VivoBook...
# 					</a>
# </h4>
# <p class="description card-text" itemprop="description">Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd</p>
# </div>
# <div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating">
# <p class="review-count float-end">
# <span itemprop="reviewCount">14</span> reviews
# 				</p>
# <p data-rating="3">
# ...

# %%
list = []
prod_dictionary = {
    'product_name': '',
    'product_link': '',
    'product_img': '',
    'product_price': '',
    'product_details': '',
    'product_reviews_number': '',
    'product_reviews_star_number': '',
}

# %%
prod_dictionary['product_name']= product.find('a').text.strip()
prod_dictionary['product_details']=product.find('p').text
prod_dictionary['product_img']=product.find('img')['src']
prod_dictionary['product_link']=product.find('a')['href']
prod_dictionary['product_reviews_number']=product.find('div',class_='ratings').text.strip()
prod_dictionary['product_reviews_star_number']
prod_dictionary['product_price']=product.find('h4').text.strip()
list.append(prod_dictionary)

# %%
prod_dictionary
# Out:
# {'product_name': 'Asus VivoBook...',
#  'product_link': '/test-sites/e-commerce/allinone/product/60',
#  'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#  'product_price': '$295.99',
#  'product_details': 'Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd',
#  'product_reviews_number': '14 reviews',
#  'product_reviews_star_number': ''}

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q6_1.csv',index=False)

# %%
len(product)
# Out:
# 5

# %% [markdown]
# ## 6.2 Extract product details from first row & save into csv file. e.g# Asus VivoBook..., Prestigio Smar...,Prestigio Smar...

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops')
response.status_code
soup = BeautifulSoup(response.text,('html'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Google Tag Manager -->
#   <script nonce="sRLmsOcgqwQoEH6FB3yWUCVlw9IZ1hTM">
#    (function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <title>
#    Allinone | Web Scraper Test Sites
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# ...

# %%
products = soup.find_all('div',class_='row')
products
# Out:
# [<div class="row">
#  <div class="col-lg-12">
#  <h1>Test Sites</h1>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-lg-3 sidebar">
#  <div class="navbar-light sidebar" role="navigation">
#  <div class="sidebar-nav navbar-collapse">
#  <ul class="nav flex-column" id="side-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
#  <li class="nav-item">
#  <a class="nav-link" href="/test-sites/e-commerce/allinone" itemprop="url"><span itemprop="name">Home</span></a>
#  </li>
#  <li class="nav-item active">
#  <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/allinone/computers" itemprop="url">
#  <span itemprop="name">Computers</span>
#  <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
#  </a>
#  <ul class="nav nav-second-level" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
#  <li class="nav-item">
# ...

# %%
len(products)
# Out:
# 5

# %%
len(prod_dictionary)
# Out:
# 7

# %%
main_div = products[2]

all_products = main_div.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")
len(all_products)
# Out:
# 117

# %%
products = soup.find_all('div',class_='row')
len(products)
# Out:
# 5

# %%
list = []
for i in all_products[0:3]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
    }
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q6_2.csv',index=False)
df
# Out:
#          product_name                                 product_link  \
# 0   Prestigio Smar...   /test-sites/e-commerce/allinone/product/62
# 1   Lenovo V110-15...   /test-sites/e-commerce/allinone/product/64
# 2   Acer Aspire A3...   /test-sites/e-commerce/allinone/product/67
# 3    Acer Aspire 3...   /test-sites/e-commerce/allinone/product/70
# 4   Lenovo ThinkPa...   /test-sites/e-commerce/allinone/product/72
# 5   Acer Aspire ES...   /test-sites/e-commerce/allinone/product/75
# 6   Asus EeeBook R...   /test-sites/e-commerce/allinone/product/77
# 7   Acer Extensa 1...   /test-sites/e-commerce/allinone/product/80
# 8   Acer Aspire A3...   /test-sites/e-commerce/allinone/product/83
# 9   Acer Aspire ES...   /test-sites/e-commerce/allinone/product/86
# 10  Lenovo V510 Bl...   /test-sites/e-commerce/allinone/product/89
# 11   Acer Aspire 3...   /test-sites/e-commerce/allinone/product/91
# 12          HP 250 G3   /test-sites/e-commerce/allinone/product/42
# ...

# %% [markdown]
# ## 6.3 Extract all product details from page & save into csv file.

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops')
response.status_code
soup = BeautifulSoup(response.text,('html'))
print(soup.prettify())

# %%
all_products = main_div.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")
all_products
# len(all_products)
# Out:
# [<div class="col-md-4 col-xl-4 col-lg-4">
#  <div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product">
#  <div class="product-wrapper card-body">
#  <img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="price float-end card-title pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
#  <span itemprop="price">$295.99</span>
#  <meta content="USD" itemprop="priceCurrency"/>
#  </h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/60" itemprop="name" title="Asus VivoBook X441NA-GA190">
#  						Asus VivoBook...
#  					</a>
#  </h4>
#  <p class="description card-text" itemprop="description">Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd</p>
#  </div>
# ...

# %%
list = []
for i in all_products[0:117]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
    }
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q6_3.csv',index=False)
df
# Out:
#          product_name                                 product_link  \
# 0   Prestigio Smar...   /test-sites/e-commerce/allinone/product/62
# 1   Lenovo V110-15...   /test-sites/e-commerce/allinone/product/64
# 2   Acer Aspire A3...   /test-sites/e-commerce/allinone/product/67
# 3    Acer Aspire 3...   /test-sites/e-commerce/allinone/product/70
# 4   Lenovo ThinkPa...   /test-sites/e-commerce/allinone/product/72
# 5   Acer Aspire ES...   /test-sites/e-commerce/allinone/product/75
# 6   Asus EeeBook R...   /test-sites/e-commerce/allinone/product/77
# 7   Acer Extensa 1...   /test-sites/e-commerce/allinone/product/80
# 8   Acer Aspire A3...   /test-sites/e-commerce/allinone/product/83
# 9   Acer Aspire ES...   /test-sites/e-commerce/allinone/product/86
# 10  Lenovo V510 Bl...   /test-sites/e-commerce/allinone/product/89
# 11   Acer Aspire 3...   /test-sites/e-commerce/allinone/product/91
# 12          HP 250 G3   /test-sites/e-commerce/allinone/product/42
# ...

# %% [markdown]
# ## 6.4 Extract all product details of first column save into csv file.

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops')
response.status_code
soup = BeautifulSoup(response.text,('html'))
print(soup.prettify())

# %%
all_products = main_div.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")
all_products
# Out:
# [<div class="col-md-4 col-xl-4 col-lg-4">
#  <div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product">
#  <div class="product-wrapper card-body">
#  <img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="price float-end card-title pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
#  <span itemprop="price">$295.99</span>
#  <meta content="USD" itemprop="priceCurrency"/>
#  </h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/60" itemprop="name" title="Asus VivoBook X441NA-GA190">
#  						Asus VivoBook...
#  					</a>
#  </h4>
#  <p class="description card-text" itemprop="description">Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd</p>
#  </div>
# ...

# %%
list = []
for i in all_products[0:117:3]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
    }
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q6_4.csv',index=False)
df
# Out:
#          product_name                                 product_link  \
# 0   Prestigio Smar...   /test-sites/e-commerce/allinone/product/62
# 1   Lenovo V110-15...   /test-sites/e-commerce/allinone/product/64
# 2   Acer Aspire A3...   /test-sites/e-commerce/allinone/product/67
# 3    Acer Aspire 3...   /test-sites/e-commerce/allinone/product/70
# 4   Lenovo ThinkPa...   /test-sites/e-commerce/allinone/product/72
# 5   Acer Aspire ES...   /test-sites/e-commerce/allinone/product/75
# 6   Asus EeeBook R...   /test-sites/e-commerce/allinone/product/77
# 7   Acer Extensa 1...   /test-sites/e-commerce/allinone/product/80
# 8   Acer Aspire A3...   /test-sites/e-commerce/allinone/product/83
# 9   Acer Aspire ES...   /test-sites/e-commerce/allinone/product/86
# 10  Lenovo V510 Bl...   /test-sites/e-commerce/allinone/product/89
# 11   Acer Aspire 3...   /test-sites/e-commerce/allinone/product/91
# 12          HP 250 G3   /test-sites/e-commerce/allinone/product/42
# ...

# %% [markdown]
# ## 6.5 Extract all product details of Second column save into csv file.

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops')
response.status_code
soup = BeautifulSoup(response.text,('html'))
print(soup.prettify())

# %%
all_products = main_div.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")
all_products
# Out:
# [<div class="col-md-4 col-xl-4 col-lg-4">
#  <div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product">
#  <div class="product-wrapper card-body">
#  <img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="price float-end card-title pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
#  <span itemprop="price">$295.99</span>
#  <meta content="USD" itemprop="priceCurrency"/>
#  </h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/60" itemprop="name" title="Asus VivoBook X441NA-GA190">
#  						Asus VivoBook...
#  					</a>
#  </h4>
#  <p class="description card-text" itemprop="description">Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd</p>
#  </div>
# ...

# %%
list = []
for i in all_products[1:117:3]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
    }
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q6_5.csv',index=False)
df
# Out:
#          product_name                                 product_link  \
# 0   Prestigio Smar...   /test-sites/e-commerce/allinone/product/62
# 1   Lenovo V110-15...   /test-sites/e-commerce/allinone/product/64
# 2   Acer Aspire A3...   /test-sites/e-commerce/allinone/product/67
# 3    Acer Aspire 3...   /test-sites/e-commerce/allinone/product/70
# 4   Lenovo ThinkPa...   /test-sites/e-commerce/allinone/product/72
# 5   Acer Aspire ES...   /test-sites/e-commerce/allinone/product/75
# 6   Asus EeeBook R...   /test-sites/e-commerce/allinone/product/77
# 7   Acer Extensa 1...   /test-sites/e-commerce/allinone/product/80
# 8   Acer Aspire A3...   /test-sites/e-commerce/allinone/product/83
# 9   Acer Aspire ES...   /test-sites/e-commerce/allinone/product/86
# 10  Lenovo V510 Bl...   /test-sites/e-commerce/allinone/product/89
# 11   Acer Aspire 3...   /test-sites/e-commerce/allinone/product/91
# 12          HP 250 G3   /test-sites/e-commerce/allinone/product/42
# ...

# %% [markdown]
# ## 6.6 Extract all product details of thirst column save into csv file.

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops')
response.status_code
soup = BeautifulSoup(response.text,('html'))
print(soup.prettify())

# %%
all_products = main_div.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")
all_products
# Out:
# [<div class="col-md-4 col-xl-4 col-lg-4">
#  <div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product">
#  <div class="product-wrapper card-body">
#  <img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="price float-end card-title pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
#  <span itemprop="price">$295.99</span>
#  <meta content="USD" itemprop="priceCurrency"/>
#  </h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/60" itemprop="name" title="Asus VivoBook X441NA-GA190">
#  						Asus VivoBook...
#  					</a>
#  </h4>
#  <p class="description card-text" itemprop="description">Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd</p>
#  </div>
# ...

# %%
list = []
for i in all_products[2:117:3]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
    }
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q6_6.csv',index=False)
df
# Out:
#          product_name                                 product_link  \
# 0   Prestigio Smar...   /test-sites/e-commerce/allinone/product/62
# 1   Lenovo V110-15...   /test-sites/e-commerce/allinone/product/64
# 2   Acer Aspire A3...   /test-sites/e-commerce/allinone/product/67
# 3    Acer Aspire 3...   /test-sites/e-commerce/allinone/product/70
# 4   Lenovo ThinkPa...   /test-sites/e-commerce/allinone/product/72
# 5   Acer Aspire ES...   /test-sites/e-commerce/allinone/product/75
# 6   Asus EeeBook R...   /test-sites/e-commerce/allinone/product/77
# 7   Acer Extensa 1...   /test-sites/e-commerce/allinone/product/80
# 8   Acer Aspire A3...   /test-sites/e-commerce/allinone/product/83
# 9   Acer Aspire ES...   /test-sites/e-commerce/allinone/product/86
# 10  Lenovo V510 Bl...   /test-sites/e-commerce/allinone/product/89
# 11   Acer Aspire 3...   /test-sites/e-commerce/allinone/product/91
# 12          HP 250 G3   /test-sites/e-commerce/allinone/product/42
# ...

# %% [markdown]
# ## 7.1 Extract first product details save into csv file. e.g# Packard 255 G2
# ## https://webscraper.io/test-sites/e-commerce/static/computers/laptops

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://webscraper.io/test-sites/e-commerce/static/computers/laptops')
response.status_code
soup = BeautifulSoup(response.text,('html'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Google Tag Manager -->
#   <script nonce="W4PkJV7B9LgvBOdMNw8b7ZQsQluIcU0e">
#    (function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <title>
#    Static | Web Scraper Test Sites
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# ...

# %%
all_products = soup.find("div",class_="col-md-4 col-xl-4 col-lg-4")
all_products.text
# Out:
# '\n\n\n\n\n\n$416.99\n\n\n\n\n\t\t\t\t\t\tPackard 255 G2\n\t\t\t\t\t\n\n15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1\n\n\n\n2 reviews\n\t\t\t\t\n\n\n\n\n\n\n\n'

# %%
all_products

# %%
list = []
prod_dictionary = {
    'product_name': '',
    'product_link': '',
    'product_img': '',
    'product_price': '',
    'product_details': '',
    'product_reviews_number': '',
    'product_reviews_star_number': '',
}

# %%
prod_dictionary['product_name']= all_products.find('a').text.strip()
prod_dictionary['product_details']=all_products.find('p').text
prod_dictionary['product_img']=all_products.find('img')['src']
prod_dictionary['product_link']=all_products.find('a')['href']
prod_dictionary['product_reviews_number']=all_products.find('div',class_='ratings').text.strip()
prod_dictionary['product_reviews_star_number']
prod_dictionary['product_price']=all_products.find('h4').text.strip()
list.append(prod_dictionary)

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q7_1.csv',index=False)
df
# Out:
#      product_name                              product_link  \
# 0  Packard 255 G2  /test-sites/e-commerce/static/product/31
#
#                                      product_img product_price  \
# 0  /images/test-sites/e-commerce/items/cart2.png       $416.99
#
#                                      product_details product_reviews_number  \
# 0  15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows...              2 reviews
#
#   product_reviews_star_number
# 0

# %% [markdown]
# ## 7.2 Extract product details from first row & save into csv file. e.g# Packard 255 G2, Aspire E1-510, ThinkPad T540p

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://webscraper.io/test-sites/e-commerce/static/computers/laptops')
response.status_code
soup = BeautifulSoup(response.text,('html'))
print(soup.prettify())

# %%
all_products = soup.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")
all_products
# Out:
# [<div class="col-md-4 col-xl-4 col-lg-4">
#  <div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product">
#  <div class="product-wrapper card-body">
#  <img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="price float-end card-title pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
#  <span itemprop="price">$416.99</span>
#  <meta content="USD" itemprop="priceCurrency"/>
#  </h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/static/product/31" itemprop="name" title="Packard 255 G2">
#  						Packard 255 G2
#  					</a>
#  </h4>
#  <p class="description card-text" itemprop="description">15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1</p>
#  </div>
#  <div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating">
#  <p class="review-count float-end">
# ...

# %%
list = []
for i in all_products[0:3]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
    }
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q7_2.csv',index=False)
df
# Out:
#      product_name                              product_link  \
# 0  Packard 255 G2  /test-sites/e-commerce/static/product/31
# 1   Aspire E1-510  /test-sites/e-commerce/static/product/32
# 2  ThinkPad T540p  /test-sites/e-commerce/static/product/33
#
#                                      product_img product_price  \
# 0  /images/test-sites/e-commerce/items/cart2.png       $416.99
# 1  /images/test-sites/e-commerce/items/cart2.png       $306.99
# 2  /images/test-sites/e-commerce/items/cart2.png      $1178.99
#
#                                      product_details product_reviews_number  \
# 0  15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows...              2 reviews
# 1    15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux              2 reviews
# 2   15.6", Core i5-4200M, 4GB, 500GB, Win7 Pro 64bit              2 reviews
#
#   product_reviews_star_number
# 0
# 1
# 2

# %% [markdown]
# ## 7.3 Extract all product details from first page & save into csv file.

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://webscraper.io/test-sites/e-commerce/static/computers/laptops')
response.status_code
soup = BeautifulSoup(response.text,('html'))
print(soup.prettify())

# %%
all_products = soup.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")
all_products
# Out:
# [<div class="col-md-4 col-xl-4 col-lg-4">
#  <div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product">
#  <div class="product-wrapper card-body">
#  <img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="price float-end card-title pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
#  <span itemprop="price">$416.99</span>
#  <meta content="USD" itemprop="priceCurrency"/>
#  </h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/static/product/31" itemprop="name" title="Packard 255 G2">
#  						Packard 255 G2
#  					</a>
#  </h4>
#  <p class="description card-text" itemprop="description">15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1</p>
#  </div>
#  <div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating">
#  <p class="review-count float-end">
# ...

# %%
list = []
for i in all_products[0:6]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
    }
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q7_3.csv',index=False)
df
# Out:
#      product_name                              product_link  \
# 0  Packard 255 G2  /test-sites/e-commerce/static/product/31
# 1   Aspire E1-510  /test-sites/e-commerce/static/product/32
# 2  ThinkPad T540p  /test-sites/e-commerce/static/product/33
# 3         ProBook  /test-sites/e-commerce/static/product/34
# 4   ThinkPad X240  /test-sites/e-commerce/static/product/35
# 5  Aspire E1-572G  /test-sites/e-commerce/static/product/36
#
#                                      product_img product_price  \
# 0  /images/test-sites/e-commerce/items/cart2.png       $416.99
# 1  /images/test-sites/e-commerce/items/cart2.png       $306.99
# 2  /images/test-sites/e-commerce/items/cart2.png      $1178.99
# 3  /images/test-sites/e-commerce/items/cart2.png       $739.99
# 4  /images/test-sites/e-commerce/items/cart2.png      $1311.99
# 5  /images/test-sites/e-commerce/items/cart2.png       $581.99
#
#                                      product_details product_reviews_number  \
# ...

# %% [markdown]
# ## 7.4 Extract all product details from second page & save into another csv file.

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=2')
response.status_code
soup = BeautifulSoup(response.text,('html'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Google Tag Manager -->
#   <script nonce="H8kFcMCfLmymRuwlD681mM1LGdb0OoOJ">
#    (function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <title>
#    Static | Web Scraper Test Sites
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# ...

# %%
all_products = soup.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")
all_products
# Out:
# [<div class="col-md-4 col-xl-4 col-lg-4">
#  <div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product">
#  <div class="product-wrapper card-body">
#  <img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="price float-end card-title pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
#  <span itemprop="price">$1033.99</span>
#  <meta content="USD" itemprop="priceCurrency"/>
#  </h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/static/product/37" itemprop="name" title="ThinkPad Yoga">
#  						ThinkPad Yoga
#  					</a>
#  </h4>
#  <p class="description card-text" itemprop="description">12.5" Touch, Core i3-4010U, 4GB, 500GB + 16GB SSD Cache,</p>
#  </div>
#  <div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating">
#  <p class="review-count float-end">
# ...

# %%
list = []
for i in all_products[0:6]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
    }
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q7_4.csv',index=False)
df
# Out:
#     product_name                              product_link  \
# 0  ThinkPad Yoga  /test-sites/e-commerce/static/product/37
# 1       Pavilion  /test-sites/e-commerce/static/product/38
# 2    Inspiron 15  /test-sites/e-commerce/static/product/39
# 3    Dell XPS 13  /test-sites/e-commerce/static/product/40
# 4  ThinkPad X230  /test-sites/e-commerce/static/product/41
# 5      HP 250 G3  /test-sites/e-commerce/static/product/42
#
#                                      product_img product_price  \
# 0  /images/test-sites/e-commerce/items/cart2.png      $1033.99
# 1  /images/test-sites/e-commerce/items/cart2.png       $609.99
# 2  /images/test-sites/e-commerce/items/cart2.png       $745.99
# 3  /images/test-sites/e-commerce/items/cart2.png      $1281.99
# 4  /images/test-sites/e-commerce/items/cart2.png      $1244.99
# 5  /images/test-sites/e-commerce/items/cart2.png       $520.99
#
#                                      product_details product_reviews_number  \
# ...

# %% [markdown]
# ## 7.5 Extract all product details from first page to fifth page & save into single csv file.

# %%
import requests
from bs4 import BeautifulSoup
# url = 'https://webscraper.io/test-sites/e-commerce/static/computers/laptops='
url = "https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page="

# %%
list = []
for i in range(1,6):
    url_b = url+str(i)
    response = requests.get(url_b)
    print(response.status_code)
    soup = BeautifulSoup(response.text,('html'))
    all_products = soup.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")


    # print(soup.prettify())
    
    for i in all_products:
        prod_dictionary = {
            'product_name': '',
            'product_link': '',
            'product_img': '',
            'product_price': '',
            'product_details': '',
            'product_reviews_number': '',
            'product_reviews_star_number': '',
        }
        prod_dictionary['product_name']= i.find('a').text.strip()
        prod_dictionary['product_details']=i.find('p').text
        prod_dictionary['product_img']=i.find('img')['src']
        prod_dictionary['product_link']=i.find('a')['href']
        prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
        prod_dictionary['product_reviews_star_number']
        prod_dictionary['product_price']=i.find('h4').text.strip()
        list.append(prod_dictionary)
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q7_5.csv',index=False)
df
# Out:
#          product_name                              product_link  \
# 0      Packard 255 G2  /test-sites/e-commerce/static/product/31
# 1       Aspire E1-510  /test-sites/e-commerce/static/product/32
# 2      ThinkPad T540p  /test-sites/e-commerce/static/product/33
# 3             ProBook  /test-sites/e-commerce/static/product/34
# 4       ThinkPad X240  /test-sites/e-commerce/static/product/35
# 5      Aspire E1-572G  /test-sites/e-commerce/static/product/36
# 6       ThinkPad Yoga  /test-sites/e-commerce/static/product/37
# 7            Pavilion  /test-sites/e-commerce/static/product/38
# 8         Inspiron 15  /test-sites/e-commerce/static/product/39
# 9         Dell XPS 13  /test-sites/e-commerce/static/product/40
# 10      ThinkPad X230  /test-sites/e-commerce/static/product/41
# 11          HP 250 G3  /test-sites/e-commerce/static/product/42
# 12      ThinkPad Yoga  /test-sites/e-commerce/static/product/43
# 13          HP 350 G1  /test-sites/e-commerce/static/product/44
# ...
