# %% [markdown]
# ## 4.1 Extract first product details save into csv file. e.g# Packard 255 G2

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome()
driver.get("https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops")

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
soup
# Out:
# <html lang="en"><head>
# <!-- Google Tag Manager -->
# <script async="" nonce="" src="https://www.googletagmanager.com/gtag/js?id=G-Q9KY1T6XJQ&amp;cx=c&amp;gtm=4e5bj0h2" type="text/javascript"></script><script async="" nonce="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NVFPDWB"></script><script nonce="">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>Ajax | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." name="description"/>
# <link href="/favicon.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="/favicon.ico" rel="icon" sizes="16x16 32x32" type="image/x-icon"/>
# <link href="/logo-icon.png" rel="apple-touch-icon" type="image/png"/>
# <link href="/icon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;600&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700;800;900&amp;display=swap" rel="stylesheet"/>
# <link href="/css/app.css?id=37e354cd0cf06349d7ad09f2f5065e98" rel="stylesheet"/>
# <link href="/css/ws-icons.font.css?id=d8505f3d910cc64df752f712c8032fdb" rel="stylesheet"/>
# <link href="https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops?page=" rel="canonical"/>
# <meta content="Ajax | Web Scraper Test Sites" property="og:title"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops?page=" property="og:url"/>
# <meta content="https://webscraper.io/webscraper-logo-header.png" property="og:image"/>
# <script defer="" src="/js/app.js?id=08b634a892b70c890a9c8f6190db952b"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVFPDWB" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header class="navbar fixed-top navbar-expand-lg navbar-dark navbar-static svg-background" id="navbar-top" role="banner">
# <div class="container">
# <div class="navbar-header">
# <a data-bs-target=".side-collapse" data-bs-target-2=".side-collapse-container" data-bs-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggler float-end collapsed" data-bs-target="#navbar" data-bs-target-2=".side-collapse-container" data-bs-target-3=".side-collapse" data-bs-toggle="collapse" type="button">
# <span class="visually-hidden">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# <span class="icon-bar extra-bottom-bar"></span>
# </button>
# </a>
# <div class="navbar-brand">
# <a href="/"><img alt="Web Scraper" height="50px" src="/img/logo_white.svg" width="150px"/></a>
# </div>
# </div>
# <div class="side-collapse in">
# <nav class="navbar-collapse collapse" id="navbar" role="navigation">
# <ul class="nav navbar-nav navbar-right">
# <li class="nav-item">
# <a class="nav-link menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/cloud-scraper" id="cloud-nav-link">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/pricing" id="pricing-nav-link">
# <p>Pricing</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item dropdown">
# <button aria-expanded="false" aria-haspopup="true" class="menuitm nav-link dropdown-toggle" data-bs-toggle="dropdown" id="dropdownMenuLink" role="button">
# <p>
# 								Learn
# 								<i class="ws-icon ws-icon-down"></i>
# </p>
# <span class="crta"></span>
# </button>
# <ul aria-labelledby="dropdownMenuLink" class="dropdown-menu">
# <li>
# <a class="dropdown-item" href="/documentation">Documentation</a>
# </li>
# <li>
# <a class="dropdown-item" href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a class="dropdown-item" href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a class="dropdown-item" href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu1 install-extension" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
# <i aria-hidden="true" class="browser-icon ws-icon ws-icon-chrome-500"></i>
# 							Install
# 						</a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu2" href="https://cloud.webscraper.io/">Cloud Login</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </header>
# <div class="wrapper">
# <div class="formenu-here container-fluid">
# </div>
# <div class="container-fluid blog-hero">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h1>Test Sites</h1>
# </div>
# </div>
# </div>
# </div>
# <div class="container test-site">
# <div class="row">
# <div class="col-lg-3 sidebar">
# <div class="navbar-light sidebar" role="navigation">
# <div class="sidebar-nav navbar-collapse">
# <ul class="nav flex-column" id="side-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a class="nav-link" href="/test-sites/e-commerce/ajax" itemprop="url"><span itemprop="name">Home</span></a>
# </li>
# <li class="nav-item active">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/ajax/computers" itemprop="url">
# <span itemprop="name">Computers</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# <ul class="nav nav-second-level" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link active" href="/test-sites/e-commerce/ajax/computers/laptops" itemprop="url">
# <span itemprop="name">Laptops</span>
# </a>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link" href="/test-sites/e-commerce/ajax/computers/tablets" itemprop="url">
# <span itemprop="name">Tablets</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/ajax/phones" itemprop="url">
# <span itemprop="name">Phones</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-lg-9">
# <h1 class="page-header">Computers / Laptops</h1>
# <div class="row ecomerce-items ecomerce-items-ajax" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD,  ...
# <div class="btn-group pagination justify-content-center" role="group">
# <button class="btn btn-default page-link page btn-primary active" data-id="1" type="button">1</button>
# <button class="btn btn-default page-link page" data-id="2" type="button">2</button>
# <button class="btn btn-default page-link page" data-id="3" type="button">3</button>
# <button class="btn btn-default page-link page" data-id="4" type="button">4</button>
# <button class="btn btn-default page-link page" data-id="5" type="button">5</button>
# <button class="btn btn-default page-link page" data-id="6" type="button">6</button>
# <button class="btn btn-default page-link page" data-id="7" type="button">7</button>
# <button class="btn btn-default page-link page" data-id="8" type="button">8</button>
# <button class="btn btn-default page-link page" data-id="9" type="button">9</button>
# <button class="btn btn-default page-link page" data-id="10" type="button">10</button>
# <button class="btn btn-default page-link page" data-id="11" type="button">11</button>
# <button class="btn btn-default page-link page" data-id="12" type="button">12</button>
# <button class="btn btn-default page-link page" data-id="13" type="button">13</button>
# <button class="btn btn-default page-link page" data-id="14" type="button">14</button>
# <button class="btn btn-default page-link page" data-id="15" type="button">15</button>
# <button class="btn btn-default page-link page" data-id="16" type="button">16</button>
# <button class="btn btn-default page-link page" data-id="17" type="button">17</button>
# <button class="btn btn-default page-link page" data-id="18" type="button">18</button>
# <button class="btn btn-default page-link page" data-id="19" type="button">19</button>
# <button class="btn btn-default page-link page" data-id="20" type="button">20</button>
# </div>
# <div class="pager">
# <button class="btn btn-default previous" disabled="" type="button">&lt; Previous</button>
# <button class="btn btn-default next" type="button">Next &gt;</button>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="push"></div>
# </div>
# <div class="container-fluid footer" id="layout-footer">
# <div class="container">
# <div class="row">
# <div class="col-lg-3">
# <ul>
# <li><p>Products</p></li>
# <li>
# <a class="install-extension" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
# 							Web Scraper browser extension
# 						</a>
# </li>
# <li>
# <a href="/cloud-scraper">Web Scraper Cloud</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Company</p></li>
# <li>
# <a href="/about-us">About us</a>
# </li>
# <li>
# <a href="/contact">Contact</a>
# </li>
# <li>
# <a href="/privacy-policy">Website Privacy Policy</a>
# </li>
# <li>
# <a href="/extension-privacy-policy">Browser Extension Privacy Policy</a>
# </li>
# <li>
# <a href="https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip">Media kit</a>
# </li>
# <li><a href="/jobs">Jobs</a></li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Resources</p></li>
# <li><a href="/blog">Blog</a></li>
# <li>
# <a href="/documentation">Documentation</a>
# </li>
# <li>
# <a href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a href="/screenshots">Screenshots</a>
# </li>
# <li>
# <a href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# <li>
# <a href="https://status.webscraper.io/" rel="noopener" target="_blank">Status</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>CONTACT US</p></li>
# <li>
# <a href="mailto:info@webscraper.io">info@webscraper.io</a>
# </li>
# <li>Ubelu 5-71,<br/> Adazi, Latvia, LV-2164</li>
# </ul>
# <ul class="smedia">
# <li>
# <a aria-label="Web Scraper on Facebook" href="https://www.facebook.com/webscraperio/" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-facebook-f"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on LinkedIn" href="https://lv.linkedin.com/company/web-scraper" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-linkedin"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on Youtube" href="https://youtube.com/@WebScraper/videos" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-youtube"></i>
# </a>
# </li>
# <li>
# <a aria-label="Download the Web Scraper extension" class="install-extension browser-icon-dark" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
# <i class="browser-icon ws-icon ws-icon-chrome-dark"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-12">
# <p class="copyright">Copyright © 2025
# 					<b>Web Scraper</b> | All rights reserved</p>
# </div>
# </div>
# </div>
# </div>
# <iframe height="0" style="display: none; visibility: hidden;" width="0"></iframe><div id="cookieBanner" style="opacity: 1; display: block; transition: opacity 0.2s;"><div id="closeCookieBanner">x</div>We use cookies to make your Web Scraper experience better. Read our <a href="/privacy-policy">Privacy Policy</a>. <div class="acceptContainer"><button class="acceptCookies">Accept &amp; Continue</button></div></div></body></html>

# %%
product = soup.find('div',class_='product-wrapper card-body')
product
# Out:
# <div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$295.99</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/60" itemprop="name" title="Asus VivoBook X441NA-GA190">Asus VivoBook X4</a></h4><p class="card-text description" itemprop="description">Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">1</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div>

# %%
list = []
prod_dictionary = {
    'product_name': '',
    'product_link': '',
    'product_img': '',
    'product_price': '',
    'product_details': '',
    'product_reviews_number': '',
    'product_reviews_star_number': '',
}

# %%
prod_dictionary['product_name']= product.find('a').text.strip()
prod_dictionary['product_details']=product.find('p').text
prod_dictionary['product_img']=product.find('img')['src']
prod_dictionary['product_link']=product.find('a')['href']
prod_dictionary['product_reviews_number']=product.find('div',class_='ratings').text.strip()
prod_dictionary['product_reviews_star_number']
prod_dictionary['product_price']=product.find('h4').text.strip()
list.append(prod_dictionary)

# %%
prod_dictionary
# Out:
# {'product_name': 'Asus VivoBook X4',
#  'product_link': '/test-sites/e-commerce/ajax/product/60',
#  'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#  'product_price': '$295.99',
#  'product_details': 'Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd',
#  'product_reviews_number': '1 reviews',
#  'product_reviews_star_number': ''}

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q4_1.csv',index=False)

# %% [markdown]
# ## 4.2 Extract product details from first row & save into csv file. e.g# Packard 255 G2, Aspire E1-510, ThinkPad T540p

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome()
driver.get("https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops")

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
soup
# Out:
# <html lang="en"><head>
# <!-- Google Tag Manager -->
# <script async="" nonce="" src="https://www.googletagmanager.com/gtag/js?id=G-Q9KY1T6XJQ&amp;cx=c&amp;gtm=4e5bj0h2" type="text/javascript"></script><script async="" nonce="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NVFPDWB"></script><script nonce="">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>Ajax | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." name="description"/>
# <link href="/favicon.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="/favicon.ico" rel="icon" sizes="16x16 32x32" type="image/x-icon"/>
# <link href="/logo-icon.png" rel="apple-touch-icon" type="image/png"/>
# <link href="/icon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;600&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700;800;900&amp;display=swap" rel="stylesheet"/>
# <link href="/css/app.css?id=37e354cd0cf06349d7ad09f2f5065e98" rel="stylesheet"/>
# <link href="/css/ws-icons.font.css?id=d8505f3d910cc64df752f712c8032fdb" rel="stylesheet"/>
# <link href="https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops" rel="canonical"/>
# <meta content="Ajax | Web Scraper Test Sites" property="og:title"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops" property="og:url"/>
# <meta content="https://webscraper.io/webscraper-logo-header.png" property="og:image"/>
# <script defer="" src="/js/app.js?id=08b634a892b70c890a9c8f6190db952b"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVFPDWB" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header class="navbar fixed-top navbar-expand-lg navbar-dark navbar-static svg-background" id="navbar-top" role="banner">
# <div class="container">
# <div class="navbar-header">
# <a data-bs-target=".side-collapse" data-bs-target-2=".side-collapse-container" data-bs-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggler float-end collapsed" data-bs-target="#navbar" data-bs-target-2=".side-collapse-container" data-bs-target-3=".side-collapse" data-bs-toggle="collapse" type="button">
# <span class="visually-hidden">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# <span class="icon-bar extra-bottom-bar"></span>
# </button>
# </a>
# <div class="navbar-brand">
# <a href="/"><img alt="Web Scraper" height="50px" src="/img/logo_white.svg" width="150px"/></a>
# </div>
# </div>
# <div class="side-collapse in">
# <nav class="navbar-collapse collapse" id="navbar" role="navigation">
# <ul class="nav navbar-nav navbar-right">
# <li class="nav-item">
# <a class="nav-link menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/cloud-scraper" id="cloud-nav-link">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/pricing" id="pricing-nav-link">
# <p>Pricing</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item dropdown">
# <button aria-expanded="false" aria-haspopup="true" class="menuitm nav-link dropdown-toggle" data-bs-toggle="dropdown" id="dropdownMenuLink" role="button">
# <p>
# 								Learn
# 								<i class="ws-icon ws-icon-down"></i>
# </p>
# <span class="crta"></span>
# </button>
# <ul aria-labelledby="dropdownMenuLink" class="dropdown-menu">
# <li>
# <a class="dropdown-item" href="/documentation">Documentation</a>
# </li>
# <li>
# <a class="dropdown-item" href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a class="dropdown-item" href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a class="dropdown-item" href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu1 install-extension" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
# <i aria-hidden="true" class="browser-icon ws-icon ws-icon-chrome-500"></i>
# 							Install
# 						</a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu2" href="https://cloud.webscraper.io/">Cloud Login</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </header>
# <div class="wrapper">
# <div class="formenu-here container-fluid">
# </div>
# <div class="container-fluid blog-hero">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h1>Test Sites</h1>
# </div>
# </div>
# </div>
# </div>
# <div class="container test-site">
# <div class="row">
# <div class="col-lg-3 sidebar">
# <div class="navbar-light sidebar" role="navigation">
# <div class="sidebar-nav navbar-collapse">
# <ul class="nav flex-column" id="side-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a class="nav-link" href="/test-sites/e-commerce/ajax" itemprop="url"><span itemprop="name">Home</span></a>
# </li>
# <li class="nav-item active">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/ajax/computers" itemprop="url">
# <span itemprop="name">Computers</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# <ul class="nav nav-second-level" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link active" href="/test-sites/e-commerce/ajax/computers/laptops" itemprop="url">
# <span itemprop="name">Laptops</span>
# </a>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link" href="/test-sites/e-commerce/ajax/computers/tablets" itemprop="url">
# <span itemprop="name">Tablets</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/ajax/phones" itemprop="url">
# <span itemprop="name">Phones</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-lg-9">
# <h1 class="page-header">Computers / Laptops</h1>
# <div class="row ecomerce-items ecomerce-items-ajax" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD,  ...
# <div class="btn-group pagination justify-content-center" role="group">
# <button class="btn btn-default page-link page btn-primary active" data-id="1" type="button">1</button>
# <button class="btn btn-default page-link page" data-id="2" type="button">2</button>
# <button class="btn btn-default page-link page" data-id="3" type="button">3</button>
# <button class="btn btn-default page-link page" data-id="4" type="button">4</button>
# <button class="btn btn-default page-link page" data-id="5" type="button">5</button>
# <button class="btn btn-default page-link page" data-id="6" type="button">6</button>
# <button class="btn btn-default page-link page" data-id="7" type="button">7</button>
# <button class="btn btn-default page-link page" data-id="8" type="button">8</button>
# <button class="btn btn-default page-link page" data-id="9" type="button">9</button>
# <button class="btn btn-default page-link page" data-id="10" type="button">10</button>
# <button class="btn btn-default page-link page" data-id="11" type="button">11</button>
# <button class="btn btn-default page-link page" data-id="12" type="button">12</button>
# <button class="btn btn-default page-link page" data-id="13" type="button">13</button>
# <button class="btn btn-default page-link page" data-id="14" type="button">14</button>
# <button class="btn btn-default page-link page" data-id="15" type="button">15</button>
# <button class="btn btn-default page-link page" data-id="16" type="button">16</button>
# <button class="btn btn-default page-link page" data-id="17" type="button">17</button>
# <button class="btn btn-default page-link page" data-id="18" type="button">18</button>
# <button class="btn btn-default page-link page" data-id="19" type="button">19</button>
# <button class="btn btn-default page-link page" data-id="20" type="button">20</button>
# </div>
# <div class="pager">
# <button class="btn btn-default previous" disabled="" type="button">&lt; Previous</button>
# <button class="btn btn-default next" type="button">Next &gt;</button>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="push"></div>
# </div>
# <div class="container-fluid footer" id="layout-footer">
# <div class="container">
# <div class="row">
# <div class="col-lg-3">
# <ul>
# <li><p>Products</p></li>
# <li>
# <a class="install-extension" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
# 							Web Scraper browser extension
# 						</a>
# </li>
# <li>
# <a href="/cloud-scraper">Web Scraper Cloud</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Company</p></li>
# <li>
# <a href="/about-us">About us</a>
# </li>
# <li>
# <a href="/contact">Contact</a>
# </li>
# <li>
# <a href="/privacy-policy">Website Privacy Policy</a>
# </li>
# <li>
# <a href="/extension-privacy-policy">Browser Extension Privacy Policy</a>
# </li>
# <li>
# <a href="https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip">Media kit</a>
# </li>
# <li><a href="/jobs">Jobs</a></li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Resources</p></li>
# <li><a href="/blog">Blog</a></li>
# <li>
# <a href="/documentation">Documentation</a>
# </li>
# <li>
# <a href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a href="/screenshots">Screenshots</a>
# </li>
# <li>
# <a href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# <li>
# <a href="https://status.webscraper.io/" rel="noopener" target="_blank">Status</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>CONTACT US</p></li>
# <li>
# <a href="mailto:info@webscraper.io">info@webscraper.io</a>
# </li>
# <li>Ubelu 5-71,<br/> Adazi, Latvia, LV-2164</li>
# </ul>
# <ul class="smedia">
# <li>
# <a aria-label="Web Scraper on Facebook" href="https://www.facebook.com/webscraperio/" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-facebook-f"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on LinkedIn" href="https://lv.linkedin.com/company/web-scraper" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-linkedin"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on Youtube" href="https://youtube.com/@WebScraper/videos" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-youtube"></i>
# </a>
# </li>
# <li>
# <a aria-label="Download the Web Scraper extension" class="install-extension browser-icon-dark" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
# <i class="browser-icon ws-icon ws-icon-chrome-dark"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-12">
# <p class="copyright">Copyright © 2025
# 					<b>Web Scraper</b> | All rights reserved</p>
# </div>
# </div>
# </div>
# </div><iframe height="0" style="display: none; visibility: hidden;" width="0"></iframe>
# <div id="cookieBanner" style="opacity: 0; display: none; transition: opacity 0.2s;"><div id="closeCookieBanner">x</div>We use cookies to make your Web Scraper experience better. Read our <a href="/privacy-policy">Privacy Policy</a>. <div class="acceptContainer"><button class="acceptCookies">Accept &amp; Continue</button></div></div></body></html>

# %%
products = soup.find_all('div',class_='row')
products
# Out:
# [<div class="row">
#  <div class="col-lg-12">
#  <h1>Test Sites</h1>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-lg-3 sidebar">
#  <div class="navbar-light sidebar" role="navigation">
#  <div class="sidebar-nav navbar-collapse">
#  <ul class="nav flex-column" id="side-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
#  <li class="nav-item">
#  <a class="nav-link" href="/test-sites/e-commerce/ajax" itemprop="url"><span itemprop="name">Home</span></a>
#  </li>
#  <li class="nav-item active">
#  <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/ajax/computers" itemprop="url">
#  <span itemprop="name">Computers</span>
#  <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
#  </a>
#  <ul class="nav nav-second-level" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
#  <li class="nav-item">
#  <a aria-label="Navigation subcategory" class="nav-link subcategory-link active" href="/test-sites/e-commerce/ajax/computers/laptops" itemprop="url">
#  <span itemprop="name">Laptops</span>
#  </a>
#  </li>
#  <li class="nav-item">
#  <a aria-label="Navigation subcategory" class="nav-link subcategory-link" href="/test-sites/e-commerce/ajax/computers/tablets" itemprop="url">
#  <span itemprop="name">Tablets</span>
#  </a>
#  </li>
#  </ul>
#  </li>
#  <li class="nav-item">
#  <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/ajax/phones" itemprop="url">
#  <span itemprop="name">Phones</span>
#  <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="col-lg-9">
#  <h1 class="page-header">Computers / Laptops</h1>
#  <div class="row ecomerce-items ecomerce-items-ajax" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD, ...
#  <div class="btn-group pagination justify-content-center" role="group">
#  <button class="btn btn-default page-link page btn-primary active" data-id="1" type="button">1</button>
#  <button class="btn btn-default page-link page" data-id="2" type="button">2</button>
#  <button class="btn btn-default page-link page" data-id="3" type="button">3</button>
#  <button class="btn btn-default page-link page" data-id="4" type="button">4</button>
#  <button class="btn btn-default page-link page" data-id="5" type="button">5</button>
#  <button class="btn btn-default page-link page" data-id="6" type="button">6</button>
#  <button class="btn btn-default page-link page" data-id="7" type="button">7</button>
#  <button class="btn btn-default page-link page" data-id="8" type="button">8</button>
#  <button class="btn btn-default page-link page" data-id="9" type="button">9</button>
#  <button class="btn btn-default page-link page" data-id="10" type="button">10</button>
#  <button class="btn btn-default page-link page" data-id="11" type="button">11</button>
#  <button class="btn btn-default page-link page" data-id="12" type="button">12</button>
#  <button class="btn btn-default page-link page" data-id="13" type="button">13</button>
#  <button class="btn btn-default page-link page" data-id="14" type="button">14</button>
#  <button class="btn btn-default page-link page" data-id="15" type="button">15</button>
#  <button class="btn btn-default page-link page" data-id="16" type="button">16</button>
#  <button class="btn btn-default page-link page" data-id="17" type="button">17</button>
#  <button class="btn btn-default page-link page" data-id="18" type="button">18</button>
#  <button class="btn btn-default page-link page" data-id="19" type="button">19</button>
#  <button class="btn btn-default page-link page" data-id="20" type="button">20</button>
#  </div>
#  <div class="pager">
#  <button class="btn btn-default previous" disabled="" type="button">&lt; Previous</button>
#  <button class="btn btn-default next" type="button">Next &gt;</button>
#  </div>
#  </div>
#  </div>,
#  <div class="row ecomerce-items ecomerce-items-ajax" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD, ...
#  <div class="row">
#  <div class="col-lg-3">
#  <ul>
#  <li><p>Products</p></li>
#  <li>
#  <a class="install-extension" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
#  							Web Scraper browser extension
#  						</a>
#  </li>
#  <li>
#  <a href="/cloud-scraper">Web Scraper Cloud</a>
#  </li>
#  </ul>
#  </div>
#  <div class="col-lg-3">
#  <ul>
#  <li><p>Company</p></li>
#  <li>
#  <a href="/about-us">About us</a>
#  </li>
#  <li>
#  <a href="/contact">Contact</a>
#  </li>
#  <li>
#  <a href="/privacy-policy">Website Privacy Policy</a>
#  </li>
#  <li>
#  <a href="/extension-privacy-policy">Browser Extension Privacy Policy</a>
#  </li>
#  <li>
#  <a href="https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip">Media kit</a>
#  </li>
#  <li><a href="/jobs">Jobs</a></li>
#  </ul>
#  </div>
#  <div class="col-lg-3">
#  <ul>
#  <li><p>Resources</p></li>
#  <li><a href="/blog">Blog</a></li>
#  <li>
#  <a href="/documentation">Documentation</a>
#  </li>
#  <li>
#  <a href="/tutorials">Video Tutorials</a>
#  </li>
#  <li>
#  <a href="/screenshots">Screenshots</a>
#  </li>
#  <li>
#  <a href="/test-sites">Test Sites</a>
#  </li>
#  <li>
#  <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
#  </li>
#  <li>
#  <a href="https://status.webscraper.io/" rel="noopener" target="_blank">Status</a>
#  </li>
#  </ul>
#  </div>
#  <div class="col-lg-3">
#  <ul>
#  <li><p>CONTACT US</p></li>
#  <li>
#  <a href="mailto:info@webscraper.io">info@webscraper.io</a>
#  </li>
#  <li>Ubelu 5-71,<br/> Adazi, Latvia, LV-2164</li>
#  </ul>
#  <ul class="smedia">
#  <li>
#  <a aria-label="Web Scraper on Facebook" href="https://www.facebook.com/webscraperio/" rel="noopener" target="_blank">
#  <i class="ws-icon ws-icon-facebook-f"></i>
#  </a>
#  </li>
#  <li>
#  <a aria-label="Web Scraper on LinkedIn" href="https://lv.linkedin.com/company/web-scraper" rel="noopener" target="_blank">
#  <i class="ws-icon ws-icon-linkedin"></i>
#  </a>
#  </li>
#  <li>
#  <a aria-label="Web Scraper on Youtube" href="https://youtube.com/@WebScraper/videos" rel="noopener" target="_blank">
#  <i class="ws-icon ws-icon-youtube"></i>
#  </a>
#  </li>
#  <li>
#  <a aria-label="Download the Web Scraper extension" class="install-extension browser-icon-dark" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
#  <i class="browser-icon ws-icon ws-icon-chrome-dark"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-lg-12">
#  <p class="copyright">Copyright © 2025
#  					<b>Web Scraper</b> | All rights reserved</p>
#  </div>
#  </div>]

# %%
main_div = products[2]

all_products = main_div.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")
len(all_products)
# all_products
# Out:
# 6

# %%
len(products)
# Out:
# 5

# %%
list = []
for i in all_products[0:3]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
 } 
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
list
# Out:
# [{'product_name': 'Asus VivoBook X4',
#   'product_link': '/test-sites/e-commerce/ajax/product/60',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$295.99',
#   'product_details': 'Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd',
#   'product_reviews_number': '1 reviews',
#   'product_reviews_star_number': ''},
#  {'product_name': 'Prestigio SmartB',
#   'product_link': '/test-sites/e-commerce/ajax/product/61',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$299',
#   'product_details': 'Prestigio SmartBook 133S Dark Grey, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam',
#   'product_reviews_number': '9 reviews',
#   'product_reviews_star_number': ''},
#  {'product_name': 'Prestigio SmartB',
#   'product_link': '/test-sites/e-commerce/ajax/product/62',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$299',
#   'product_details': 'Prestigio SmartBook 133S Gold, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam',
#   'product_reviews_number': '9 reviews',
#   'product_reviews_star_number': ''}]

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q4_2.csv',index=False)

# %% [markdown]
# ## 4.3 Extract all product details from first page & save into csv file.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome()
driver.get("https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops")

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
soup
# Out:
# <html lang="en"><head>
# <!-- Google Tag Manager -->
# <script async="" nonce="" src="https://www.googletagmanager.com/gtag/js?id=G-Q9KY1T6XJQ&amp;cx=c&amp;gtm=4e5bj0h2" type="text/javascript"></script><script async="" nonce="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NVFPDWB"></script><script nonce="">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>Ajax | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." name="description"/>
# <link href="/favicon.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="/favicon.ico" rel="icon" sizes="16x16 32x32" type="image/x-icon"/>
# <link href="/logo-icon.png" rel="apple-touch-icon" type="image/png"/>
# <link href="/icon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;600&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700;800;900&amp;display=swap" rel="stylesheet"/>
# <link href="/css/app.css?id=37e354cd0cf06349d7ad09f2f5065e98" rel="stylesheet"/>
# <link href="/css/ws-icons.font.css?id=d8505f3d910cc64df752f712c8032fdb" rel="stylesheet"/>
# <link href="https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops" rel="canonical"/>
# <meta content="Ajax | Web Scraper Test Sites" property="og:title"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops" property="og:url"/>
# <meta content="https://webscraper.io/webscraper-logo-header.png" property="og:image"/>
# <script defer="" src="/js/app.js?id=08b634a892b70c890a9c8f6190db952b"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVFPDWB" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header class="navbar fixed-top navbar-expand-lg navbar-dark navbar-static svg-background" id="navbar-top" role="banner">
# <div class="container">
# <div class="navbar-header">
# <a data-bs-target=".side-collapse" data-bs-target-2=".side-collapse-container" data-bs-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggler float-end collapsed" data-bs-target="#navbar" data-bs-target-2=".side-collapse-container" data-bs-target-3=".side-collapse" data-bs-toggle="collapse" type="button">
# <span class="visually-hidden">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# <span class="icon-bar extra-bottom-bar"></span>
# </button>
# </a>
# <div class="navbar-brand">
# <a href="/"><img alt="Web Scraper" height="50px" src="/img/logo_white.svg" width="150px"/></a>
# </div>
# </div>
# <div class="side-collapse in">
# <nav class="navbar-collapse collapse" id="navbar" role="navigation">
# <ul class="nav navbar-nav navbar-right">
# <li class="nav-item">
# <a class="nav-link menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/cloud-scraper" id="cloud-nav-link">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/pricing" id="pricing-nav-link">
# <p>Pricing</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item dropdown">
# <button aria-expanded="false" aria-haspopup="true" class="menuitm nav-link dropdown-toggle" data-bs-toggle="dropdown" id="dropdownMenuLink" role="button">
# <p>
# 								Learn
# 								<i class="ws-icon ws-icon-down"></i>
# </p>
# <span class="crta"></span>
# </button>
# <ul aria-labelledby="dropdownMenuLink" class="dropdown-menu">
# <li>
# <a class="dropdown-item" href="/documentation">Documentation</a>
# </li>
# <li>
# <a class="dropdown-item" href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a class="dropdown-item" href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a class="dropdown-item" href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu1 install-extension" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
# <i aria-hidden="true" class="browser-icon ws-icon ws-icon-chrome-500"></i>
# 							Install
# 						</a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu2" href="https://cloud.webscraper.io/">Cloud Login</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </header>
# <div class="wrapper">
# <div class="formenu-here container-fluid">
# </div>
# <div class="container-fluid blog-hero">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h1>Test Sites</h1>
# </div>
# </div>
# </div>
# </div>
# <div class="container test-site">
# <div class="row">
# <div class="col-lg-3 sidebar">
# <div class="navbar-light sidebar" role="navigation">
# <div class="sidebar-nav navbar-collapse">
# <ul class="nav flex-column" id="side-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a class="nav-link" href="/test-sites/e-commerce/ajax" itemprop="url"><span itemprop="name">Home</span></a>
# </li>
# <li class="nav-item active">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/ajax/computers" itemprop="url">
# <span itemprop="name">Computers</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# <ul class="nav nav-second-level" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link active" href="/test-sites/e-commerce/ajax/computers/laptops" itemprop="url">
# <span itemprop="name">Laptops</span>
# </a>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link" href="/test-sites/e-commerce/ajax/computers/tablets" itemprop="url">
# <span itemprop="name">Tablets</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/ajax/phones" itemprop="url">
# <span itemprop="name">Phones</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-lg-9">
# <h1 class="page-header">Computers / Laptops</h1>
# <div class="row ecomerce-items ecomerce-items-ajax" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD,  ...
# <div class="btn-group pagination justify-content-center" role="group">
# <button class="btn btn-default page-link page btn-primary active" data-id="1" type="button">1</button>
# <button class="btn btn-default page-link page" data-id="2" type="button">2</button>
# <button class="btn btn-default page-link page" data-id="3" type="button">3</button>
# <button class="btn btn-default page-link page" data-id="4" type="button">4</button>
# <button class="btn btn-default page-link page" data-id="5" type="button">5</button>
# <button class="btn btn-default page-link page" data-id="6" type="button">6</button>
# <button class="btn btn-default page-link page" data-id="7" type="button">7</button>
# <button class="btn btn-default page-link page" data-id="8" type="button">8</button>
# <button class="btn btn-default page-link page" data-id="9" type="button">9</button>
# <button class="btn btn-default page-link page" data-id="10" type="button">10</button>
# <button class="btn btn-default page-link page" data-id="11" type="button">11</button>
# <button class="btn btn-default page-link page" data-id="12" type="button">12</button>
# <button class="btn btn-default page-link page" data-id="13" type="button">13</button>
# <button class="btn btn-default page-link page" data-id="14" type="button">14</button>
# <button class="btn btn-default page-link page" data-id="15" type="button">15</button>
# <button class="btn btn-default page-link page" data-id="16" type="button">16</button>
# <button class="btn btn-default page-link page" data-id="17" type="button">17</button>
# <button class="btn btn-default page-link page" data-id="18" type="button">18</button>
# <button class="btn btn-default page-link page" data-id="19" type="button">19</button>
# <button class="btn btn-default page-link page" data-id="20" type="button">20</button>
# </div>
# <div class="pager">
# <button class="btn btn-default previous" disabled="" type="button">&lt; Previous</button>
# <button class="btn btn-default next" type="button">Next &gt;</button>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="push"></div>
# </div>
# <div class="container-fluid footer" id="layout-footer">
# <div class="container">
# <div class="row">
# <div class="col-lg-3">
# <ul>
# <li><p>Products</p></li>
# <li>
# <a class="install-extension" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
# 							Web Scraper browser extension
# 						</a>
# </li>
# <li>
# <a href="/cloud-scraper">Web Scraper Cloud</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Company</p></li>
# <li>
# <a href="/about-us">About us</a>
# </li>
# <li>
# <a href="/contact">Contact</a>
# </li>
# <li>
# <a href="/privacy-policy">Website Privacy Policy</a>
# </li>
# <li>
# <a href="/extension-privacy-policy">Browser Extension Privacy Policy</a>
# </li>
# <li>
# <a href="https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip">Media kit</a>
# </li>
# <li><a href="/jobs">Jobs</a></li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Resources</p></li>
# <li><a href="/blog">Blog</a></li>
# <li>
# <a href="/documentation">Documentation</a>
# </li>
# <li>
# <a href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a href="/screenshots">Screenshots</a>
# </li>
# <li>
# <a href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# <li>
# <a href="https://status.webscraper.io/" rel="noopener" target="_blank">Status</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>CONTACT US</p></li>
# <li>
# <a href="mailto:info@webscraper.io">info@webscraper.io</a>
# </li>
# <li>Ubelu 5-71,<br/> Adazi, Latvia, LV-2164</li>
# </ul>
# <ul class="smedia">
# <li>
# <a aria-label="Web Scraper on Facebook" href="https://www.facebook.com/webscraperio/" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-facebook-f"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on LinkedIn" href="https://lv.linkedin.com/company/web-scraper" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-linkedin"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on Youtube" href="https://youtube.com/@WebScraper/videos" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-youtube"></i>
# </a>
# </li>
# <li>
# <a aria-label="Download the Web Scraper extension" class="install-extension browser-icon-dark" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
# <i class="browser-icon ws-icon ws-icon-chrome-dark"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-12">
# <p class="copyright">Copyright © 2025
# 					<b>Web Scraper</b> | All rights reserved</p>
# </div>
# </div>
# </div>
# </div><iframe height="0" style="display: none; visibility: hidden;" width="0"></iframe>
# <div id="cookieBanner" style="opacity: 0; display: none; transition: opacity 0.2s;"><div id="closeCookieBanner">x</div>We use cookies to make your Web Scraper experience better. Read our <a href="/privacy-policy">Privacy Policy</a>. <div class="acceptContainer"><button class="acceptCookies">Accept &amp; Continue</button></div></div></body></html>

# %%
all_products = main_div.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")
all_products
len(all_products)
# Out:
# 6

# %%
list = []
for i in all_products[0:6]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
    }
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
list
# Out:
# [{'product_name': 'Asus VivoBook X4',
#   'product_link': '/test-sites/e-commerce/ajax/product/60',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$295.99',
#   'product_details': 'Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd',
#   'product_reviews_number': '1 reviews',
#   'product_reviews_star_number': ''},
#  {'product_name': 'Prestigio SmartB',
#   'product_link': '/test-sites/e-commerce/ajax/product/61',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$299',
#   'product_details': 'Prestigio SmartBook 133S Dark Grey, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam',
#   'product_reviews_number': '9 reviews',
#   'product_reviews_star_number': ''},
#  {'product_name': 'Prestigio SmartB',
#   'product_link': '/test-sites/e-commerce/ajax/product/62',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$299',
#   'product_details': 'Prestigio SmartBook 133S Gold, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam',
#   'product_reviews_number': '9 reviews',
#   'product_reviews_star_number': ''},
#  {'product_name': 'Aspire E1-510',
#   'product_link': '/test-sites/e-commerce/ajax/product/32',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$306.99',
#   'product_details': '15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux',
#   'product_reviews_number': '2 reviews',
#   'product_reviews_star_number': ''},
#  {'product_name': 'Lenovo V110-15IA',
#   'product_link': '/test-sites/e-commerce/ajax/product/63',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$321.94',
#   'product_details': 'Lenovo V110-15IAP, 15.6" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home',
#   'product_reviews_number': '12 reviews',
#   'product_reviews_star_number': ''},
#  {'product_name': 'Lenovo V110-15IA',
#   'product_link': '/test-sites/e-commerce/ajax/product/64',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$356.49',
#   'product_details': 'Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd',
#   'product_reviews_number': '12 reviews',
#   'product_reviews_star_number': ''}]

# %%
import pandas as pd 
df = pd.DataFrame(list)
df
df.to_csv('webscraper q4_3.csv',index=False)

# %% [markdown]
# ## 4.4 Extract all product details from second page & save into another csv file.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Edge()
driver.get("https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops?page=")

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
soup
# Out:
# <html lang="en"><head>
# <!-- Google Tag Manager -->
# <script async="" nonce="" src="https://www.googletagmanager.com/gtag/js?id=G-Q9KY1T6XJQ&amp;cx=c&amp;gtm=4e5bi1" type="text/javascript"></script><script async="" nonce="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NVFPDWB"></script><script nonce="">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>Ajax | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." name="description"/>
# <link href="/favicon.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="/favicon.ico" rel="icon" sizes="16x16 32x32" type="image/x-icon"/>
# <link href="/logo-icon.png" rel="apple-touch-icon" type="image/png"/>
# <link href="/icon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;600&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700;800;900&amp;display=swap" rel="stylesheet"/>
# <link href="/css/app.css?id=37e354cd0cf06349d7ad09f2f5065e98" rel="stylesheet"/>
# <link href="/css/ws-icons.font.css?id=d8505f3d910cc64df752f712c8032fdb" rel="stylesheet"/>
# <link href="https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops?page=" rel="canonical"/>
# <meta content="Ajax | Web Scraper Test Sites" property="og:title"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops?page=" property="og:url"/>
# <meta content="https://webscraper.io/webscraper-logo-header.png" property="og:image"/>
# <script defer="" src="/js/app.js?id=08b634a892b70c890a9c8f6190db952b"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVFPDWB" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header class="navbar fixed-top navbar-expand-lg navbar-dark navbar-static svg-background" id="navbar-top" role="banner">
# <div class="container">
# <div class="navbar-header">
# <a data-bs-target=".side-collapse" data-bs-target-2=".side-collapse-container" data-bs-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggler float-end collapsed" data-bs-target="#navbar" data-bs-target-2=".side-collapse-container" data-bs-target-3=".side-collapse" data-bs-toggle="collapse" type="button">
# <span class="visually-hidden">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# <span class="icon-bar extra-bottom-bar"></span>
# </button>
# </a>
# <div class="navbar-brand">
# <a href="/"><img alt="Web Scraper" height="50px" src="/img/logo_white.svg" width="150px"/></a>
# </div>
# </div>
# <div class="side-collapse in">
# <nav class="navbar-collapse collapse" id="navbar" role="navigation">
# <ul class="nav navbar-nav navbar-right">
# <li class="nav-item">
# <a class="nav-link menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/cloud-scraper" id="cloud-nav-link">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/pricing" id="pricing-nav-link">
# <p>Pricing</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item dropdown">
# <button aria-expanded="false" aria-haspopup="true" class="menuitm nav-link dropdown-toggle" data-bs-toggle="dropdown" id="dropdownMenuLink" role="button">
# <p>
# 								Learn
# 								<i class="ws-icon ws-icon-down"></i>
# </p>
# <span class="crta"></span>
# </button>
# <ul aria-labelledby="dropdownMenuLink" class="dropdown-menu">
# <li>
# <a class="dropdown-item" href="/documentation">Documentation</a>
# </li>
# <li>
# <a class="dropdown-item" href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a class="dropdown-item" href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a class="dropdown-item" href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu1 install-extension" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
# <i aria-hidden="true" class="browser-icon ws-icon ws-icon-chrome-500"></i>
# 							Install
# 						</a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu2" href="https://cloud.webscraper.io/">Cloud Login</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </header>
# <div class="wrapper">
# <div class="formenu-here container-fluid">
# </div>
# <div class="container-fluid blog-hero">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h1>Test Sites</h1>
# </div>
# </div>
# </div>
# </div>
# <div class="container test-site">
# <div class="row">
# <div class="col-lg-3 sidebar">
# <div class="navbar-light sidebar" role="navigation">
# <div class="sidebar-nav navbar-collapse">
# <ul class="nav flex-column" id="side-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a class="nav-link" href="/test-sites/e-commerce/ajax" itemprop="url"><span itemprop="name">Home</span></a>
# </li>
# <li class="nav-item active">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/ajax/computers" itemprop="url">
# <span itemprop="name">Computers</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# <ul class="nav nav-second-level" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link active" href="/test-sites/e-commerce/ajax/computers/laptops" itemprop="url">
# <span itemprop="name">Laptops</span>
# </a>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link" href="/test-sites/e-commerce/ajax/computers/tablets" itemprop="url">
# <span itemprop="name">Tablets</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/ajax/phones" itemprop="url">
# <span itemprop="name">Phones</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-lg-9">
# <h1 class="page-header">Computers / Laptops</h1>
# <div class="row ecomerce-items ecomerce-items-ajax" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD,  ...
# <div class="btn-group pagination justify-content-center" role="group">
# <button class="btn btn-default page-link page btn-primary active" data-id="1" type="button">1</button>
# <button class="btn btn-default page-link page" data-id="2" type="button">2</button>
# <button class="btn btn-default page-link page" data-id="3" type="button">3</button>
# <button class="btn btn-default page-link page" data-id="4" type="button">4</button>
# <button class="btn btn-default page-link page" data-id="5" type="button">5</button>
# <button class="btn btn-default page-link page" data-id="6" type="button">6</button>
# <button class="btn btn-default page-link page" data-id="7" type="button">7</button>
# <button class="btn btn-default page-link page" data-id="8" type="button">8</button>
# <button class="btn btn-default page-link page" data-id="9" type="button">9</button>
# <button class="btn btn-default page-link page" data-id="10" type="button">10</button>
# <button class="btn btn-default page-link page" data-id="11" type="button">11</button>
# <button class="btn btn-default page-link page" data-id="12" type="button">12</button>
# <button class="btn btn-default page-link page" data-id="13" type="button">13</button>
# <button class="btn btn-default page-link page" data-id="14" type="button">14</button>
# <button class="btn btn-default page-link page" data-id="15" type="button">15</button>
# <button class="btn btn-default page-link page" data-id="16" type="button">16</button>
# <button class="btn btn-default page-link page" data-id="17" type="button">17</button>
# <button class="btn btn-default page-link page" data-id="18" type="button">18</button>
# <button class="btn btn-default page-link page" data-id="19" type="button">19</button>
# <button class="btn btn-default page-link page" data-id="20" type="button">20</button>
# </div>
# <div class="pager">
# <button class="btn btn-default previous" disabled="" type="button">&lt; Previous</button>
# <button class="btn btn-default next" type="button">Next &gt;</button>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="push"></div>
# </div>
# <div class="container-fluid footer" id="layout-footer">
# <div class="container">
# <div class="row">
# <div class="col-lg-3">
# <ul>
# <li><p>Products</p></li>
# <li>
# <a class="install-extension" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
# 							Web Scraper browser extension
# 						</a>
# </li>
# <li>
# <a href="/cloud-scraper">Web Scraper Cloud</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Company</p></li>
# <li>
# <a href="/about-us">About us</a>
# </li>
# <li>
# <a href="/contact">Contact</a>
# </li>
# <li>
# <a href="/privacy-policy">Website Privacy Policy</a>
# </li>
# <li>
# <a href="/extension-privacy-policy">Browser Extension Privacy Policy</a>
# </li>
# <li>
# <a href="https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip">Media kit</a>
# </li>
# <li><a href="/jobs">Jobs</a></li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Resources</p></li>
# <li><a href="/blog">Blog</a></li>
# <li>
# <a href="/documentation">Documentation</a>
# </li>
# <li>
# <a href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a href="/screenshots">Screenshots</a>
# </li>
# <li>
# <a href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# <li>
# <a href="https://status.webscraper.io/" rel="noopener" target="_blank">Status</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>CONTACT US</p></li>
# <li>
# <a href="mailto:info@webscraper.io">info@webscraper.io</a>
# </li>
# <li>Ubelu 5-71,<br/> Adazi, Latvia, LV-2164</li>
# </ul>
# <ul class="smedia">
# <li>
# <a aria-label="Web Scraper on Facebook" href="https://www.facebook.com/webscraperio/" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-facebook-f"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on LinkedIn" href="https://lv.linkedin.com/company/web-scraper" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-linkedin"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on Youtube" href="https://youtube.com/@WebScraper/videos" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-youtube"></i>
# </a>
# </li>
# <li>
# <a aria-label="Download the Web Scraper extension" class="install-extension browser-icon-dark" href="https://chromewebstore.google.com/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" rel="noopener" target="_blank">
# <i class="browser-icon ws-icon ws-icon-chrome-dark"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-12">
# <p class="copyright">Copyright © 2025
# 					<b>Web Scraper</b> | All rights reserved</p>
# </div>
# </div>
# </div>
# </div>
# <iframe height="0" style="display: none; visibility: hidden;" width="0"></iframe><div id="cookieBanner" style="opacity: 1; display: block; transition: opacity 0.2s;"><div id="closeCookieBanner">x</div>We use cookies to make your Web Scraper experience better. Read our <a href="/privacy-policy">Privacy Policy</a>. <div class="acceptContainer"><button class="acceptCookies">Accept &amp; Continue</button></div></div></body></html>

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd 

driver = webdriver.Edge() # to get webdriver to edge
url= ("https://webscraper.io/test-sites/e-commerce/ajax/computers/laptops") # to get the url 
driver.get(url)
for j in range(2): 
    driver.find_element("xpath",f'//div[@class={j}]').click() # difrent file are element to chcek and click to  secand wibsite
    print(j) # print j this is all wibsite data
    time.sleep(3) # this a timer 
    soup = BeautifulSoup(driver.page_source, 'html.parser') # to website html code 
    
    for i in all_products:
            prod_dictionary = {
                'product_name': '',
                'product_link': '',
                'product_img': '',
                'product_price': '',
                'product_details': '',
                'product_reviews_number': '',
                'product_reviews_star_number': '',
            }
            prod_dictionary['product_name']= i.find('a').text.strip()
            prod_dictionary['product_details']=i.find('p').text
            prod_dictionary['product_img']=i.find('img')['src']
            prod_dictionary['product_link']=i.find('a')['href']
            prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
            prod_dictionary['product_reviews_star_number']
            prod_dictionary['product_price']=i.find('h4').text.strip()
            list.append(prod_dictionary)
            df = pd.DataFrame(list) # to convert to data frame 
            df
            df.to_csv(f'scrapthisside q4_4{j}.csv',index=False)# to save into csv file 
            df
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[5], line 10
#       8 driver.get(url)
#       9 for j in range(2):
# ---> 10     driver.find_element("xpath",f'//a[@class={j}]').click() # difrent file are element to chcek and click to  secand wibsite
#      11     print(j) # print j this is all wibsite data
#      12     time.sleep(3) # this a timer
#
# File c:\Users\T460\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\T460\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File c:\Users\T460\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//a[@class=0]"}
#   (Session info: MicrosoftEdge=142.0.3595.94); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff603afa715
# 	0x7ff603afa774
# 	0x7ff603cac558
# 	0x7ff6038b40ce
# 	0x7ff6038b431b
# 	0x7ff6038f0777
# 	0x7ff6038ab3d5
# 	0x7ff6038ee6f2
# 	0x7ff6038aa8aa
# 	0x7ff6038a9bd1
# 	0x7ff6038aa6d3
# 	0x7ff6039681f4
# 	0x7ff603964717
# 	0x7ff603b27375
# 	0x7ff603b157d1
# 	0x7ff603b1dc79
# 	0x7ff603b01c64
# 	0x7ff603b01db3
# 	0x7ff603aefae6
# 	0x7ff89f457374
# 	0x7ff89fb9cc91

# %%
driver.find_elements("xpath",f'//div[@class="btn-group pagination justify-content-center"]')[0]
driver
# Out:
# <selenium.webdriver.edge.webdriver.WebDriver (session="357b679e23760098e22bb93fe927b9c5")>

# %% [markdown]
# ## 5.1 Extract first product details save into csv file. e.g# Asus VivoBook X4

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Edge()

driver.get("https://webscraper.io/test-sites/e-commerce/more/computers/laptops")

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
soup
# Out:
# <html lang="en"><head>
# <!-- Google Tag Manager -->
# <script async="" nonce="" src="https://www.googletagmanager.com/gtag/js?id=G-Q9KY1T6XJQ&amp;cx=c&amp;gtm=4e5bi1h1" type="text/javascript"></script><script async="" nonce="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NVFPDWB"></script><script nonce="">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>More | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." name="description"/>
# <link href="/favicon.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="/favicon.ico" rel="icon" sizes="16x16 32x32" type="image/x-icon"/>
# <link href="/logo-icon.png" rel="apple-touch-icon" type="image/png"/>
# <link href="/icon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;600&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700;800;900&amp;display=swap" rel="stylesheet"/>
# <link href="/css/app.css?id=37e354cd0cf06349d7ad09f2f5065e98" rel="stylesheet"/>
# <link href="/css/ws-icons.font.css?id=d8505f3d910cc64df752f712c8032fdb" rel="stylesheet"/>
# <link href="https://webscraper.io/test-sites/e-commerce/more/computers/laptops" rel="canonical"/>
# <meta content="More | Web Scraper Test Sites" property="og:title"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://webscraper.io/test-sites/e-commerce/more/computers/laptops" property="og:url"/>
# <meta content="https://webscraper.io/webscraper-logo-header.png" property="og:image"/>
# <script defer="" src="/js/app.js?id=08b634a892b70c890a9c8f6190db952b"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVFPDWB" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header class="navbar fixed-top navbar-expand-lg navbar-dark navbar-static svg-background" id="navbar-top" role="banner">
# <div class="container">
# <div class="navbar-header">
# <a data-bs-target=".side-collapse" data-bs-target-2=".side-collapse-container" data-bs-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggler float-end collapsed" data-bs-target="#navbar" data-bs-target-2=".side-collapse-container" data-bs-target-3=".side-collapse" data-bs-toggle="collapse" type="button">
# <span class="visually-hidden">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# <span class="icon-bar extra-bottom-bar"></span>
# </button>
# </a>
# <div class="navbar-brand">
# <a href="/"><img alt="Web Scraper" height="50px" src="/img/logo_white.svg" width="150px"/></a>
# </div>
# </div>
# <div class="side-collapse in">
# <nav class="navbar-collapse collapse" id="navbar" role="navigation">
# <ul class="nav navbar-nav navbar-right">
# <li class="nav-item">
# <a class="nav-link menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/cloud-scraper" id="cloud-nav-link">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/pricing" id="pricing-nav-link">
# <p>Pricing</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item dropdown">
# <button aria-expanded="false" aria-haspopup="true" class="menuitm nav-link dropdown-toggle" data-bs-toggle="dropdown" id="dropdownMenuLink" role="button">
# <p>
# 								Learn
# 								<i class="ws-icon ws-icon-down"></i>
# </p>
# <span class="crta"></span>
# </button>
# <ul aria-labelledby="dropdownMenuLink" class="dropdown-menu">
# <li>
# <a class="dropdown-item" href="/documentation">Documentation</a>
# </li>
# <li>
# <a class="dropdown-item" href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a class="dropdown-item" href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a class="dropdown-item" href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu1 install-extension" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# <i aria-hidden="true" class="browser-icon ws-icon ws-icon-edge-500 ws-icon-edge-dark"></i>
# 							Install
# 						</a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu2" href="https://cloud.webscraper.io/">Cloud Login</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </header>
# <div class="wrapper">
# <div class="formenu-here container-fluid">
# </div>
# <div class="container-fluid blog-hero">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h1>Test Sites</h1>
# </div>
# </div>
# </div>
# </div>
# <div class="container test-site">
# <div class="row">
# <div class="col-lg-3 sidebar">
# <div class="navbar-light sidebar" role="navigation">
# <div class="sidebar-nav navbar-collapse">
# <ul class="nav flex-column" id="side-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a class="nav-link" href="/test-sites/e-commerce/more" itemprop="url"><span itemprop="name">Home</span></a>
# </li>
# <li class="nav-item active">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/more/computers" itemprop="url">
# <span itemprop="name">Computers</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# <ul class="nav nav-second-level" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link active" href="/test-sites/e-commerce/more/computers/laptops" itemprop="url">
# <span itemprop="name">Laptops</span>
# </a>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link" href="/test-sites/e-commerce/more/computers/tablets" itemprop="url">
# <span itemprop="name">Tablets</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/more/phones" itemprop="url">
# <span itemprop="name">Phones</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-lg-9">
# <h1 class="page-header">Computers / Laptops</h1>
# <div class="row ecomerce-items ecomerce-items-more" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD,  ...
# <a class="btn btn-lg btn-block btn-primary ecomerce-items-scroll-more">More</a>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="push"></div>
# </div>
# <div class="container-fluid footer" id="layout-footer">
# <div class="container">
# <div class="row">
# <div class="col-lg-3">
# <ul>
# <li><p>Products</p></li>
# <li>
# <a class="install-extension" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# 							Web Scraper browser extension
# 						</a>
# </li>
# <li>
# <a href="/cloud-scraper">Web Scraper Cloud</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Company</p></li>
# <li>
# <a href="/about-us">About us</a>
# </li>
# <li>
# <a href="/contact">Contact</a>
# </li>
# <li>
# <a href="/privacy-policy">Website Privacy Policy</a>
# </li>
# <li>
# <a href="/extension-privacy-policy">Browser Extension Privacy Policy</a>
# </li>
# <li>
# <a href="https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip">Media kit</a>
# </li>
# <li><a href="/jobs">Jobs</a></li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Resources</p></li>
# <li><a href="/blog">Blog</a></li>
# <li>
# <a href="/documentation">Documentation</a>
# </li>
# <li>
# <a href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a href="/screenshots">Screenshots</a>
# </li>
# <li>
# <a href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# <li>
# <a href="https://status.webscraper.io/" rel="noopener" target="_blank">Status</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>CONTACT US</p></li>
# <li>
# <a href="mailto:info@webscraper.io">info@webscraper.io</a>
# </li>
# <li>Ubelu 5-71,<br/> Adazi, Latvia, LV-2164</li>
# </ul>
# <ul class="smedia">
# <li>
# <a aria-label="Web Scraper on Facebook" href="https://www.facebook.com/webscraperio/" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-facebook-f"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on LinkedIn" href="https://lv.linkedin.com/company/web-scraper" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-linkedin"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on Youtube" href="https://youtube.com/@WebScraper/videos" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-youtube"></i>
# </a>
# </li>
# <li>
# <a aria-label="Download the Web Scraper extension" class="install-extension browser-icon-dark" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# <i class="browser-icon ws-icon ws-icon-edge-500 ws-icon-edge-dark"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-12">
# <p class="copyright">Copyright © 2025
# 					<b>Web Scraper</b> | All rights reserved</p>
# </div>
# </div>
# </div>
# </div>
# <iframe height="0" style="display: none; visibility: hidden;" width="0"></iframe><div id="cookieBanner" style="opacity: 1; display: block; transition: opacity 0.2s;"><div id="closeCookieBanner">x</div>We use cookies to make your Web Scraper experience better. Read our <a href="/privacy-policy">Privacy Policy</a>. <div class="acceptContainer"><button class="acceptCookies">Accept &amp; Continue</button></div></div></body></html>

# %%
product = soup.find('div',class_='product-wrapper card-body')
product
# Out:
# <div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$295.99</h4><h4><a class="title" href="/test-sites/e-commerce/more/product/60" itemprop="name" title="Asus VivoBook X441NA-GA190">Asus VivoBook X4</a></h4><p class="card-text description" itemprop="description">Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">1</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div>

# %%
list = []
prod_dictionary = {
    'product_name': '',
    'product_link': '',
    'product_img': '',
    'product_price': '',
    'product_details': '',
    'product_reviews_number': '',
    'product_reviews_star_number': '',
}

# %%
prod_dictionary['product_name']= product.find('a').text.strip()
prod_dictionary['product_details']=product.find('p').text
prod_dictionary['product_img']=product.find('img')['src']
prod_dictionary['product_link']=product.find('a')['href']
prod_dictionary['product_reviews_number']=product.find('div',class_='ratings').text.strip()
prod_dictionary['product_reviews_star_number']
prod_dictionary['product_price']=product.find('h4').text.strip()
list.append(prod_dictionary)

# %%
list
# Out:
# [{'product_name': 'Asus VivoBook X4',
#   'product_link': '/test-sites/e-commerce/more/product/60',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$295.99',
#   'product_details': 'Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd',
#   'product_reviews_number': '1 reviews',
#   'product_reviews_star_number': ''}]

# %%
import pandas as pd
df = pd.DataFrame(list)
df
df.to_csv('webscraper io 5_1.csv',index=False)

# %% [markdown]
# ## 5.2 Extract product details from first row & save into csv file. e.g# Asus VivoBook X4, Prestigio SmartB , Asus VivoBook X4

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Edge()
driver.get("https://webscraper.io/test-sites/e-commerce/more/computers/laptops")


soup = BeautifulSoup(driver.page_source, 'html.parser')
soup
# Out:
# <html lang="en"><head>
# <!-- Google Tag Manager -->
# <script async="" nonce="" src="https://www.googletagmanager.com/gtag/js?id=G-Q9KY1T6XJQ&amp;cx=c&amp;gtm=4e5bj0h2" type="text/javascript"></script><script async="" nonce="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NVFPDWB"></script><script nonce="">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>More | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." name="description"/>
# <link href="/favicon.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="/favicon.ico" rel="icon" sizes="16x16 32x32" type="image/x-icon"/>
# <link href="/logo-icon.png" rel="apple-touch-icon" type="image/png"/>
# <link href="/icon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;600&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700;800;900&amp;display=swap" rel="stylesheet"/>
# <link href="/css/app.css?id=37e354cd0cf06349d7ad09f2f5065e98" rel="stylesheet"/>
# <link href="/css/ws-icons.font.css?id=d8505f3d910cc64df752f712c8032fdb" rel="stylesheet"/>
# <link href="https://webscraper.io/test-sites/e-commerce/more/computers/laptops" rel="canonical"/>
# <meta content="More | Web Scraper Test Sites" property="og:title"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://webscraper.io/test-sites/e-commerce/more/computers/laptops" property="og:url"/>
# <meta content="https://webscraper.io/webscraper-logo-header.png" property="og:image"/>
# <script defer="" src="/js/app.js?id=08b634a892b70c890a9c8f6190db952b"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVFPDWB" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header class="navbar fixed-top navbar-expand-lg navbar-dark navbar-static svg-background" id="navbar-top" role="banner">
# <div class="container">
# <div class="navbar-header">
# <a data-bs-target=".side-collapse" data-bs-target-2=".side-collapse-container" data-bs-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggler float-end collapsed" data-bs-target="#navbar" data-bs-target-2=".side-collapse-container" data-bs-target-3=".side-collapse" data-bs-toggle="collapse" type="button">
# <span class="visually-hidden">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# <span class="icon-bar extra-bottom-bar"></span>
# </button>
# </a>
# <div class="navbar-brand">
# <a href="/"><img alt="Web Scraper" height="50px" src="/img/logo_white.svg" width="150px"/></a>
# </div>
# </div>
# <div class="side-collapse in">
# <nav class="navbar-collapse collapse" id="navbar" role="navigation">
# <ul class="nav navbar-nav navbar-right">
# <li class="nav-item">
# <a class="nav-link menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/cloud-scraper" id="cloud-nav-link">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/pricing" id="pricing-nav-link">
# <p>Pricing</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item dropdown">
# <button aria-expanded="false" aria-haspopup="true" class="menuitm nav-link dropdown-toggle" data-bs-toggle="dropdown" id="dropdownMenuLink" role="button">
# <p>
# 								Learn
# 								<i class="ws-icon ws-icon-down"></i>
# </p>
# <span class="crta"></span>
# </button>
# <ul aria-labelledby="dropdownMenuLink" class="dropdown-menu">
# <li>
# <a class="dropdown-item" href="/documentation">Documentation</a>
# </li>
# <li>
# <a class="dropdown-item" href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a class="dropdown-item" href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a class="dropdown-item" href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu1 install-extension" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# <i aria-hidden="true" class="browser-icon ws-icon ws-icon-edge-500 ws-icon-edge-dark"></i>
# 							Install
# 						</a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu2" href="https://cloud.webscraper.io/">Cloud Login</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </header>
# <div class="wrapper">
# <div class="formenu-here container-fluid">
# </div>
# <div class="container-fluid blog-hero">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h1>Test Sites</h1>
# </div>
# </div>
# </div>
# </div>
# <div class="container test-site">
# <div class="row">
# <div class="col-lg-3 sidebar">
# <div class="navbar-light sidebar" role="navigation">
# <div class="sidebar-nav navbar-collapse">
# <ul class="nav flex-column" id="side-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a class="nav-link" href="/test-sites/e-commerce/more" itemprop="url"><span itemprop="name">Home</span></a>
# </li>
# <li class="nav-item active">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/more/computers" itemprop="url">
# <span itemprop="name">Computers</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# <ul class="nav nav-second-level" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link active" href="/test-sites/e-commerce/more/computers/laptops" itemprop="url">
# <span itemprop="name">Laptops</span>
# </a>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link" href="/test-sites/e-commerce/more/computers/tablets" itemprop="url">
# <span itemprop="name">Tablets</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/more/phones" itemprop="url">
# <span itemprop="name">Phones</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-lg-9">
# <h1 class="page-header">Computers / Laptops</h1>
# <div class="row ecomerce-items ecomerce-items-more" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD,  ...
# <a class="btn btn-lg btn-block btn-primary ecomerce-items-scroll-more">More</a>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="push"></div>
# </div>
# <div class="container-fluid footer" id="layout-footer">
# <div class="container">
# <div class="row">
# <div class="col-lg-3">
# <ul>
# <li><p>Products</p></li>
# <li>
# <a class="install-extension" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# 							Web Scraper browser extension
# 						</a>
# </li>
# <li>
# <a href="/cloud-scraper">Web Scraper Cloud</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Company</p></li>
# <li>
# <a href="/about-us">About us</a>
# </li>
# <li>
# <a href="/contact">Contact</a>
# </li>
# <li>
# <a href="/privacy-policy">Website Privacy Policy</a>
# </li>
# <li>
# <a href="/extension-privacy-policy">Browser Extension Privacy Policy</a>
# </li>
# <li>
# <a href="https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip">Media kit</a>
# </li>
# <li><a href="/jobs">Jobs</a></li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Resources</p></li>
# <li><a href="/blog">Blog</a></li>
# <li>
# <a href="/documentation">Documentation</a>
# </li>
# <li>
# <a href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a href="/screenshots">Screenshots</a>
# </li>
# <li>
# <a href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# <li>
# <a href="https://status.webscraper.io/" rel="noopener" target="_blank">Status</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>CONTACT US</p></li>
# <li>
# <a href="mailto:info@webscraper.io">info@webscraper.io</a>
# </li>
# <li>Ubelu 5-71,<br/> Adazi, Latvia, LV-2164</li>
# </ul>
# <ul class="smedia">
# <li>
# <a aria-label="Web Scraper on Facebook" href="https://www.facebook.com/webscraperio/" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-facebook-f"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on LinkedIn" href="https://lv.linkedin.com/company/web-scraper" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-linkedin"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on Youtube" href="https://youtube.com/@WebScraper/videos" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-youtube"></i>
# </a>
# </li>
# <li>
# <a aria-label="Download the Web Scraper extension" class="install-extension browser-icon-dark" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# <i class="browser-icon ws-icon ws-icon-edge-500 ws-icon-edge-dark"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-12">
# <p class="copyright">Copyright © 2025
# 					<b>Web Scraper</b> | All rights reserved</p>
# </div>
# </div>
# </div>
# </div>
# <iframe height="0" style="display: none; visibility: hidden;" width="0"></iframe><div id="cookieBanner" style="opacity: 1; display: block; transition: opacity 0.2s;"><div id="closeCookieBanner">x</div>We use cookies to make your Web Scraper experience better. Read our <a href="/privacy-policy">Privacy Policy</a>. <div class="acceptContainer"><button class="acceptCookies">Accept &amp; Continue</button></div></div></body></html>

# %%
products = soup.find_all('div',class_='row')
products
# Out:
# [<div class="row">
#  <div class="col-lg-12">
#  <h1>Test Sites</h1>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-lg-3 sidebar">
#  <div class="navbar-light sidebar" role="navigation">
#  <div class="sidebar-nav navbar-collapse">
#  <ul class="nav flex-column" id="side-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
#  <li class="nav-item">
#  <a class="nav-link" href="/test-sites/e-commerce/more" itemprop="url"><span itemprop="name">Home</span></a>
#  </li>
#  <li class="nav-item active">
#  <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/more/computers" itemprop="url">
#  <span itemprop="name">Computers</span>
#  <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
#  </a>
#  <ul class="nav nav-second-level" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
#  <li class="nav-item">
#  <a aria-label="Navigation subcategory" class="nav-link subcategory-link active" href="/test-sites/e-commerce/more/computers/laptops" itemprop="url">
#  <span itemprop="name">Laptops</span>
#  </a>
#  </li>
#  <li class="nav-item">
#  <a aria-label="Navigation subcategory" class="nav-link subcategory-link" href="/test-sites/e-commerce/more/computers/tablets" itemprop="url">
#  <span itemprop="name">Tablets</span>
#  </a>
#  </li>
#  </ul>
#  </li>
#  <li class="nav-item">
#  <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/more/phones" itemprop="url">
#  <span itemprop="name">Phones</span>
#  <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="col-lg-9">
#  <h1 class="page-header">Computers / Laptops</h1>
#  <div class="row ecomerce-items ecomerce-items-more" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD, ...
#  <a class="btn btn-lg btn-block btn-primary ecomerce-items-scroll-more">More</a>
#  </div>
#  </div>,
#  <div class="row ecomerce-items ecomerce-items-more" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD, ...
#  <div class="row">
#  <div class="col-lg-3">
#  <ul>
#  <li><p>Products</p></li>
#  <li>
#  <a class="install-extension" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
#  							Web Scraper browser extension
#  						</a>
#  </li>
#  <li>
#  <a href="/cloud-scraper">Web Scraper Cloud</a>
#  </li>
#  </ul>
#  </div>
#  <div class="col-lg-3">
#  <ul>
#  <li><p>Company</p></li>
#  <li>
#  <a href="/about-us">About us</a>
#  </li>
#  <li>
#  <a href="/contact">Contact</a>
#  </li>
#  <li>
#  <a href="/privacy-policy">Website Privacy Policy</a>
#  </li>
#  <li>
#  <a href="/extension-privacy-policy">Browser Extension Privacy Policy</a>
#  </li>
#  <li>
#  <a href="https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip">Media kit</a>
#  </li>
#  <li><a href="/jobs">Jobs</a></li>
#  </ul>
#  </div>
#  <div class="col-lg-3">
#  <ul>
#  <li><p>Resources</p></li>
#  <li><a href="/blog">Blog</a></li>
#  <li>
#  <a href="/documentation">Documentation</a>
#  </li>
#  <li>
#  <a href="/tutorials">Video Tutorials</a>
#  </li>
#  <li>
#  <a href="/screenshots">Screenshots</a>
#  </li>
#  <li>
#  <a href="/test-sites">Test Sites</a>
#  </li>
#  <li>
#  <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
#  </li>
#  <li>
#  <a href="https://status.webscraper.io/" rel="noopener" target="_blank">Status</a>
#  </li>
#  </ul>
#  </div>
#  <div class="col-lg-3">
#  <ul>
#  <li><p>CONTACT US</p></li>
#  <li>
#  <a href="mailto:info@webscraper.io">info@webscraper.io</a>
#  </li>
#  <li>Ubelu 5-71,<br/> Adazi, Latvia, LV-2164</li>
#  </ul>
#  <ul class="smedia">
#  <li>
#  <a aria-label="Web Scraper on Facebook" href="https://www.facebook.com/webscraperio/" rel="noopener" target="_blank">
#  <i class="ws-icon ws-icon-facebook-f"></i>
#  </a>
#  </li>
#  <li>
#  <a aria-label="Web Scraper on LinkedIn" href="https://lv.linkedin.com/company/web-scraper" rel="noopener" target="_blank">
#  <i class="ws-icon ws-icon-linkedin"></i>
#  </a>
#  </li>
#  <li>
#  <a aria-label="Web Scraper on Youtube" href="https://youtube.com/@WebScraper/videos" rel="noopener" target="_blank">
#  <i class="ws-icon ws-icon-youtube"></i>
#  </a>
#  </li>
#  <li>
#  <a aria-label="Download the Web Scraper extension" class="install-extension browser-icon-dark" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
#  <i class="browser-icon ws-icon ws-icon-edge-500 ws-icon-edge-dark"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-lg-12">
#  <p class="copyright">Copyright © 2025
#  					<b>Web Scraper</b> | All rights reserved</p>
#  </div>
#  </div>]

# %%
all_products = main_div.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")
all_products
# len(all_products)
# Out:
# [<div class="col-md-4 col-xl-4 col-lg-4"><div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product"><div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$295.99</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/60" itemprop="name" title="Asus VivoBook X441NA-GA190">Asus VivoBook X4</a></h4><p class="card-text description" itemprop="description">Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">1</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div></div></div>,
#  <div class="col-md-4 col-xl-4 col-lg-4"><div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product"><div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$299</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/61" itemprop="name" title="Prestigio SmartBook 133S Dark Grey">Prestigio SmartB</a></h4><p class="card-text description" itemprop="description">Prestigio SmartBook 133S Dark Grey, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">9</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div></div></div>,
#  <div class="col-md-4 col-xl-4 col-lg-4"><div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product"><div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$299</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/62" itemprop="name" title="Prestigio SmartBook 133S Gold">Prestigio SmartB</a></h4><p class="card-text description" itemprop="description">Prestigio SmartBook 133S Gold, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">9</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div></div></div>,
#  <div class="col-md-4 col-xl-4 col-lg-4"><div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product"><div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$306.99</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/32" itemprop="name" title="Aspire E1-510">Aspire E1-510</a></h4><p class="card-text description" itemprop="description">15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">2</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div></div></div>,
#  <div class="col-md-4 col-xl-4 col-lg-4"><div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product"><div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$321.94</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/63" itemprop="name" title="Lenovo V110-15IAP">Lenovo V110-15IA</a></h4><p class="card-text description" itemprop="description">Lenovo V110-15IAP, 15.6" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">12</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div></div></div>,
#  <div class="col-md-4 col-xl-4 col-lg-4"><div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product"><div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$356.49</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/64" itemprop="name" title="Lenovo V110-15IAP">Lenovo V110-15IA</a></h4><p class="card-text description" itemprop="description">Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">12</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div></div></div>]

# %%
list = []
for i in all_products[0:3]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
    }
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
list
# Out:
# [{'product_name': 'Asus VivoBook X4',
#   'product_link': '/test-sites/e-commerce/ajax/product/60',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$295.99',
#   'product_details': 'Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd',
#   'product_reviews_number': '1 reviews',
#   'product_reviews_star_number': ''},
#  {'product_name': 'Prestigio SmartB',
#   'product_link': '/test-sites/e-commerce/ajax/product/61',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$299',
#   'product_details': 'Prestigio SmartBook 133S Dark Grey, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam',
#   'product_reviews_number': '9 reviews',
#   'product_reviews_star_number': ''},
#  {'product_name': 'Prestigio SmartB',
#   'product_link': '/test-sites/e-commerce/ajax/product/62',
#   'product_img': '/images/test-sites/e-commerce/items/cart2.png',
#   'product_price': '$299',
#   'product_details': 'Prestigio SmartBook 133S Gold, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam',
#   'product_reviews_number': '9 reviews',
#   'product_reviews_star_number': ''}]

# %%
import pandas as pd
df = pd.DataFrame(list)
df
df.to_csv('webscraper io 5_2.csv',index=False)

# %% [markdown]
# ## 5.3 Extract all product details from first page & save into csv file.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Edge()
driver.get("https://webscraper.io/test-sites/e-commerce/more/computers/laptops")


soup = BeautifulSoup(driver.page_source, 'html.parser')
soup

# %%
all_products = main_div.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")
all_products
# len(all_products)
# Out:
# [<div class="col-md-4 col-xl-4 col-lg-4"><div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product"><div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$295.99</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/60" itemprop="name" title="Asus VivoBook X441NA-GA190">Asus VivoBook X4</a></h4><p class="card-text description" itemprop="description">Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">1</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div></div></div>,
#  <div class="col-md-4 col-xl-4 col-lg-4"><div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product"><div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$299</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/61" itemprop="name" title="Prestigio SmartBook 133S Dark Grey">Prestigio SmartB</a></h4><p class="card-text description" itemprop="description">Prestigio SmartBook 133S Dark Grey, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">9</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div></div></div>,
#  <div class="col-md-4 col-xl-4 col-lg-4"><div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product"><div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$299</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/62" itemprop="name" title="Prestigio SmartBook 133S Gold">Prestigio SmartB</a></h4><p class="card-text description" itemprop="description">Prestigio SmartBook 133S Gold, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">9</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div></div></div>,
#  <div class="col-md-4 col-xl-4 col-lg-4"><div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product"><div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$306.99</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/32" itemprop="name" title="Aspire E1-510">Aspire E1-510</a></h4><p class="card-text description" itemprop="description">15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">2</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div></div></div>,
#  <div class="col-md-4 col-xl-4 col-lg-4"><div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product"><div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$321.94</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/63" itemprop="name" title="Lenovo V110-15IAP">Lenovo V110-15IA</a></h4><p class="card-text description" itemprop="description">Lenovo V110-15IAP, 15.6" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">12</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div></div></div>,
#  <div class="col-md-4 col-xl-4 col-lg-4"><div class="card thumbnail" itemscope="" itemtype="https://schema.org/Product"><div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$356.49</h4><h4><a class="title" href="/test-sites/e-commerce/ajax/product/64" itemprop="name" title="Lenovo V110-15IAP">Lenovo V110-15IA</a></h4><p class="card-text description" itemprop="description">Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">12</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div></div></div>]

# %%
list = []
for i in all_products[0:6]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
    }
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
import pandas as pd
df = pd.DataFrame(list)
df
df.to_csv('webscraper io 5_3.csv',index=False)
df
# Out:
#        product_name                            product_link  \
# 0  Asus VivoBook X4  /test-sites/e-commerce/ajax/product/60
# 1  Prestigio SmartB  /test-sites/e-commerce/ajax/product/61
# 2  Prestigio SmartB  /test-sites/e-commerce/ajax/product/62
# 3     Aspire E1-510  /test-sites/e-commerce/ajax/product/32
# 4  Lenovo V110-15IA  /test-sites/e-commerce/ajax/product/63
# 5  Lenovo V110-15IA  /test-sites/e-commerce/ajax/product/64
#
#                                      product_img product_price  \
# 0  /images/test-sites/e-commerce/items/cart2.png       $295.99
# 1  /images/test-sites/e-commerce/items/cart2.png          $299
# 2  /images/test-sites/e-commerce/items/cart2.png          $299
# 3  /images/test-sites/e-commerce/items/cart2.png       $306.99
# 4  /images/test-sites/e-commerce/items/cart2.png       $321.94
# 5  /images/test-sites/e-commerce/items/cart2.png       $356.49
#
#                                      product_details product_reviews_number  \
# 0  Asus VivoBook X441NA-GA190 Chocolate Black, 14...              1 reviews
# 1  Prestigio SmartBook 133S Dark Grey, 13.3" FHD ...              9 reviews
# 2  Prestigio SmartBook 133S Gold, 13.3" FHD IPS, ...              9 reviews
# 3    15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux              2 reviews
# 4  Lenovo V110-15IAP, 15.6" HD, Celeron N3350 1.1...             12 reviews
# 5  Asus VivoBook 15 X540NA-GQ008T Chocolate Black...             12 reviews
#
#   product_reviews_star_number
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## 5.3 Extract all product details from first page & save into csv file.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Edge()
driver.get("https://webscraper.io/test-sites/e-commerce/more/computers/laptops")


soup = BeautifulSoup(driver.page_source, 'html.parser')

soup
# Out:
# <html lang="en"><head>
# <!-- Google Tag Manager -->
# <script async="" nonce="" src="https://www.googletagmanager.com/gtag/js?id=G-Q9KY1T6XJQ&amp;cx=c&amp;gtm=4e5bi1" type="text/javascript"></script><script async="" nonce="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NVFPDWB"></script><script nonce="">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>More | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." name="description"/>
# <link href="/favicon.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="/favicon.ico" rel="icon" sizes="16x16 32x32" type="image/x-icon"/>
# <link href="/logo-icon.png" rel="apple-touch-icon" type="image/png"/>
# <link href="/icon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;600&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700;800;900&amp;display=swap" rel="stylesheet"/>
# <link href="/css/app.css?id=37e354cd0cf06349d7ad09f2f5065e98" rel="stylesheet"/>
# <link href="/css/ws-icons.font.css?id=d8505f3d910cc64df752f712c8032fdb" rel="stylesheet"/>
# <link href="https://webscraper.io/test-sites/e-commerce/more/computers/laptops" rel="canonical"/>
# <meta content="More | Web Scraper Test Sites" property="og:title"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://webscraper.io/test-sites/e-commerce/more/computers/laptops" property="og:url"/>
# <meta content="https://webscraper.io/webscraper-logo-header.png" property="og:image"/>
# <script defer="" src="/js/app.js?id=08b634a892b70c890a9c8f6190db952b"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVFPDWB" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header class="navbar fixed-top navbar-expand-lg navbar-dark navbar-static svg-background" id="navbar-top" role="banner">
# <div class="container">
# <div class="navbar-header">
# <a data-bs-target=".side-collapse" data-bs-target-2=".side-collapse-container" data-bs-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggler float-end collapsed" data-bs-target="#navbar" data-bs-target-2=".side-collapse-container" data-bs-target-3=".side-collapse" data-bs-toggle="collapse" type="button">
# <span class="visually-hidden">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# <span class="icon-bar extra-bottom-bar"></span>
# </button>
# </a>
# <div class="navbar-brand">
# <a href="/"><img alt="Web Scraper" height="50px" src="/img/logo_white.svg" width="150px"/></a>
# </div>
# </div>
# <div class="side-collapse in">
# <nav class="navbar-collapse collapse" id="navbar" role="navigation">
# <ul class="nav navbar-nav navbar-right">
# <li class="nav-item">
# <a class="nav-link menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/cloud-scraper" id="cloud-nav-link">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/pricing" id="pricing-nav-link">
# <p>Pricing</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item dropdown">
# <button aria-expanded="false" aria-haspopup="true" class="menuitm nav-link dropdown-toggle" data-bs-toggle="dropdown" id="dropdownMenuLink" role="button">
# <p>
# 								Learn
# 								<i class="ws-icon ws-icon-down"></i>
# </p>
# <span class="crta"></span>
# </button>
# <ul aria-labelledby="dropdownMenuLink" class="dropdown-menu">
# <li>
# <a class="dropdown-item" href="/documentation">Documentation</a>
# </li>
# <li>
# <a class="dropdown-item" href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a class="dropdown-item" href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a class="dropdown-item" href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu1 install-extension" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# <i aria-hidden="true" class="browser-icon ws-icon ws-icon-edge-500 ws-icon-edge-dark"></i>
# 							Install
# 						</a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu2" href="https://cloud.webscraper.io/">Cloud Login</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </header>
# <div class="wrapper">
# <div class="formenu-here container-fluid">
# </div>
# <div class="container-fluid blog-hero">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h1>Test Sites</h1>
# </div>
# </div>
# </div>
# </div>
# <div class="container test-site">
# <div class="row">
# <div class="col-lg-3 sidebar">
# <div class="navbar-light sidebar" role="navigation">
# <div class="sidebar-nav navbar-collapse">
# <ul class="nav flex-column" id="side-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a class="nav-link" href="/test-sites/e-commerce/more" itemprop="url"><span itemprop="name">Home</span></a>
# </li>
# <li class="nav-item active">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/more/computers" itemprop="url">
# <span itemprop="name">Computers</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# <ul class="nav nav-second-level" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link active" href="/test-sites/e-commerce/more/computers/laptops" itemprop="url">
# <span itemprop="name">Laptops</span>
# </a>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link" href="/test-sites/e-commerce/more/computers/tablets" itemprop="url">
# <span itemprop="name">Tablets</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/more/phones" itemprop="url">
# <span itemprop="name">Phones</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-lg-9">
# <h1 class="page-header">Computers / Laptops</h1>
# <div class="row ecomerce-items ecomerce-items-more" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD,  ...
# <a class="btn btn-lg btn-block btn-primary ecomerce-items-scroll-more">More</a>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="push"></div>
# </div>
# <div class="container-fluid footer" id="layout-footer">
# <div class="container">
# <div class="row">
# <div class="col-lg-3">
# <ul>
# <li><p>Products</p></li>
# <li>
# <a class="install-extension" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# 							Web Scraper browser extension
# 						</a>
# </li>
# <li>
# <a href="/cloud-scraper">Web Scraper Cloud</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Company</p></li>
# <li>
# <a href="/about-us">About us</a>
# </li>
# <li>
# <a href="/contact">Contact</a>
# </li>
# <li>
# <a href="/privacy-policy">Website Privacy Policy</a>
# </li>
# <li>
# <a href="/extension-privacy-policy">Browser Extension Privacy Policy</a>
# </li>
# <li>
# <a href="https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip">Media kit</a>
# </li>
# <li><a href="/jobs">Jobs</a></li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Resources</p></li>
# <li><a href="/blog">Blog</a></li>
# <li>
# <a href="/documentation">Documentation</a>
# </li>
# <li>
# <a href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a href="/screenshots">Screenshots</a>
# </li>
# <li>
# <a href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# <li>
# <a href="https://status.webscraper.io/" rel="noopener" target="_blank">Status</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>CONTACT US</p></li>
# <li>
# <a href="mailto:info@webscraper.io">info@webscraper.io</a>
# </li>
# <li>Ubelu 5-71,<br/> Adazi, Latvia, LV-2164</li>
# </ul>
# <ul class="smedia">
# <li>
# <a aria-label="Web Scraper on Facebook" href="https://www.facebook.com/webscraperio/" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-facebook-f"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on LinkedIn" href="https://lv.linkedin.com/company/web-scraper" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-linkedin"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on Youtube" href="https://youtube.com/@WebScraper/videos" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-youtube"></i>
# </a>
# </li>
# <li>
# <a aria-label="Download the Web Scraper extension" class="install-extension browser-icon-dark" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# <i class="browser-icon ws-icon ws-icon-edge-500 ws-icon-edge-dark"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-12">
# <p class="copyright">Copyright © 2025
# 					<b>Web Scraper</b> | All rights reserved</p>
# </div>
# </div>
# </div>
# </div>
# <iframe height="0" style="display: none; visibility: hidden;" width="0"></iframe><div id="cookieBanner" style="opacity: 1; display: block; transition: opacity 0.2s;"><div id="closeCookieBanner">x</div>We use cookies to make your Web Scraper experience better. Read our <a href="/privacy-policy">Privacy Policy</a>. <div class="acceptContainer"><button class="acceptCookies">Accept &amp; Continue</button></div></div></body></html>

# %% [markdown]
# ## 6.1 Extract first product details save into csv file. e.g# Asus VivoBook X4

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Edge()

driver.get("https://webscraper.io/test-sites/e-commerce/scroll/computers/laptops")

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
soup
# Out:
# <html lang="en"><head>
# <!-- Google Tag Manager -->
# <script async="" nonce="" src="https://www.googletagmanager.com/gtag/js?id=G-Q9KY1T6XJQ&amp;cx=c&amp;gtm=4e5bi1" type="text/javascript"></script><script async="" nonce="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NVFPDWB"></script><script nonce="">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>Scroll | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." name="description"/>
# <link href="/favicon.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="/favicon.ico" rel="icon" sizes="16x16 32x32" type="image/x-icon"/>
# <link href="/logo-icon.png" rel="apple-touch-icon" type="image/png"/>
# <link href="/icon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;600&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700;800;900&amp;display=swap" rel="stylesheet"/>
# <link href="/css/app.css?id=37e354cd0cf06349d7ad09f2f5065e98" rel="stylesheet"/>
# <link href="/css/ws-icons.font.css?id=d8505f3d910cc64df752f712c8032fdb" rel="stylesheet"/>
# <link href="https://webscraper.io/test-sites/e-commerce/scroll/computers/laptops" rel="canonical"/>
# <meta content="Scroll | Web Scraper Test Sites" property="og:title"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://webscraper.io/test-sites/e-commerce/scroll/computers/laptops" property="og:url"/>
# <meta content="https://webscraper.io/webscraper-logo-header.png" property="og:image"/>
# <script defer="" src="/js/app.js?id=08b634a892b70c890a9c8f6190db952b"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVFPDWB" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header class="navbar fixed-top navbar-expand-lg navbar-dark navbar-static svg-background" id="navbar-top" role="banner">
# <div class="container">
# <div class="navbar-header">
# <a data-bs-target=".side-collapse" data-bs-target-2=".side-collapse-container" data-bs-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggler float-end collapsed" data-bs-target="#navbar" data-bs-target-2=".side-collapse-container" data-bs-target-3=".side-collapse" data-bs-toggle="collapse" type="button">
# <span class="visually-hidden">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# <span class="icon-bar extra-bottom-bar"></span>
# </button>
# </a>
# <div class="navbar-brand">
# <a href="/"><img alt="Web Scraper" height="50px" src="/img/logo_white.svg" width="150px"/></a>
# </div>
# </div>
# <div class="side-collapse in">
# <nav class="navbar-collapse collapse" id="navbar" role="navigation">
# <ul class="nav navbar-nav navbar-right">
# <li class="nav-item">
# <a class="nav-link menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/cloud-scraper" id="cloud-nav-link">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/pricing" id="pricing-nav-link">
# <p>Pricing</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item dropdown">
# <button aria-expanded="false" aria-haspopup="true" class="menuitm nav-link dropdown-toggle" data-bs-toggle="dropdown" id="dropdownMenuLink" role="button">
# <p>
# 								Learn
# 								<i class="ws-icon ws-icon-down"></i>
# </p>
# <span class="crta"></span>
# </button>
# <ul aria-labelledby="dropdownMenuLink" class="dropdown-menu">
# <li>
# <a class="dropdown-item" href="/documentation">Documentation</a>
# </li>
# <li>
# <a class="dropdown-item" href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a class="dropdown-item" href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a class="dropdown-item" href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu1 install-extension" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# <i aria-hidden="true" class="browser-icon ws-icon ws-icon-edge-500 ws-icon-edge-dark"></i>
# 							Install
# 						</a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu2" href="https://cloud.webscraper.io/">Cloud Login</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </header>
# <div class="wrapper">
# <div class="formenu-here container-fluid">
# </div>
# <div class="container-fluid blog-hero">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h1>Test Sites</h1>
# </div>
# </div>
# </div>
# </div>
# <div class="container test-site">
# <div class="row">
# <div class="col-lg-3 sidebar">
# <div class="navbar-light sidebar" role="navigation">
# <div class="sidebar-nav navbar-collapse">
# <ul class="nav flex-column" id="side-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a class="nav-link" href="/test-sites/e-commerce/scroll" itemprop="url"><span itemprop="name">Home</span></a>
# </li>
# <li class="nav-item active">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/scroll/computers" itemprop="url">
# <span itemprop="name">Computers</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# <ul class="nav nav-second-level" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link active" href="/test-sites/e-commerce/scroll/computers/laptops" itemprop="url">
# <span itemprop="name">Laptops</span>
# </a>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link" href="/test-sites/e-commerce/scroll/computers/tablets" itemprop="url">
# <span itemprop="name">Tablets</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/scroll/phones" itemprop="url">
# <span itemprop="name">Phones</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-lg-9">
# <h1 class="page-header">Computers / Laptops</h1>
# <div class="row ecomerce-items ecomerce-items-scroll" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD ...
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="push"></div>
# </div>
# <div class="container-fluid footer" id="layout-footer">
# <div class="container">
# <div class="row">
# <div class="col-lg-3">
# <ul>
# <li><p>Products</p></li>
# <li>
# <a class="install-extension" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# 							Web Scraper browser extension
# 						</a>
# </li>
# <li>
# <a href="/cloud-scraper">Web Scraper Cloud</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Company</p></li>
# <li>
# <a href="/about-us">About us</a>
# </li>
# <li>
# <a href="/contact">Contact</a>
# </li>
# <li>
# <a href="/privacy-policy">Website Privacy Policy</a>
# </li>
# <li>
# <a href="/extension-privacy-policy">Browser Extension Privacy Policy</a>
# </li>
# <li>
# <a href="https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip">Media kit</a>
# </li>
# <li><a href="/jobs">Jobs</a></li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Resources</p></li>
# <li><a href="/blog">Blog</a></li>
# <li>
# <a href="/documentation">Documentation</a>
# </li>
# <li>
# <a href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a href="/screenshots">Screenshots</a>
# </li>
# <li>
# <a href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# <li>
# <a href="https://status.webscraper.io/" rel="noopener" target="_blank">Status</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>CONTACT US</p></li>
# <li>
# <a href="mailto:info@webscraper.io">info@webscraper.io</a>
# </li>
# <li>Ubelu 5-71,<br/> Adazi, Latvia, LV-2164</li>
# </ul>
# <ul class="smedia">
# <li>
# <a aria-label="Web Scraper on Facebook" href="https://www.facebook.com/webscraperio/" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-facebook-f"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on LinkedIn" href="https://lv.linkedin.com/company/web-scraper" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-linkedin"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on Youtube" href="https://youtube.com/@WebScraper/videos" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-youtube"></i>
# </a>
# </li>
# <li>
# <a aria-label="Download the Web Scraper extension" class="install-extension browser-icon-dark" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# <i class="browser-icon ws-icon ws-icon-edge-500 ws-icon-edge-dark"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-12">
# <p class="copyright">Copyright © 2025
# 					<b>Web Scraper</b> | All rights reserved</p>
# </div>
# </div>
# </div>
# </div>
# <iframe height="0" style="display: none; visibility: hidden;" width="0"></iframe><div id="cookieBanner" style="opacity: 1; display: block; transition: opacity 0.2s;"><div id="closeCookieBanner">x</div>We use cookies to make your Web Scraper experience better. Read our <a href="/privacy-policy">Privacy Policy</a>. <div class="acceptContainer"><button class="acceptCookies">Accept &amp; Continue</button></div></div></body></html>

# %%
product = soup.find('div',class_='product-wrapper card-body')
product
# Out:
# <div class="product-wrapper card-body"><img alt="item" class="img-fluid card-img-top image img-responsive" itemprop="image" src="/images/test-sites/e-commerce/items/cart2.png"/><div class="caption"><h4 class="price float-end pull-right" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">$295.99</h4><h4><a class="title" href="/test-sites/e-commerce/scroll/product/60" itemprop="name" title="Asus VivoBook X441NA-GA190">Asus VivoBook X4</a></h4><p class="card-text description" itemprop="description">Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd</p></div><div class="ratings" itemprop="aggregateRating" itemscope="" itemtype="https://schema.org/AggregateRating"><p class="review-count float-end pull-right"><span itemprop="reviewCount">1</span> reviews</p><p><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span><span class="ws-icon ws-icon-star"></span></p></div></div>

# %%
list = []
prod_dictionary = {
    'product_name': '',
    'product_link': '',
    'product_img': '',
    'product_price': '',
    'product_details': '',
    'product_reviews_number': '',
    'product_reviews_star_number': '',
}

# %%
prod_dictionary['product_name']= product.find('a').text.strip()
prod_dictionary['product_details']=product.find('p').text
prod_dictionary['product_img']=product.find('img')['src']
prod_dictionary['product_link']=product.find('a')['href']
prod_dictionary['product_reviews_number']=product.find('div',class_='ratings').text.strip()
prod_dictionary['product_reviews_star_number']
prod_dictionary['product_price']=product.find('h4').text.strip()
list.append(prod_dictionary)

# %%
import pandas as pd
df = pd.DataFrame(list)
df
df.to_csv('webscraper io 6_1.csv',index=False)

# %% [markdown]
# ## 6.2 Extract product details from first row & save into csv file. e.g# Asus VivoBook X4, Prestigio SmartB , prestigio SmartB

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Edge()

driver.get("https://webscraper.io/test-sites/e-commerce/scroll/computers/laptops")

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
soup
# Out:
# <html lang="en"><head>
# <!-- Google Tag Manager -->
# <script async="" nonce="" src="https://www.googletagmanager.com/gtag/js?id=G-Q9KY1T6XJQ&amp;cx=c&amp;gtm=4e5bi1" type="text/javascript"></script><script async="" nonce="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NVFPDWB"></script><script nonce="">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>Scroll | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." name="description"/>
# <link href="/favicon.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="/favicon.ico" rel="icon" sizes="16x16 32x32" type="image/x-icon"/>
# <link href="/logo-icon.png" rel="apple-touch-icon" type="image/png"/>
# <link href="/icon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;600&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700;800;900&amp;display=swap" rel="stylesheet"/>
# <link href="/css/app.css?id=37e354cd0cf06349d7ad09f2f5065e98" rel="stylesheet"/>
# <link href="/css/ws-icons.font.css?id=d8505f3d910cc64df752f712c8032fdb" rel="stylesheet"/>
# <link href="https://webscraper.io/test-sites/e-commerce/scroll/computers/laptops" rel="canonical"/>
# <meta content="Scroll | Web Scraper Test Sites" property="og:title"/>
# <meta content="Test Web Scraper's features and performance on mock e-commerce sites. Extract product data, prices, and categories in a controlled environment." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://webscraper.io/test-sites/e-commerce/scroll/computers/laptops" property="og:url"/>
# <meta content="https://webscraper.io/webscraper-logo-header.png" property="og:image"/>
# <script defer="" src="/js/app.js?id=08b634a892b70c890a9c8f6190db952b"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVFPDWB" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header class="navbar fixed-top navbar-expand-lg navbar-dark navbar-static svg-background" id="navbar-top" role="banner">
# <div class="container">
# <div class="navbar-header">
# <a data-bs-target=".side-collapse" data-bs-target-2=".side-collapse-container" data-bs-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggler float-end collapsed" data-bs-target="#navbar" data-bs-target-2=".side-collapse-container" data-bs-target-3=".side-collapse" data-bs-toggle="collapse" type="button">
# <span class="visually-hidden">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# <span class="icon-bar extra-bottom-bar"></span>
# </button>
# </a>
# <div class="navbar-brand">
# <a href="/"><img alt="Web Scraper" height="50px" src="/img/logo_white.svg" width="150px"/></a>
# </div>
# </div>
# <div class="side-collapse in">
# <nav class="navbar-collapse collapse" id="navbar" role="navigation">
# <ul class="nav navbar-nav navbar-right">
# <li class="nav-item">
# <a class="nav-link menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/cloud-scraper" id="cloud-nav-link">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link menuitm" href="/pricing" id="pricing-nav-link">
# <p>Pricing</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="nav-item dropdown">
# <button aria-expanded="false" aria-haspopup="true" class="menuitm nav-link dropdown-toggle" data-bs-toggle="dropdown" id="dropdownMenuLink" role="button">
# <p>
# 								Learn
# 								<i class="ws-icon ws-icon-down"></i>
# </p>
# <span class="crta"></span>
# </button>
# <ul aria-labelledby="dropdownMenuLink" class="dropdown-menu">
# <li>
# <a class="dropdown-item" href="/documentation">Documentation</a>
# </li>
# <li>
# <a class="dropdown-item" href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a class="dropdown-item" href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a class="dropdown-item" href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu1 install-extension" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# <i aria-hidden="true" class="browser-icon ws-icon ws-icon-edge-500 ws-icon-edge-dark"></i>
# 							Install
# 						</a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn-menu2" href="https://cloud.webscraper.io/">Cloud Login</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </header>
# <div class="wrapper">
# <div class="formenu-here container-fluid">
# </div>
# <div class="container-fluid blog-hero">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h1>Test Sites</h1>
# </div>
# </div>
# </div>
# </div>
# <div class="container test-site">
# <div class="row">
# <div class="col-lg-3 sidebar">
# <div class="navbar-light sidebar" role="navigation">
# <div class="sidebar-nav navbar-collapse">
# <ul class="nav flex-column" id="side-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a class="nav-link" href="/test-sites/e-commerce/scroll" itemprop="url"><span itemprop="name">Home</span></a>
# </li>
# <li class="nav-item active">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/scroll/computers" itemprop="url">
# <span itemprop="name">Computers</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# <ul class="nav nav-second-level" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link active" href="/test-sites/e-commerce/scroll/computers/laptops" itemprop="url">
# <span itemprop="name">Laptops</span>
# </a>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation subcategory" class="nav-link subcategory-link" href="/test-sites/e-commerce/scroll/computers/tablets" itemprop="url">
# <span itemprop="name">Tablets</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item">
# <a aria-label="Navigation category" class="category-link nav-link" href="/test-sites/e-commerce/scroll/phones" itemprop="url">
# <span itemprop="name">Phones</span>
# <i aria-hidden="true" class="ws-icon ws-icon-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-lg-9">
# <h1 class="page-header">Computers / Laptops</h1>
# <div class="row ecomerce-items ecomerce-items-scroll" data-items='[{"id":60,"title":"Asus VivoBook X441NA-GA190","description":"Asus VivoBook X441NA-GA190 Chocolate Black, 14\", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd","price":295.99},{"id":61,"title":"Prestigio SmartBook 133S Dark Grey","description":"Prestigio SmartBook 133S Dark Grey, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":62,"title":"Prestigio SmartBook 133S Gold","description":"Prestigio SmartBook 133S Gold, 13.3\" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam","price":299},{"id":32,"title":"Aspire E1-510","description":"15.6\", Pentium N3520 2.16GHz, 4GB, 500GB, Linux","price":306.99},{"id":63,"title":"Lenovo V110-15IAP","description":"Lenovo V110-15IAP, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":321.94},{"id":64,"title":"Lenovo V110-15IAP","description":"Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd","price":356.49},{"id":65,"title":"Hewlett Packard 250 G6 Dark Ash Silver","description":"Hewlett Packard 250 G6 Dark Ash Silver, 15.6\" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS","price":364.46},{"id":66,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":372.7},{"id":67,"title":"Acer Aspire A315-31-C33J","description":"Acer Aspire A315-31-C33J Black 15.6\", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG","price":379.94},{"id":68,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 128GB SSD, Linux","price":379.95},{"id":69,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":391.48},{"id":70,"title":"Acer Aspire 3 A315-21","description":"Acer Aspire 3 A315-21, 15.6\", AMD A4-9120. 4GB. 128GB SSD, Linux","price":393.88},{"id":45,"title":"Asus VivoBook Max","description":"Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home","price":399},{"id":71,"title":"Asus VivoBook E502NA-GO022T Dark Blue","description":"Asus VivoBook E502NA-GO022T Dark Blue, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":399.99},{"id":72,"title":"Lenovo ThinkPad E31-80","description":"Lenovo ThinkPad E31-80, 13.3\" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home","price":404.23},{"id":73,"title":"Acer Aspire 3 A315-31 Black","description":"Acer Aspire 3 A315-31 Black, 15.6\" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home","price":408.98},{"id":74,"title":"Lenovo V110-15ISK","description":"Lenovo V110-15ISK, 15.6\" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home","price":409.63},{"id":75,"title":"Acer Aspire ES1-732 Black","description":"Acer Aspire ES1-732 Black, 17.3\" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home","price":410.46},{"id":76,"title":"Asus VivoBook 15 X540NA-GQ026T","description":"Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6\" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En\/Ru kbd","price":410.66},{"id":31,"title":"Packard 255 G2","description":"15.6\", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1","price":416.99},{"id":77,"title":"Asus EeeBook R416NA-FA014T","description":"Asus EeeBook R416NA-FA014T, 14\" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd","price":433.3},{"id":78,"title":"Acer Aspire 3 A315-51","description":"Acer Aspire 3 A315-51, 15.6\" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home","price":436.29},{"id":79,"title":"Acer Aspire ES1-572 Black","description":"Acer Aspire ES1-572 Black, 15.6\" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home","price":436.29},{"id":80,"title":"Acer Extensa 15 (2540) Black","description":"Acer Extensa 15 (2540) Black, 15.6\" HD ...
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="push"></div>
# </div>
# <div class="container-fluid footer" id="layout-footer">
# <div class="container">
# <div class="row">
# <div class="col-lg-3">
# <ul>
# <li><p>Products</p></li>
# <li>
# <a class="install-extension" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# 							Web Scraper browser extension
# 						</a>
# </li>
# <li>
# <a href="/cloud-scraper">Web Scraper Cloud</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Company</p></li>
# <li>
# <a href="/about-us">About us</a>
# </li>
# <li>
# <a href="/contact">Contact</a>
# </li>
# <li>
# <a href="/privacy-policy">Website Privacy Policy</a>
# </li>
# <li>
# <a href="/extension-privacy-policy">Browser Extension Privacy Policy</a>
# </li>
# <li>
# <a href="https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip">Media kit</a>
# </li>
# <li><a href="/jobs">Jobs</a></li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>Resources</p></li>
# <li><a href="/blog">Blog</a></li>
# <li>
# <a href="/documentation">Documentation</a>
# </li>
# <li>
# <a href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a href="/screenshots">Screenshots</a>
# </li>
# <li>
# <a href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# <li>
# <a href="https://status.webscraper.io/" rel="noopener" target="_blank">Status</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-3">
# <ul>
# <li><p>CONTACT US</p></li>
# <li>
# <a href="mailto:info@webscraper.io">info@webscraper.io</a>
# </li>
# <li>Ubelu 5-71,<br/> Adazi, Latvia, LV-2164</li>
# </ul>
# <ul class="smedia">
# <li>
# <a aria-label="Web Scraper on Facebook" href="https://www.facebook.com/webscraperio/" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-facebook-f"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on LinkedIn" href="https://lv.linkedin.com/company/web-scraper" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-linkedin"></i>
# </a>
# </li>
# <li>
# <a aria-label="Web Scraper on Youtube" href="https://youtube.com/@WebScraper/videos" rel="noopener" target="_blank">
# <i class="ws-icon ws-icon-youtube"></i>
# </a>
# </li>
# <li>
# <a aria-label="Download the Web Scraper extension" class="install-extension browser-icon-dark" href="https://microsoftedge.microsoft.com/addons/detail/web-scraper-free-web-sc/jfmdjnnfminejadhegajcjbpgjofnkaj" rel="noopener" target="_blank">
# <i class="browser-icon ws-icon ws-icon-edge-500 ws-icon-edge-dark"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-12">
# <p class="copyright">Copyright © 2025
# 					<b>Web Scraper</b> | All rights reserved</p>
# </div>
# </div>
# </div>
# </div>
# <iframe height="0" style="display: none; visibility: hidden;" width="0"></iframe><div id="cookieBanner" style="opacity: 1; display: block; transition: opacity 0.2s;"><div id="closeCookieBanner">x</div>We use cookies to make your Web Scraper experience better. Read our <a href="/privacy-policy">Privacy Policy</a>. <div class="acceptContainer"><button class="acceptCookies">Accept &amp; Continue</button></div></div></body></html>

# %%
all_products = soup.find_all("div",class_="col-md-4 col-xl-4 col-lg-4")

all_products
# len(all_products)
# Out:
# 3

# %%
list = []
for i in all_products[0:3]:
    prod_dictionary = {
        'product_name': '',
        'product_link': '',
        'product_img': '',
        'product_price': '',
        'product_details': '',
        'product_reviews_number': '',
        'product_reviews_star_number': '',
    }
    prod_dictionary['product_name']= i.find('a').text.strip()
    prod_dictionary['product_details']=i.find('p').text
    prod_dictionary['product_img']=i.find('img')['src']
    prod_dictionary['product_link']=i.find('a')['href']
    prod_dictionary['product_reviews_number']=i.find('div',class_='ratings').text.strip()
    prod_dictionary['product_reviews_star_number']
    prod_dictionary['product_price']=i.find('h4').text.strip()
    list.append(prod_dictionary)

# %%
import pandas as pd
df = pd.DataFrame(list)
df
df.to_csv('webscraper io 6_2.csv',index=False)
df
# Out:
#        product_name                              product_link  \
# 0  Asus VivoBook X4  /test-sites/e-commerce/scroll/product/60
# 1  Prestigio SmartB  /test-sites/e-commerce/scroll/product/61
# 2  Prestigio SmartB  /test-sites/e-commerce/scroll/product/62
#
#                                      product_img product_price  \
# 0  /images/test-sites/e-commerce/items/cart2.png       $295.99
# 1  /images/test-sites/e-commerce/items/cart2.png          $299
# 2  /images/test-sites/e-commerce/items/cart2.png          $299
#
#                                      product_details product_reviews_number  \
# 0  Asus VivoBook X441NA-GA190 Chocolate Black, 14...              1 reviews
# 1  Prestigio SmartBook 133S Dark Grey, 13.3" FHD ...              9 reviews
# 2  Prestigio SmartBook 133S Gold, 13.3" FHD IPS, ...              9 reviews
#
#   product_reviews_star_number
# 0
# 1
# 2

# %% [markdown]
# ## 6.3 Extract all product details from first page & save into csv file.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Edge()

driver.get("https://webscraper.io/test-sites/e-commerce/scroll/computers/laptops")
