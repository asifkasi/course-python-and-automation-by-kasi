# %%
userinput = int(input("enter number"))
if userinput%3==0:
    if userinput%5==0:
        print("not diviable by 3 & 5 both")
    else:
        print("no. only diviable by 3")
elif(userinput%5==0):
    print("no. only diviable by 5")  
else:
    print("no. not diviable")
# Out:
# no. only diviable by 5

# %%
userinput = int(input("enter number"))
if userinput%3==0:
   print ("diviable")      
        
else:
      print("no. not diviable")
# Out:
# diviable

# %%
userinput = int(input("enter number"))
if userinput%3==0:
   if userinput%5==0:
      print("divisable")
else:
    print("not divisable")
# Out:
# not divisable

# %%
userinput = int(input("enter number"))
if (userinput%3==0)and (userinput !=0):
    if userinput%5==0:
        print("no divisable by 3&5 both")
    else:
        print("no. only divisable by 3")        
elif (userinput%5==0)and (userinput !=0):
    print("no.only divisable by 5")
else:
    print("no.not divisable")
# Out:
# no.not divisable

# %%
userinput = int(input("enter number"))
hours = userinput/60
mints = userinput%60
print(f"total hours {hours}and {mints}")
# Out:
# total hours 1.5and 30

# %%
userinput = int(input("enter number"))
years = userinput// 365
remaining_days = userinput%365
months = remaining_days//30
remaining_days =  remaining_days %30
weeks = remaining_days /7
days = userinput /7
print(f"years {years} and months {months} and weeks {weeks} and days {days}")
# Out:
# years 0 and months 2 and weeks 0.0 and days 8.571428571428571

# %%
userinput = int(input("enter number"))
amount = 88888
noths = [5000, 1000, 500, 100, 50, 10,]
coins = [5,3, 1]
for nothe in noths: 
count = userinput// noths
remaining_amount = userinput % noths
print(f"noths {noths} and {count}")
for coins in coins:
count = userinput// coins 
remaining_amount = userinput % coins
print(f"coins {coins} and   {count}")
# Out:
#   Cell In[6], line 6
#     count = userinput// noths
#     ^
# IndentationError: expected an indented block after 'for' statement on line 5

# %%
userinput = int(input("Enter number: "))

count_5000 = userinput // 5000
userinput %= 5000

count_1000 = userinput // 1000
userinput %= 1000

count_500 = userinput // 500
userinput %= 500

count_100 = userinput // 100
userinput %= 100

count_50 = userinput // 50
userinput %= 50

count_10 = userinput // 10
userinput %= 10

count_5 = userinput // 5
userinput %= 5

count_3 = userinput // 3
userinput %= 3

count_1 = userinput // 1
userinput %= 1

print(f"Note 5000: {count_5000}")
print(f"Note 1000: {count_1000}")
print(f"Note 500: {count_500}")
print(f"Note 100: {count_100}")
print(f"Note 50: {count_50}")
print(f"Note 10: {count_10}")
print(f"Coin 5: {count_5}")
print(f"Coin 3: {count_3}")
print(f"Coin 1: {count_1}")
# Out:
# Note 5000: 0
# Note 1000: 0
# Note 500: 0
# Note 100: 0
# Note 50: 1
# Note 10: 0
# Coin 5: 0
# Coin 3: 0
# Coin 1: 0
