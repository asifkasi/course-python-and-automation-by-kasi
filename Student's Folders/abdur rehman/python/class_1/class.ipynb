# %%
rs = int(input("enter amount"))
if(rs == 1000):
   print('you are allowed')
elif(rs>1000):
   print("you have enrugh find")
elif(rs==500):   
    print("you allowed for 2 hours")
else:
   print("you are not allowed")
# Out:
# you have enrugh find

# %%
rs = int(input("enter amount"))
if(rs == 1000):
   print('you are allowed')
if(rs>=1000):
   print("you have enrugh find")
elif(rs==500):   
    print("you allowed for 2 hours")
else:
   print("you are not allowed")
# Out:
# you are allowed
# you have enrugh find

# %%
rs = int(input("enter amount"))
if(rs == 1000):
   print('you are allowed')
elif(rs>=1000):
   print("you have enrugh find")
elif(rs==500):   
    print("you allowed for 2 hours")
else:
   print("you are not allowed")
# Out:
# you are allowed

# %%
userinput =int(input("enter number"))
if (userinput== 0):
   print("nutral")
elif(userinput%2==0):   
    print("even number")
else:
   print("odd")
# Out:
# odd

# %%
userinput = int(input("enter number"))
if (userinput%2 == 0):
    print("positive")
else:
    print('negetive')
# Out:
# negetive

# %%
rs = int(input("enter number"))
if(rs==0):
    print("neutral")
elif(rs>0):
    print("positive")

else:
    print("nagitve")
# Out:
# nagitve

# %%
userinput = int(input("enter number"))
if(userinput%5==0):
   print("yes")
else:
   print("not")
# Out:
# yes

# %%
userinput = int(input("enter number"))
if userinput%3==0:
    # print("it is divisable by 3")
    if(userinput%5 ==0):
        print("divistalbe by 3&5")
    else:
        print("not divisabe")  
else:
    print("not divisable")
# Out:
# divistalbe by 3&5

# %%
userinput = int(input("enter number"))
if userinput%3==0:
    # print("it is divisable by 3")
    if(userinput%5 ==0):
        print("divistalbe by 3&5")
    else:
        print("not divisabe")
    if(userinput%3==0):
        print("it is divisable by 3")  
    else:
        print("not divisable") 
    
    if(userinput%5==0):
        print("it is divisable by 5")  
    else:
        print("not divisable")          
else:
    print("not divisable")
# Out:
# not divisable

# %%
userinput = int(input("enter number"))
if userinput%3==0:
    if userinput%5==0:
        print("not diviable by 3 & 5 both")
    else:
        print("no. only diviable by 3")
elif(userinput%5==0):
    print("no. only diviable by 5")  
else:
    print("no. not diviable")
# Out:
# no. only diviable by 5

# %%
userinput = int(input("enter number"))

if(userinput%3==0)and(userinput%5==0):
    print("no. is diviable by both")
elif(userinput%3==0):
    print("no. is only diviable by 3") 
elif(userinput%5==0):
    print("no. is only diviable by 5")
else:
    print("no. not diviable")
# Out:
# no. is only diviable by 3

# %%
userinput = int(input("enter number"))
if(userinput<0):
    print(" not accepted")
elif (userinput <100):
    print(" accpeted")     
    if (userinput%2==0):
       print("even")
    else:
        print("odd")           
       
else:
    print("number not accepted, try with less than 100")
# Out:
#  not accepted

# %%
userinput = int(input("enter number"))
if userinput <100:
    print(" not accepted") 
    if (userinput%2==0):
       print("even")
    else:
        print("odd")           
       
else:
    print("number not accepted, try with less than 100")

# %%
userinput=int(input("enter number"))
if(userinput>0)and(userinput<100):
    if userinput%2==0:
        print("even")
    else:
        print("odd")  
else:
    print("number is not eccecpted")
# Out:
# number is not eccecpted

# %%
userinput=int(input("enter number"))
if(userinput<0)or(userinput>100):
    print("not accecptrd")
elif userinput%2==0:        
        print("even")  
else:
    print("odd")
# Out:
# odd

# %%
userinput_laptop= input(" do you have a laptop")
userinput_card = input(" do you have a card")
if (userinput_laptop== "yes")and(userinput_card=="yes"):
    print("allowed")
else:
    print(" you are not allowed")
# Out:
# not allowed

# %%
userinput_laptop= input(" do you have a laptop")
userinput_card = input(" do you have a card")
if (userinput_laptop== "no")or(userinput_card=="no"):
    print(" not allowed")
else:
    print("allowd")
# Out:
#  not allowed
