# %%
varr = "abdur rehman"
if " " in varr:
    print("exist")
else:
    ("not")
# Out:
# exist

# %%
varr = "abdur_rehman"
if "_"  in varr:
    print("exist")
else:
    ("not")
# Out:
# exist

# %%
varr = "asif kasi"
varr = varr + " s/o qasim kasi"
print(varr)
# Out:
# asif kasi s/o qasim kasi

# %%
print(varr.count("kasi"))
# Out:
# 2

# %%
#how to remove frist white space from variable.
varr = "asif kasi s/o qasim kasi"
varindex=varr.index(" ")
print(varr[:varindex])
print(varr[varindex+1:])
newvarr = varr[:varindex]+ varr[varindex+1:]
print(newvarr)
# Out:
# asifkasi
# s/o qasim kasi
# asifkasis/o qasim kasi

# %%
varr = "asifkasi s/o qasim kasi"
newvarr = varr[:4]+ varr[5:]
print(newvarr)
# Out:
# asifasi s/o qasim kasi

# %%
# how to replace all white sapace with "_".
varr = "asif kasi s/o qasim kasi"
print(varr.replace(" ","_"))
# Out:
# asif_kasi_s/o_qasim_kasi

# %%
# check variable start from "asif" or not.
varr = "asif kasi s/o qasim kasi"
print(varr.startswith("asif")) #print ("asif" in varr )
# Out:
# True

# %%
varr = "asif kasi s/o qasim kasi"
print(varr.endswith("asif")) #
# Out:
# False

# %%
varr = "abdur rehman s/o shakir ullah"
word =(varr.split())
print(word)
# Out:
# ['abdur', 'rehman', 's/o', 'shakir', 'ullah']

# %%
varr = "abdur rehman s/o shakir ullah"
word =(varr.split())
for word in word:
    print(word)
# Out:
# abdur
# rehman
# s/o
# shakir
# ullah
