# %%
# find the sum from 1 to 10 using loop.
sum=0
for i in range(1,10,1):
    sum = i+sum
    print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45

# %%
# find average of 15 to 25.
sum = 0
for i in range(15,26,1):
    sum = i +sum
averge = sum/10
print(averge)
# Out:
# 22.0

# %%
sum = 0
for i in range(1,5):
    user=int(input("enter number"))
    sum = user+sum
averge = sum/10
print(averge)
# Out:
# 1.9

# %%
sum = 0
userinput = int(input("enter number"))
varr = "3,5,7,10,20,15,25"
varrlist =(varr.split(","))
for i in range(len(varrlist)):
    #print(varrlist[i])
    sum =int(varrlist[i])+sum
print(sum)
avg = sum/len(varrlist)
print(avg)
# Out:
# 85
# 12.142857142857142
