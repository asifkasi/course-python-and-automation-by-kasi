# %%
print("abdur rehman")
# Out:
# abdur rehman

# %%
print('saim')
# Out:
# saim

# %%
'arshad mehboob'
# Out:
# 'arshad mehboob'

# %%
'your name'
# Out:
# 'your name'

# %%
'your name'
"your father name"
# Out:
# 'your father name'

# %%
print("name")
print('father')
# Out:
# name
# father

# %%
1
# Out:
# 1

# %%
print("name")
print("name2")
# Out:
# name
# name2

# %%
name = "abdur rehman"
print(name)
# Out:
# abdur rehman

# %%
print("name")
# Out:
# name

# %%
age = 28
print(age)
# Out:
# 28

# %%
name1 = saim 
print(name1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 name1 = saim
#       2 print(name1)
#
# NameError: name 'saim' is not defined

# %%
type (age)
# Out:
# int

# %%
type (name)
# Out:
# str

# %%
height = 5.5
print (height)
# Out:
# 5.5

# %%
type (height)
# Out:
# float

# %%
a = "18"
print(a)
# Out:
# 18

# %%
type(a)
# Out:
# str

# %%
age = 26
print(age)
# Out:
# 26

# %%
#method1
print()

# %%
#method3
height = 5.7
print(f"age1 is {age} & height is {height}")
# Out:
# age1 is 26 & height is 5.7

# %%
print("enter number1")
N1 = input(5)
print("enter number2")
N2 = input(10)
sum = int(N1) +int (N2)
print(sum)
# Out:
# enter number1
# enter number2
# 15

# %%
#method 2
N1 = input("enter number1")
N2 = input("enter number2")
sum = (N1) + (N2)
print(sum)
# Out:
# 510

# %%
N1 = int(input("enter N1"))
N2 = int(input("enter N2"))
sum = N1+N2
print(sum)
# Out:
# 15

# %%
N1 = input("enter a distance from califton to saddar")
N2 = input("enter a distance from califton to keamari")
sum = N1 + N2
print(sum)
# Out:
# 4.55.6

# %%
N1 =  float(input("enter a distance from califton to saddar"))
N2 = float(input("enter a distance from califton to keamari"))
sum = N1 + N2
print(sum)
# Out:
# 7.1

# %%
Ruppes = int(input("enter amount you can give"))
if Ruppes == 1000:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party

# %%
Ruppes = input("enter amount you can give")
if Ruppes == 1000:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
   #error occuer becoues of date type ruppe variable date type is str & in condition use are
# Out:
# not allowed, give 1000 Ruppes

# %%
Ruppes = (input("enter amount you can give"))
if Ruppes == '1000':
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party

# %%
Ruppes = int(input("enter amount you can give"))
if Ruppes = 1000:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
#   Cell In[21], line 2
#     if Ruppes = 1000:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
Ruppes = int(input("enter amount you can give"))
if Ruppes == 1000:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# not allowed, give 1000 Ruppes

# %%
Ruppes = int(input("enter amount you can give"))
if Ruppes >= 1000:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party

# %%
Ruppes = (input("enter amount you can give"))
if Ruppes >= '1000':
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party

# %%
Ruppes = (input("enter amount you can give"))
if Ruppes >= '1000':
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party

# %%
Ruppes = 1050
Ruppes >= 1000
# Out:
# True

# %%
Ruppes = int(input("enter amount you can give"))
if Ruppes <= 1000:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party

# %%
Ruppes = int(input("enter amount you can give"))
if 1000 <= Ruppes:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party

# %%
Ruppes = int(input("enter amount you can give"))
if 1000 < Ruppes:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# not allowed, give 1000 Ruppes

# %%
Ruppes = int(input("enter amount you can give"))
if 1000 < Ruppes:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party

# %%
Ruppes = int(input("enter amount you can give"))
if 1000 < Ruppes:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# not allowed, give 1000 Ruppes

# %%
Ruppes = int(input("enter amount you can give"))
if 999 < Ruppes:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party

# %%
Ruppes = int(input("enter amount you can give"))
if 1000 < Ruppes+1:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party

# %%
Ruppes = int(input("enter amount you can give"))
if 1000 > Ruppes:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party

# %%
Ruppes = int(input("enter amount you can give"))
if 999 > Ruppes:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party

# %%
Ruppes = int(input("enter amount you can give"))
if 1000 > Ruppes-1:
   print('wlecome to party')
else:
   print("not allowed, give 1000 Ruppes")
# Out:
# wlecome to party
