# %%
std = ["'abdur rehman', 'shawaiz','shariq','asim','sheraz','umair' "]
print(std[0])
# Out:
# 'abdur rehman', 'shawaiz','shariq','asim','sheraz','umair'

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair' ]
print(std[0])
# Out:
# abdur rehman

# %%
std = ['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec']
std_no = int(input("enter number b/w 1 to 12"))
if  std_no >12:
    print("input no must be b/w 1 to 12")
else:
     print(std[std_no -1])
# Out:
# sep

# %%
std = ['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec']
std_no = int(input("enter number b/w 1 to 12"))
if  std_no >12 or std_no <=0:
    print("input no must be b/w 1 to 12")
else:
     print(std[std_no -1])
# Out:
# input no must be b/w 1 to 12

# %%
std = ['sat','sun','man','tue','wed','thu','fri']
std_no = int(input("enter number"))
print(std[std_no -1])
# Out:
# wed

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair','abdur rehman' ,'7' , '8.8' ,'9.0'  ]
std_no = int(input("enter number"))
print(std[std_no -1])
# Out:
# 9.0

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair','abdur rehman' ,'7' , '8.8' ,'9.0'  ]
std appened ("sammmi")
print(std)
# Out:
#   Cell In[1], line 2
#     std appened ("sammmi")
#         ^
# SyntaxError: invalid syntax

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair','abdur rehman' ,'7' , '8.8' ,'9.0'  ]
std.insert(2 , 'wasim')

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair','abdur rehman' ,'7' , '8.8' ,'9.0'  ]
std.find("shariq")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair','abdur rehman' ,'7' , '8.8' ,'9.0'  ]
# ----> 2 std.find("shariq")
#
# AttributeError: 'list' object has no attribute 'find'

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair','abdur rehman' ,'7' , '8.8' ,'9.0'  ]
std.find("shariq1")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair','abdur rehman' ,'7' , '8.8' ,'9.0'  ]
# ----> 2 std.find("shariq1")
#
# AttributeError: 'list' object has no attribute 'find'

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair','abdur rehman' ,'7' , '8.8' ,'9.0'  ]
std.index("shariq")
# Out:
# 2

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair' ]
std.index("shariq1")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair','abdur rehman' ,'7' , '8.8' ,'9.0'  ]
# ----> 2 std.index("shariq1")
#
# ValueError: 'shariq1' is not in list

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair','abdur rehman' ,'7' , '8.8' ,'9.0'  ]
std[2] 'wasim'
# Out:
#   Cell In[8], line 2
#     std[2] 'wasim'
#            ^
# SyntaxError: invalid syntax

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
std.remove("shariq")
print(std)
# Out:
# ['abdur rehman', 'shawaiz', 'asim', 'sheraz', 'umair']

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
std.remove("shariq2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
# ----> 2 std.remove("shariq2")
#
# ValueError: list.remove(x): x not in list

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
std.pop("2")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
# ----> 2 std.pop("2")
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
std.pop(2)
# Out:
# 'shariq'

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
std.index(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
# ----> 2 std.index(2)
#
# ValueError: 2 is not in list

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
std.count("shariq")
# Out:
# 1

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
std.append("umair")
print(std.count("umair"))
# Out:
# 2

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
print(std.index("umair")) 
# stop seaching after finding frist occurancey of element
# Out:
# 5

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair']
std.remove("umair")
print(std)
#if seaching after deleting first occurancey of element
# Out:
# ['abdur rehman', 'shawaiz', 'shariq', 'asim', 'sheraz']

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
print(std[3:])
# Out:
# ['asim', 'sheraz', 'umair']

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
print(std[:3])
# Out:
# ['abdur rehman', 'shawaiz', 'shariq']

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
print(std [:-3])
# Out:
# ['abdur rehman', 'shawaiz', 'shariq']

# %%
std = ['abdur rehman', 'shawaiz','shariq','asim','sheraz','umair',]
print(std[-5: -3])
# Out:
# ['shawaiz', 'shariq']

# %%
std = [ 'umair','shariq','asim','umair','sheraz',"umair"]
firstindex =std.index("umair")
std2 = std[firstindex+1:]
secondindex = std2.index("umair")
print(secondindex+firstindex+1)
# Out:
# 3

# %%
std = ['hamza','umair','shariq','asim','umair','wasim']
firstindex =std.index("umair")
std2 = std[firstindex+1:]
secondindex = std2.index("umair")
print(secondindex+firstindex+1)
# Out:
# 4

# %%
std = ['umair','shariq','asim','umair','wasim','umair']
std.reverse()
print(std)
# Out:
# ['umair', 'wasim', 'umair', 'asim', 'shariq', 'umair']

# %%
std = ['abdur rehman','shariq','asim','wasim','shawaiz','umair','sheraz']
print(std[6:])
# Out:
# ['sheraz']

# %%
std = ['abdur rehman','asim','abdur rehman','sheraz','shariq','abdur rehman','asim']
firstindex=std.index('asim')
std2 = std[firstindex+1:]
secondindex = std2.index("asim")
print(secondindex+firstindex+1)
# Out:
# 6

# %%
std = ['abdur rehman','shariq','asim','wasim','shawaiz','umair','sheraz']
std.append("wasim")
print(std)
# Out:
# ['abdur rehman', 'shariq', 'asim', 'wasim', 'shawaiz', 'umair', 'sheraz', 'wasim']

# %%
Room1 = ['abdur rehman','shariq','asim','wasim']
Room2 = ['shawaiz','umair','sheraz']
["Room1+Room2"]
# Out:
# ['Room1+Room2']

# %%
std = ['abdur rehman','shariq','asim','wasim','shawaiz','umair','sheraz']
