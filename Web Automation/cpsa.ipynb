# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
from selenium import webdriver

driver = webdriver.Chrome()

url   = "https://search.cpsa.ca/"
driver.get(url) # open the website

driver.maximize_window() # miximize window

driver.find_element("xpath", "//input[@id=\'MainContent_physicianSearchView_txtFirstName\']").click() # click on the first name input box

driver.find_element("xpath","//input[@id='MainContent_physicianSearchView_txtFirstName']").send_keys("a") # enter first name
time.sleep(2) # time delay for input to be registered

driver.find_element("xpath", "//input[@id=\'MainContent_physicianSearchView_btnSearch\']").click() # click on the search button
time.sleep(7) # time delay for results to load

# %%
# soup = BeautifulSoup(driver.page_source,"html") # parse the page source

# table= soup.find("table",id = "MainContent_physicianSearchView_gvResults") # find the results table

# trs = table.find_all("tr") # find all rows in the table

# len(trs) # count the number of rows

# # trs[0].find_all("th")
# len(trs) # count the number of rows

# # Initialize empty lists to store the data
# names = []
# locations = []
# disciplines = []
# genders = []
# languages = []

# # Iterate over each row in trs and extract the relevant data
# for tr in trs[1:]:  # Skip the header row (trs[0])
#     soup = BeautifulSoup(str(tr), 'html.parser')
    
#     # Extract Name
#     name_tag = soup.find('td', class_='status4')
#     if name_tag:
#         name = name_tag.get_text(strip=True)
#     else:
#         name = None
#     names.append(name)
    
#     # Extract Location
#     location_tag = soup.find_all('td')[1] if len(soup.find_all('td')) > 1 else None
#     if location_tag:
#         location = location_tag.get_text(strip=True)
#     else:
#         location = None
#     locations.append(location)
    
#     # Extract Practice Discipline
#     discipline_tag = soup.find_all('td')[2] if len(soup.find_all('td')) > 2 else None
#     if discipline_tag:
#         discipline = discipline_tag.get_text(strip=True)
#     else:
#         discipline = None
#     disciplines.append(discipline)
    
#     # Extract Gender
#     gender_tag = soup.find_all('td')[3] if len(soup.find_all('td')) > 3 else None
#     if gender_tag:
#         gender = gender_tag.get_text(strip=True)
#     else:
#         gender = None
#     genders.append(gender)
    
#     # Extract Languages
#     language_tag = soup.find_all('td')[4] if len(soup.find_all('td')) > 4 else None
#     if language_tag:
#         language = language_tag.get_text(strip=True)
#     else:
#         language = None
#     languages.append(language)

# # Create a DataFrame from the extracted data
# data = {
#     'Name': names,
#     'Location': locations,
#     'Practice Discipline': disciplines,
#     'Gender': genders,
#     'Languages': languages
# }

# df = pd.DataFrame(data)
# df

# driver.find_element("xpath", "//table[@id=\'MainContent_physicianSearchView_gvResults\']/tbody/tr[12]/td/div/div[3]/input").click()
# time.sleep(4)

# %%
# import time
# import pandas as pd
# from selenium import webdriver
# from bs4 import BeautifulSoup

# # Initialize WebDriver (make sure to replace with your own WebDriver path)
# driver = webdriver.Chrome(executable_path='path_to_chromedriver')

# # Open the website
# driver.get("your_target_url")

# Initialize empty lists to store the data
names = []
locations = []
disciplines = []
genders = []
languages = []

# Define a loop to extract data from multiple pages
for i in range(5):
    # Parse the page source
    soup = BeautifulSoup(driver.page_source, "html.parser")
    
    # Find the results table
    table = soup.find("table", id="MainContent_physicianSearchView_gvResults")
    
    # Find all rows in the table
    trs = table.find_all("tr")
    
    # Extract the data for each row
    for tr in trs[1:]:  # Skip the header row
        soup_tr = BeautifulSoup(str(tr), 'html.parser')
        
        # Extract Name
        name_tag = soup_tr.find('td', class_='status4')
        name = name_tag.get_text(strip=True) if name_tag else None
        names.append(name)
        
        # Extract Location
        location_tag = soup_tr.find_all('td')[1] if len(soup_tr.find_all('td')) > 1 else None
        location = location_tag.get_text(strip=True) if location_tag else None
        locations.append(location)
        
        # Extract Practice Discipline
        discipline_tag = soup_tr.find_all('td')[2] if len(soup_tr.find_all('td')) > 2 else None
        discipline = discipline_tag.get_text(strip=True) if discipline_tag else None
        disciplines.append(discipline)
        
        # Extract Gender
        gender_tag = soup_tr.find_all('td')[3] if len(soup_tr.find_all('td')) > 3 else None
        gender = gender_tag.get_text(strip=True) if gender_tag else None
        genders.append(gender)
        
        # Extract Languages
        language_tag = soup_tr.find_all('td')[4] if len(soup_tr.find_all('td')) > 4 else None
        language = language_tag.get_text(strip=True) if language_tag else None
        languages.append(language)
    
    # Check if the "Next" button is available and click it
    try:
        next_button = driver.find_element("xpath", "//input[@value='Next']")  # Modify as per the actual button element
        if next_button.is_enabled():  # Check if the button is enabled
            next_button.click()  # Click the "Next" button
            time.sleep(4)  # Wait for the next page to load
        else:
            break  # If the button is not available, break the loop
    except Exception as e:
        print(f"Error while trying to click next: {e}")
        break

# Create a DataFrame from the extracted data
data = {
    'Name': names,
    'Location': locations,
    'Practice Discipline': disciplines,
    'Gender': genders,
    'Languages': languages
}

df = pd.DataFrame(data)
df
# # Display the DataFrame
# import caas_jupyter_tools as tools; tools.display_dataframe_to_user(name="Physician Data", dataframe=df)

# # Close the driver after finishing the task
# driver.quit()
# Out:
#                                                  Name  \
# 0                                       Aamir,  Areeb
# 1                        Abahussein, Dr. Abdulaziz S.
# 2                                  Abba-Aji, Dr. Adam
# 3                                    Abbas, Dr. Ahmed
# 4               Abbas, Dr. Ali Sajjad(Abbas, Dr. Ali)
# 5                                   Abbas, Dr. Ausami
# 6                           Abbasi, Dr. Ahmed Mustafa
# 7                                     Abbasian,  Aram
# 8                   Abbi, Dr. Arun K.(Abbi, Dr. Arun)
# 9                                  Abbi, Dr. Attam V.
# 10                                               None
# 11                             Abbott, Dr. A. Patrick
# 12  Abbott, Dr. Annalise(Abbott, Dr. Annalise Geor...
# 13                        Abdalkreem, Dr. Amel Rodwan
# 14               Abdalla, Dr. Abdelazim Ahmed Mohamed
# 15                                 Abdalla, Dr. Anwer
# 16                                 Abdallah, Dr. Amel
# 17                                    Abdalle,  Ahmed
# 18                                 Abdalvand, Dr. Ali
# 19                              Abdalwahab, Dr. Ahmed
# 20                                 Abdeen, Dr. Ayesha
# 21                                               None
# 22                         Abdel Malik, Dr. Abu Baker
# 23                 Abdel Masih, Dr. Ayman Anwar Ghaly
# 24                         Abdelbasit, Dr. Ahmed Omar
# 25                    Abdelmagid Mohamed, Dr. Abdalla
# 26               Abdelmalek, Dr. Abeer Kamal Ghobrial
# 27                               Abdel-sayyed,  Ahmed
# 28                                Abderahem, Dr. Atef
# 29                                Abdi Ali, Dr. Ahmed
# 30  Abdihalim, Dr. Abdihamid Yusuf(Abdihalim, Dr. ...
# 31     Abdin Osman Medani, Dr. Alaa(Medani, Dr. Alaa)
# 32                                               None
# 33                              Abdo, Dr. Ayman Assad
# 34                   Abdukadr, Dr. Almuez Abdualla K.
# 35                        Abdul Aziz, Dr. Ahmad Nizar
# 50  933 17 Avenue SouthwestCalgary, Alberta, Canad...
# 51   39 StreetSt Paul, Alberta, CanadaT0A780-645-6077
# 52  6633 177 Street NorthwestEdmonton, Alberta, Ca...
# 53  3210 118Avenue Northwest135Edmonton, Alberta, ...
# 54                                               None
#
#                              Practice Discipline  Gender  \
# 0                       Supervised Practice Only    Male
# 1                                           None    Male
# 2                                     Psychiatry    Male
# 3                       Supervised Practice Only    Male
# 4                               General Practice    Male
# 5                                           None    Male
# 6                                           None    Male
# 7                                           None    Male
# 8                             Emergency Medicine    Male
# 9              Family Medicine, General Practice    Male
# 10                                          None    None
# 11                                    Psychiatry    Male
# 12                            Physician Extender  Female
# 13                                    Pediatrics  Female
# 14                                          None    Male
# 15             General Practice, Family Medicine    Male
# 16                                          None  Female
# 17                                          None    Male
# 18                               Family Medicine    Male
# 19                                          None    Male
# 20                            Orthopedic Surgery  Female
# 21                                          None    None
# 22             General Practice, Family Medicine    Male
# 23                                          None    Male
# 24                                          None    Male
# 25                                          None    Male
# 26                            Clinical Assistant  Female
# 27                      Supervised Practice Only    Male
# 28                             Internal Medicine    Male
# 29                 Internal Medicine, Cardiology    Male
# 30  General Internal Medicine, Internal Medicine    Male
# 31                           Associate Physician  Female
# 32                                          None    None
# 33                                          None    Male
# 34                             Internal Medicine    Male
# 35                                          None    Male
# 36                                          None    Male
# 37                       Obstetrics & Gynecology    Male
# 38             General Practice, Family Medicine    Male
# 39                               Family Medicine  Female
# 40                                          None    Male
# 41                                          None    Male
# 42                Internal Medicine, Respirology    Male
# 43                                          None    None
# 44                 Cardiology, Internal Medicine    Male
# 45                                          None    Male
# 46             General Practice, Family Medicine    Male
# 47             General Practice, Family Medicine    Male
# 48                            Pathology, General    Male
# 49                                          None    Male
# 50                               Family Medicine  Female
# 51             Family Medicine, General Practice    Male
# 52               Internal Medicine, Rheumatology    Male
# 53             General Practice, Family Medicine    Male
# 54                                          None    None
#
#                                            Languages
# 0                                            English
# 1                                            English
# 2                                     English, Hausa
# 3                                            English
# 4           English, Hindi, Pakistani, Punjabi, Urdu
# 5                                            English
# 6                                            English
# 7                                            English
# 8                                            English
# 9                                            English
# 10                                              None
# 11                                           English
# 12                                           English
# 13                                           English
# 14                                           English
# 15                                   English, Arabic
# 16                                           English
# 17                                           English
# 18                                           English
# 19                                           English
# 20                                  English, Spanish
# 21                                              None
# 22                                   English, Arabic
# 23                                           English
# 24                                           English
# 25                                           English
# 26                                           English
# 27                                           English
# 28                                   English, Arabic
# 29                          English, Swahili, Somali
# 30                                   English, Somali
# 31                                   English, Arabic
# 32                                              None
# 33                                           English
# 34                                   English, Arabic
# 35                                           English
# 36                                   English, Arabic
# 37                                   English, Arabic
# 38                           English, French, Arabic
# 39                                           English
# 40                                           English
# 41                                           English
# 42                                   English, Arabic
# 43                                              None
# 44  English, Gujarati, Hindi, Kachi, Kiswahili, Urdu
# 45                                           English
# 46                                   English, Arabic
# 47                                   English, Arabic
# 48                  English, Arabic, Persian (Farsi)
# 49                                           English
# 50                                   English, Arabic
# 51                            English, Hausa, Yoruba
# 52                                   English, Arabic
# 53                                   English, Arabic
# 54                                              None
