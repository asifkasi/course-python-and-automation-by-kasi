# %% [markdown]
# # class 1: Introduction to Web Scraping and Basics

# %% [markdown]
# ## Day 1: Introduction to the Web and HTML
#
# ### What is a webpage?
#     - A webpage is like a digital page on the internet. Every page we see on a website is written in HTML (HyperText Markup Language).
#
# ### What is HTML?
#     - HTML is the language used to structure the contents of a webpage. It uses tags to define different parts of the content. For example, <p> is used for paragraphs, and <h1> is used for headings.
#
# ### What is the DOM (Document Object Model)?
#     - The DOM is a tree-like structure that shows how HTML elements are arranged on a webpage. Each tag is like a branch on this tree, and it helps us understand how the page is built.
#
# ### What is HTTP?
#      - HTTP (HyperText Transfer Protocol) is how computers communicate with websites. It is like a messenger delivering a request to the website and bringing the webpage back to you.
#
# ### What is the requests library?
#     - In Python, we use requests to fetch or "download" the HTML of a webpage. It is like sending a message to a website, asking for its page.
# ### Response Codes:
#     - When we request a webpage, we get a status code:
#         * 200: Success, the webpage is available.
#         * 404: Not found, the webpage does not exist.

# %%
# pip install request

# %%
# !pip install requests
# pip install requests==2.19.0
# !pip install "C:\Users\Asif\Downloads\requests-2.16.1-py2.py3-none-any.whl"
# Out:
# Processing c:\users\asif\downloads\requests-2.16.1-py2.py3-none-any.whl
# WARNING: Requirement 'C:\\Users\\Asif\\Downloads\\requests-2.16.1-py2.py3-none-any.whl' looks like a filename, but the file does not exist
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\Asif\\Downloads\\requests-2.16.1-py2.py3-none-any.whl'
#
# WARNING: You are using pip version 22.0.4; however, version 25.2 is available.
# You should consider upgrading via the 'C:\Users\Asif_\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import requests

# %%
requests.__version__
# Out:
# '2.32.5'

# %%
requests.__version__
# Out:
# '2.32.5'

# %% [markdown]
# # class2

# %% [markdown]
# ## Requests

# %%
import requests

# %%
r = requests.get('https://example.com/')

r

# %%
r.url
# Out:
# 'https://example.com/'

# %%
print(r.url)
"asif kasi"
# Out:
# https://example.com/
# 'asif kasi'

# %%
r.status_code
# Out:
# 200

# %%
print(r.text)
# Out:
# <!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.<p><a href="https://iana.org/domains/example">Learn more</a></div></body></html>

# %%
r.raise_for_status()

# %% [markdown]
# ## BeautifulSoup

# %%
# !pip install beautifulsoup4
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.2 is available.
# You should consider upgrading via the 'C:\Users\Asif_\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
r.text
# Out:
# '<!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.<p><a href="https://iana.org/domains/example">Learn more</a></div></body></html>\n'

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><title>Example Domain</title><meta content="width=device-width, initial-scale=1" name="viewport"/><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.<p><a href="https://iana.org/domains/example">Learn more</a></p></p></div></body></head></html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Example Domain
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <style>
#    body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}
#   </style>
#   <body>
#    <div>
#     <h1>
#      Example Domain
#     </h1>
#     <p>
#      This domain is for use in documentation examples without needing permission. Avoid use in operations.
#      <p>
#       <a href="https://iana.org/domains/example">
#        Learn more
#       </a>
#      </p>
#     </p>
#    </div>
#   </body>
#  </head>
# </html>

# %%
soup.find('h1')
# Out:
# <h1>Example Domain</h1>

# %%
soup.find('div').find('h1')
# Out:
# <h1>Example Domain</h1>

# %%
def fun_hit_url(url):
    r = requests.get(url)
    if r.status_code == 200:
        from bs4 import BeautifulSoup

        soup = BeautifulSoup(r.text, 'html.parser')
        
        return soup
    else:    
        return False

# %%
var_url = "https://en.wikipedia.org/wiki/Python"
var_flag_or_data = fun_hit_url(var_url)
if var_flag_or_data != False:
    print("Hit")

else:
    print("website is not hitted")
# Out:
# website is not hitted

# %%
print(var_flag_or_data.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Python - Wikipedia
#   </title>
#   <script>
# ...

# %%
def fun_print_pre(html_tags):

    print(html_tags.prettify())

# %%
print(var_flag_or_data.find('div').prettify())
# Out:
# <div class="vector-header-container">
#  <header class="vector-header mw-header">
#   <div class="vector-header-start">
#    <nav aria-label="Site" class="vector-main-menu-landmark">
#     <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
#      <input aria-haspopup="true" aria-label="Main menu" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
#      <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-main-menu-dropdown-checkbox" id="vector-main-menu-dropdown-label">
#       <span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu">
#       </span>
#       <span class="vector-dropdown-label-text">
#        Main menu
#       </span>
#      </label>
# ...

# %%
var_div = var_flag_or_data.find('div')
fun_print_pre(var_div)
# Out:
# <div class="vector-header-container">
#  <header class="vector-header mw-header">
#   <div class="vector-header-start">
#    <nav aria-label="Site" class="vector-main-menu-landmark">
#     <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
#      <input aria-haspopup="true" aria-label="Main menu" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
#      <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-main-menu-dropdown-checkbox" id="vector-main-menu-dropdown-label">
#       <span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu">
#       </span>
#       <span class="vector-dropdown-label-text">
#        Main menu
#       </span>
#      </label>
# ...

# %%
var_div = var_flag_or_data.find_all('div')
fun_print_pre(var_div)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 var_div = var_flag_or_data.find_all('div')
# ----> 2 fun_print_pre(var_div)
#
# Cell In[42], line 3, in fun_print_pre(html_tags)
#       1 def fun_print_pre(html_tags):
# ----> 3     print(html_tags.prettify())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\bs4\element.py:2433, in ResultSet.__getattr__(self, key)
#    2431 def __getattr__(self, key):
#    2432     """Raise a helpful exception to explain a common code fix."""
# -> 2433     raise AttributeError(
#    2434         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435     )
#
# ...

# %%
len(var_div)
# Out:
# 135

# %% [markdown]
# ### finding "Computing" in H2 tags from HTML tags

# %%
var_flag_or_data.find('h2')
# Out:
# <h2 class="vector-pinnable-header-label">Contents</h2>

# %%
var_flag_or_data.find('h2').text
# Out:
# 'Contents'

# %%
'''
if we use soup.find() it will give the first h2 tag.
below are the method to find the specific h2
'''
# Out:
# '\nif we use soup.find() it will give the first h2 tag.\nbelow are the method to find the specific h2\n'

# %% [markdown]
# #### Method 1 of finding the specific h2

# %%
var_flag_or_data.find_all('h2')
# Out:
# [<h2 class="vector-pinnable-header-label">Contents</h2>,
#  <h2 id="Snakes">Snakes</h2>,
#  <h2 id="Computing">Computing</h2>,
#  <h2 id="People">People</h2>,
#  <h2 id="Roller_coasters">Roller coasters</h2>,
#  <h2 id="Vehicles">Vehicles</h2>,
#  <h2 id="Weaponry">Weaponry</h2>,
#  <h2 id="Other_uses">Other uses</h2>,
#  <h2 id="See_also">See also</h2>]

# %%
for i in var_flag_or_data.find_all('h2'):
    if i.text == "Computing":
        print(i.text,"::::Found")
# Out:
# Computing ::::Found

# %% [markdown]
# #### Method 2: finding the specific h2

# %%
fun_print_pre(var_flag_or_data.find('div',class_="mw-heading mw-heading2"))
# Out:
# <div class="mw-heading mw-heading2">
#  <h2 id="Snakes">
#   Snakes
#  </h2>
#  <span class="mw-editsection">
#   <span class="mw-editsection-bracket">
#    [
#   </span>
#   <a href="/w/index.php?title=Python&amp;action=edit&amp;section=1" title="Edit section: Snakes">
#    <span>
#     edit
#    </span>
#   </a>
#   <span class="mw-editsection-bracket">
#    ]
#   </span>
#  </span>
# </div>

# %%
fun_print_pre(var_flag_or_data.find_all('div',class_="mw-heading mw-heading2")[1])
# .text
# Out:
# <div class="mw-heading mw-heading2">
#  <h2 id="Computing">
#   Computing
#  </h2>
#  <span class="mw-editsection">
#   <span class="mw-editsection-bracket">
#    [
#   </span>
#   <a href="/w/index.php?title=Python&amp;action=edit&amp;section=2" title="Edit section: Computing">
#    <span>
#     edit
#    </span>
#   </a>
#   <span class="mw-editsection-bracket">
#    ]
#   </span>
#  </span>
# </div>

# %%
var_flag_or_data.find_all('div',class_="mw-heading mw-heading2")[1].text
# Out:
# 'Computing[edit]'

# %%
var_flag_or_data.find_all('div',class_="mw-heading mw-heading2")[1].find('h2').text
# Out:
# 'Computing'

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><title>Example Domain</title><meta content="width=device-width, initial-scale=1" name="viewport"/><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.<p><a href="https://iana.org/domains/example">Learn more</a></p></p></div></body></head></html>

# %%
import requests
r = requests.get("https://en.wikipedia.org/wiki/Python")
r.status_code
# Out:
# 403

# %%
from bs4 import BeautifulSoup
# soup = BeautifulSoup(r.text,"html.parser")
# soup
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 from bs4 import BeautifulSoup
# ----> 2 soup = BeautifulSoup(r.text,"html.parser")
#       3 soup
#
# NameError: name 'r' is not defined

# %%
import requests
from bs4 import BeautifulSoup

url = "https://getlatka.com/companies/leadin.fr"

headers = {
    "User-Agent": "Googlebot"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

print(soup.title.text)
# Out:
# Just a moment...

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Python (programming language) - Wikipedia</title>
# ...

# %%
el = soup.select_one('body > div:nth-child(1) > p:nth-child(2)')
el.text
# Out:
# 'This domain is for use in documentation examples without needing permission. Avoid use in operations.Learn more'

# %%
# price = 
el2 = el.find_next('p')  # forward
el2.text
# Out:
# 'Learn more'

# %%
type(el)
# Out:
# bs4.element.Tag

# %%
type(soup.find(string='Learn more').parent
)# .get_attribute_list()
            #  exact text node
# Out:
# bs4.element.Tag

# %% [markdown]
# # class3
# ## Continue with bs4

# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get("https://www.crummy.com/software/BeautifulSoup/bs4/doc/")

# %%
r.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(r.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html data-content_root="./" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/><meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Beautiful Soup Documentation — Beautiful Soup 4.12.0 documentation</title>
# <link href="_static/pygments.css?v=fa44fd50" rel="stylesheet" type="text/css"/>
# <link href="_static/classic.css?v=514cf933" rel="stylesheet" type="text/css"/>
# <script src="_static/documentation_options.js?v=7155e95a"></script>
# <script src="_static/doctools.js?v=888ff710"></script>
# <script src="_static/sphinx_highlight.js?v=dc90522c"></script>
# <link href="genindex.html" rel="index" title="Index"/>
# <link href="search.html" rel="search" title="Search"/>
# </head><body>
# <div aria-label="related navigation" class="related" role="navigation">
# <h3>Navigation</h3>
# <ul>
# <li class="right" style="margin-right: 10px">
# ...

# %%
soup.title
# Out:
# <title>Beautiful Soup Documentation — Beautiful Soup 4.12.0 documentation</title>

# %%
soup.title.name
# Out:
# 'title'

# %% [markdown]
# # class 04

# %%
def fun_hit_url(url):
    r = requests.get(url)
    if r.status_code == 200:
        from bs4 import BeautifulSoup

        soup = BeautifulSoup(r.text, 'html.parser')
        
        return soup
    else:    
        return False

def fun_print_pre(html_tags):

    print(html_tags.prettify())

# %%
import requests

# %%
var_url = "https://en.wikipedia.org/wiki/Python"
soup_return = fun_hit_url(var_url)
if soup_return != False:
    print("Hit")
else:
    print("website is not hitted")
# Out:
# Hit

# %%
soup_return
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Python - Wikipedia</title>
# ...

# %% [markdown]
# ## class 04

# %%
var_first_H = soup_return.find(class_ = "mw-heading mw-heading2")
var_first_H
# Out:
# <div class="mw-heading mw-heading2"><h2 id="Snakes">Snakes</h2><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Python&amp;action=edit&amp;section=1" title="Edit section: Snakes"><span>edit</span></a><span class="mw-editsection-bracket">]</span></span></div>

# %%
var_first_H.find("h2").text
# Out:
# 'Snakes'

# %%
# Out:
# <span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Python&amp;action=edit&amp;section=1" title="Edit section: Snakes"><span>edit</span></a><span class="mw-editsection-bracket">]</span></span>

# %%
var_first_H.find_all("span")[1]
# Out:
# <span class="mw-editsection-bracket">[</span>

# %%
fun_print_pre(var_first_H.find("span", class_="mw-editsection-bracket"))
# Out:
# <span class="mw-editsection-bracket">
#  [
# </span>

# %%
fun_print_pre(var_first_H)
# Out:
# <div class="mw-heading mw-heading2">
#  <h2 id="Snakes">
#   Snakes
#  </h2>
#  <span class="mw-editsection">
#   <span class="mw-editsection-bracket">
#    [
#   </span>
#   <a href="/w/index.php?title=Python&amp;action=edit&amp;section=1" title="Edit section: Snakes">
#    <span>
#     edit
#    </span>
#   </a>
#   <span class="mw-editsection-bracket">
#    ]
#   </span>
#  </span>
# </div>

# %%
'''above code will extract only first h2, but I need to extract all h2 (sub heading) of python article'''

# %%
var_all_subheading = soup_return.find_all("div",class_ = "mw-heading mw-heading2")
len(var_all_subheading)
# Out:
# 8

# %%
fun_print_pre(var_all_subheading[0])
# Out:
# <div class="mw-heading mw-heading2">
#  <h2 id="Snakes">
#   Snakes
#  </h2>
#  <span class="mw-editsection">
#   <span class="mw-editsection-bracket">
#    [
#   </span>
#   <a href="/w/index.php?title=Python&amp;action=edit&amp;section=1" title="Edit section: Snakes">
#    <span>
#     edit
#    </span>
#   </a>
#   <span class="mw-editsection-bracket">
#    ]
#   </span>
#  </span>
# </div>

# %%
print(var_all_subheading[0].find("h2").text)
print(var_all_subheading[1].find("h2").text)
print(var_all_subheading[2].find("h2").text)
# Out:
# Snakes
# Computing
# People

# %%
var_all_subheading
# Out:
# [<div class="mw-heading mw-heading2"><h2 id="Snakes">Snakes</h2><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Python&amp;action=edit&amp;section=1" title="Edit section: Snakes"><span>edit</span></a><span class="mw-editsection-bracket">]</span></span></div>,
#  <div class="mw-heading mw-heading2"><h2 id="Computing">Computing</h2><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Python&amp;action=edit&amp;section=2" title="Edit section: Computing"><span>edit</span></a><span class="mw-editsection-bracket">]</span></span></div>,
#  <div class="mw-heading mw-heading2"><h2 id="People">People</h2><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Python&amp;action=edit&amp;section=3" title="Edit section: People"><span>edit</span></a><span class="mw-editsection-bracket">]</span></span></div>,
# ...

# %%
'''
w = overwrite a file
w+ = overwrite if file not exist create a file with same name
r = read a file
a = append a file
a+ = append if file not exist create a file with same name

'''

# %%
# for i in range(5000):
with open("text.txt","a+") as f:
    f.write("Hello, world! - 11\n")
    f.write("Hello, world! - 12\n")
    f.write("Hello, world! - 13\n")
f.close()

# %%
for h2 in var_all_subheading:
    with open("sub_heading.txt","a+") as f:
        f.write(h2.find("h2").text)
        f.write("\n")
        # print(h2.find("h2").text)
f.close()

# %% [markdown]
# ## class 05

# %%
var_parent_div = soup_return.find("div",class_="mw-content-ltr mw-parser-output")
var_parent_div
# Out:
# <div class="mw-content-ltr mw-parser-output" dir="ltr" lang="en"><style data-mw-deduplicate="TemplateStyles:r1235681985">.mw-parser-output .side-box{margin:4px 0;box-sizing:border-box;border:1px solid #aaa;font-size:88%;line-height:1.25em;background-color:var(--background-color-interactive-subtle,#f8f9fa);display:flow-root}.mw-parser-output .side-box-abovebelow,.mw-parser-output .side-box-text{padding:0.25em 0.9em}.mw-parser-output .side-box-image{padding:2px 0 2px 0.9em;text-align:center}.mw-parser-output .side-box-imageright{padding:2px 0.9em 2px 0;text-align:center}@media(min-width:500px){.mw-parser-output .side-box-flex{display:flex;align-items:center}.mw-parser-output .side-box-text{flex:1;min-width:0}}@media(min-width:720px){.mw-parser-output .side-box{width:238px}.mw-parser-output .side-box-right{clear:right;float:right;margin-left:1em}.mw-parser-output .side-box-left{margin-right:1em}}</style><style data-mw-deduplicate="TemplateStyles:r1237033735">@media print{body.ns-0 .mw-p
# ...

# %%
var_div_headings = var_parent_div.find_all("div",class_="mw-heading mw-heading2")

# %%
var_ul = var_parent_div.find_all("ul")
print(len(var_ul))
len(var_div_headings)
# Out:
# 10
# 8

# %%
for li in var_ul:
    print(li.text)
# Out:
# Pythonidae, a family of nonvenomous snakes found in Africa, Asia, and Australia
# Python (genus), a genus of Pythonidae found in Africa and Asia
# Python (mythology), a mythical serpent
# Python (programming language), a widely used high-level programming language
# Python, a native code compiler for CMU Common Lisp
# Python, the internal project name for the PERQ 3 computer workstation
# Python of Aenus (4th-century BCE), student of Plato
# Python (painter) (ca. 360–320 BCE), vase painter in Poseidonia
# Python of Byzantium (4th-century BCE), orator, diplomat of Philip II of Macedon
# Python of Catana, poet who accompanied Alexander the Great
# Python Anghelo (1954–2014), Romanian graphic artist
# Python (Efteling), a roller coaster in the Netherlands
# Python (Busch Gardens Tampa Bay), a defunct roller coaster
# Python (Coney Island, Cincinnati, Ohio), a steel roller coaster
# Python (automobile maker), an Australian car company
# ...

# %%
# unneeded uls of index = 1,8
print(var_ul)
# Out:
# [<ul><li><a href="/wiki/Pythonidae" title="Pythonidae">Pythonidae</a>, a family of nonvenomous snakes found in Africa, Asia, and Australia
# <ul><li><a href="/wiki/Python_(genus)" title="Python (genus)"><i>Python</i> (genus)</a>, a genus of Pythonidae found in Africa and Asia</li></ul></li>
# <li><a href="/wiki/Python_(mythology)" title="Python (mythology)">Python (mythology)</a>, a mythical serpent</li></ul>, <ul><li><a href="/wiki/Python_(programming_language)" title="Python (programming language)">Python (programming language)</a>, a widely used high-level programming language</li>
# <li>Python, a native code compiler for <a href="/wiki/CMU_Common_Lisp" title="CMU Common Lisp">CMU Common Lisp</a></li>
# <li>Python, the internal project name for the <a href="/wiki/PERQ#PERQ_3" title="PERQ">PERQ 3</a> computer workstation</li></ul>, <ul><li><a href="/wiki/Python_of_Aenus" title="Python of Aenus">Python of Aenus</a> (4th-century BCE), student of Plato</li>
# ...

# %%
len(var_ul)
# Out:
# 8

# %%
var_ul.pop(1)
# remove()
# Out:
# <ul><li><a href="/wiki/Python_(genus)" title="Python (genus)"><i>Python</i> (genus)</a>, a genus of Pythonidae found in Africa and Asia</li></ul>

# %%
for ul in var_ul:
    print(var_ul.index(ul)+1,end=" ")
    print(len(ul.find_all("li")))
# Out:
# 1 3
# 2 1
# 3 3
# 4 5
# 5 3
# 6 2
# 7 3
# 8 5
# 9 1
# 10 2

# %%
head = 8
ul = 8

# %%
# Out:
# 'Snakes'

# %%
{
    "snakes" : [point1,point2,point3],
    "computing" : [point1,point2]
}

# %%
with open("extracted_data.txt","a+") as f:
    for i in range(8):

        var_header = var_div_headings[i].find('h2').text
        # print(var_header)
        f.write(var_header)
        
        
        list_li = []
        for li in var_ul[i]:
            print("\t",li.text)
            list_li.append(li.text)
        
        
        f.write(str(list_li)+"\n")

        
        # data[var_header] = list_li
        # var_div_headings[i].text
# Out:
# 	 Pythonidae, a family of nonvenomous snakes found in Africa, Asia, and Australia
# Python (genus), a genus of Pythonidae found in Africa and Asia
#
#
# 	 Python (mythology), a mythical serpent
# 	 Python (programming language), a widely used high-level programming language
#
#
# 	 Python, a native code compiler for CMU Common Lisp
#
#
# 	 Python, the internal project name for the PERQ 3 computer workstation
# 	 Python of Aenus (4th-century BCE), student of Plato
#
#
# 	 Python (painter) (ca. 360–320 BCE), vase painter in Poseidonia
#
#
# 	 Python of Byzantium (4th-century BCE), orator, diplomat of Philip II of Macedon
#
#
# 	 Python of Catana, poet who accompanied Alexander the Great
#
#
# 	 Python Anghelo (1954–2014), Romanian graphic artist
# 	 Python (Efteling), a roller coaster in the Netherlands
#
#
# 	 Python (Busch Gardens Tampa Bay), a defunct roller coaster
#
#
# 	 Python (Coney Island, Cincinnati, Ohio), a steel roller coaster
# ...

# %%
data = {}

for i in range(8):
    var_header = var_div_headings[i].find('h2').text
    print(var_header)

    list_li = []
    for li in var_ul[i]:
        print("\t",li.text)
        list_li.append(li.text)
    
    data[var_header] = list_li
    # var_div_headings[i].text
# Out:
# Snakes
# 	 Pythonidae, a family of nonvenomous snakes found in Africa, Asia, and Australia
# Python (genus), a genus of Pythonidae found in Africa and Asia
#
#
# 	 Python (mythology), a mythical serpent
# Computing
# 	 Python (programming language), a widely used high-level programming language
#
#
# 	 Python, a native code compiler for CMU Common Lisp
#
#
# 	 Python, the internal project name for the PERQ 3 computer workstation
# People
# 	 Python of Aenus (4th-century BCE), student of Plato
#
#
# 	 Python (painter) (ca. 360–320 BCE), vase painter in Poseidonia
#
#
# 	 Python of Byzantium (4th-century BCE), orator, diplomat of Philip II of Macedon
#
#
# 	 Python of Catana, poet who accompanied Alexander the Great
#
#
# 	 Python Anghelo (1954–2014), Romanian graphic artist
# Roller coasters
# 	 Python (Efteling), a roller coaster in the Netherlands
#
#
# 	 Python (Busch Gardens Tampa Bay), a defunct roller coaster
#
#
# ...

# %%
data
# Out:
# {'Snakes': ['Pythonidae, a family of nonvenomous snakes found in Africa, Asia, and Australia\nPython (genus), a genus of Pythonidae found in Africa and Asia',
#   'Python (mythology), a mythical serpent'],
#  'Computing': ['Python (programming language), a widely used high-level programming language',
#   'Python, a native code compiler for CMU Common Lisp',
#   '\n',
#   'Python, the internal project name for the PERQ 3 computer workstation'],
#  'People': ['Python of Aenus (4th-century BCE), student of Plato',
#   'Python (painter) (ca. 360–320 BCE), vase painter in Poseidonia',
#   '\n',
#   'Python of Byzantium (4th-century BCE), orator, diplomat of Philip II of Macedon',
#   '\n',
#   'Python of Catana, poet who accompanied Alexander the Great',
#   '\n',
#   'Python Anghelo (1954–2014), Romanian graphic artist'],
#  'Roller coasters': ['Python (Efteling), a roller coaster in the Netherlands',
#   'Python (Busch Gardens Tampa Bay), a defunct roller coaster',
#   '\n',
# ...

# %%
# Assignment

1. extract all links of "https://en.wikipedia.org/wiki/Python" relavent to topic. and save into text file
2. repeat Q1 and save data into CSV.
3. extract the value as well with respectivily URLs. save into text file.

# %%
## class 06

# %%
a = []
b = [0,0,0]

# %%
a,b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a,b
#
# NameError: name 'a' is not defined

# %%
a = a+b
a

# %%
list_of_a = []
for ul in var_ul:
    # print (ul.find_all('a'))
    b = ul.find_all('a')
    list_of_a = list_of_a + b #merging list_of_a into b, that will store all 'a' tag in a single list

# %%
list_of_a

# %%
first_a_tag = list_of_a[0]
first_a_tag
 # we extract the tag of a, but still we want given link on a page.

# %%
first_a_tag.text

# %%
# as we see in above tag, link is given as attr value, and we can access the value of any attr by below code

first_a_tag["href"]

# %%
third_a_tag = list_of_a [3]
third_a_tag.text

# %%
# if we want to get all links of tag 'a'

for a in list_of_a:
    print("https://en.wikipedia.org"+a["href"])

# %%
#method1

for a in list_of_a:
    with open ("text_url.txt" , "a+")as f:
        # f.write(str(print("https://en.wikipedia.org"+a["href"])))
        f.write("https://en.wikipedia.org"+a["href"])

        f.write("\n")
f.close()

# %%
#method2

for a in list_of_a:
    with open ("text_url.txt" , "a+")as f:
        # f.write(str(print("https://en.wikipedia.org"+a["href"])))
        f.write(a.text + "\n")
        extracted_link  = "https://en.wikipedia.org"+a["href"]
        f.write(extracted_link)

        f.write("\n")
f.close()

# %%
#method2

for a in list_of_a:
    with open ("csv_url.csv" , "a+")as f:
        # f.write(str(print("https://en.wikipedia.org"+a["href"])))
        f.write(a.text + "\n")
        extracted_link  = "https://en.wikipedia.org"+a["href"]
        f.write(extracted_link,)

        f.write("\n")
f.close()

# %%
# Assuming list_of_a contains elements with 'text' and 'href' attributes (from BeautifulSoup)
for a in list_of_a:
    # Open the CSV file in append mode ('a+')
    with open("url.csv", "a+") as f:
        # Extract the text and link
        extracted_text = a.text
        extracted_link = "https://en.wikipedia.org" + a["href"]
        
        # Write the extracted text and link, separated by a comma (for CSV format)
        f.write(f"{extracted_text}, {extracted_link}\n")

f.close()

# %%
for a in list_of_a:
    extracted_text = a.text
    extracted_link = "https://en.wikipedia.org" + a["href"]
    print(extracted_text,extracted_link)

# %%
# if I want to save data into CSV/XLSX (excel), we will use pandas library

# %%
val_list = []
link_list = []

for link in a_tags:
    extracted_link = "https://en.wikipedia.org"+link["href"]
    link_list.append(extracted_link)
    extracted_val= link.text
    val_list.append(extracted_val)

    print(extracted_val,extracted_link)

# %%
link_list

# %%
pip install pandas

# %%
import pandas as pd

# %%
sheet_data = pd.DataFrame()
sheet_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
sheet_data["value"] = val_list
sheet_data["link"] = link_list
sheet_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sheet_data["value"] = val_list
#       2 sheet_data["link"] = link_list
#       3 sheet_data
#
# NameError: name 'val_list' is not defined

# %%
sheet_data.to_csv("data.csv")
sheet_data.to_csv("data.xlsx",index=False)

# %%
# 1. difference b/w csv and xlsx
# 2. why we use csv files rather than excel

# %%
'''3
1. read the links from CSV (same file your save previously) via Pandas.
2. hit each link via Request and print status.
3. save status respectivily next to link into csv.
'''

# %% [markdown]
# ## class 06

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["link"] #all values of columns shown with index values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'link'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
type(df["link"])
# Out:
# pandas.core.series.Series

# %%
df[["link","value"]]
# Out:
#                                                  link  \
# 0            https://en.wikipedia.org/wiki/Pythonidae
# 1        https://en.wikipedia.org/wiki/Python_(genus)
# 2    https://en.wikipedia.org/wiki/Python_(mythology)
# 3   https://en.wikipedia.org/wiki/Python_(programm...
# 4       https://en.wikipedia.org/wiki/CMU_Common_Lisp
# 5           https://en.wikipedia.org/wiki/PERQ#PERQ_3
# 6       https://en.wikipedia.org/wiki/Python_of_Aenus
# 7      https://en.wikipedia.org/wiki/Python_(painter)
# 8   https://en.wikipedia.org/wiki/Python_of_Byzantium
# 9      https://en.wikipedia.org/wiki/Python_of_Catana
# 10       https://en.wikipedia.org/wiki/Python_Anghelo
# 11    https://en.wikipedia.org/wiki/Python_(Efteling)
# 12  https://en.wikipedia.org/wiki/Python_(Busch_Ga...
# 13  https://en.wikipedia.org/wiki/Python_(Coney_Is...
# 14  https://en.wikipedia.org/wiki/Python_(automobi...
# 15  https://en.wikipedia.org/wiki/Python_(Ford_pro...
# ...

# %%
link_status = []

for all_links in df["link"]:
    var = requests.get(all_links)
    if var.status_code == 200:
        link_status.append("link is hitted")
        
        
    else:
        link_status.append("link is not hitted")

# %%
link_status
# Out:
# ['link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is hitted',
#  'link is not hitted']

# %%
# note: length of a list which is adding to DF must be equal to length of DF.

# %%
len(link_status)
# Out:
# 27

# %%
df["status"]= link_status
df
# Out:
#                                       value  \
# 0                                Pythonidae
# 1                            Python (genus)
# 2                        Python (mythology)
# 3             Python (programming language)
# 4                           CMU Common Lisp
# 5                                    PERQ 3
# 6                           Python of Aenus
# 7                          Python (painter)
# 8                       Python of Byzantium
# 9                          Python of Catana
# 10                           Python Anghelo
# 11                        Python (Efteling)
# 12         Python (Busch Gardens Tampa Bay)
# 13  Python (Coney Island, Cincinnati, Ohio)
# 14                Python (automobile maker)
# 15                  Python (Ford prototype)
# 16                         Python (missile)
# 17                 Python (nuclear primary)
# 18                              Colt Python
# 19                        Python (codename)
# ...

# %%
len(df)
# Out:
# 27

# %%
df.shape # 27 rows and 3 columns
# Out:
# (27, 3)

# %%
link_status.append("i")

# %%
len(link_status)
# Out:
# 28

# %%
df["status2"] = link_status
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df["status2"] = link_status
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# ...

# %%
df
# Out:
#                                       value  \
# 0                                Pythonidae
# 1                            Python (genus)
# 2                        Python (mythology)
# 3             Python (programming language)
# 4                           CMU Common Lisp
# 5                                    PERQ 3
# 6                           Python of Aenus
# 7                          Python (painter)
# 8                       Python of Byzantium
# 9                          Python of Catana
# 10                           Python Anghelo
# 11                        Python (Efteling)
# 12         Python (Busch Gardens Tampa Bay)
# 13  Python (Coney Island, Cincinnati, Ohio)
# 14                Python (automobile maker)
# 15                  Python (Ford prototype)
# 16                         Python (missile)
# 17                 Python (nuclear primary)
# 18                              Colt Python
# 19                        Python (codename)
# ...

# %%
df.to_csv("status.csv",index=False)

# %%
type(df[["link","value"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df["link"].to_clipboard()
# [-1]

# %%
df["link"].to_dict()
# to_clipboard()
# [-1]
# Out:
# {0: 'https://en.wikipedia.org/wiki/Pythonidae',
#  1: 'https://en.wikipedia.org/wiki/Python_(genus)',
#  2: 'https://en.wikipedia.org/wiki/Python_(mythology)',
#  3: 'https://en.wikipedia.org/wiki/Python_(programming_language)',
#  4: 'https://en.wikipedia.org/wiki/CMU_Common_Lisp',
#  5: 'https://en.wikipedia.org/wiki/PERQ#PERQ_3',
#  6: 'https://en.wikipedia.org/wiki/Python_of_Aenus',
#  7: 'https://en.wikipedia.org/wiki/Python_(painter)',
#  8: 'https://en.wikipedia.org/wiki/Python_of_Byzantium',
#  9: 'https://en.wikipedia.org/wiki/Python_of_Catana',
#  10: 'https://en.wikipedia.org/wiki/Python_Anghelo',
#  11: 'https://en.wikipedia.org/wiki/Python_(Efteling)',
#  12: 'https://en.wikipedia.org/wiki/Python_(Busch_Gardens_Tampa_Bay)',
#  13: 'https://en.wikipedia.org/wiki/Python_(Coney_Island,_Cincinnati,_Ohio)',
#  14: 'https://en.wikipedia.org/wiki/Python_(automobile_maker)',
#  15: 'https://en.wikipedia.org/wiki/Python_(Ford_prototype)',
# ...

# %%
df["link"].to_frame()
# .to_dict()
# to_clipboard()
# [-1]
# Out:
#                                                  link
# 0            https://en.wikipedia.org/wiki/Pythonidae
# 1        https://en.wikipedia.org/wiki/Python_(genus)
# 2    https://en.wikipedia.org/wiki/Python_(mythology)
# 3   https://en.wikipedia.org/wiki/Python_(programm...
# 4       https://en.wikipedia.org/wiki/CMU_Common_Lisp
# 5           https://en.wikipedia.org/wiki/PERQ#PERQ_3
# 6       https://en.wikipedia.org/wiki/Python_of_Aenus
# 7      https://en.wikipedia.org/wiki/Python_(painter)
# 8   https://en.wikipedia.org/wiki/Python_of_Byzantium
# 9      https://en.wikipedia.org/wiki/Python_of_Catana
# 10       https://en.wikipedia.org/wiki/Python_Anghelo
# 11    https://en.wikipedia.org/wiki/Python_(Efteling)
# 12  https://en.wikipedia.org/wiki/Python_(Busch_Ga...
# 13  https://en.wikipedia.org/wiki/Python_(Coney_Is...
# 14  https://en.wikipedia.org/wiki/Python_(automobi...
# 15  https://en.wikipedia.org/wiki/Python_(Ford_pro...
# ...

# %%
df["link"].to_list()
# .to_frame()
# .to_dict()
# to_clipboard()
# [-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df["link"].to_list()
#       2 # .to_frame()
#       3 # .to_dict()
#       4 # to_clipboard()
#       5 # [-1]
#
# NameError: name 'df' is not defined

# %%
import requests

# %%
## try and exception

# %%
url = df["link"].to_list()[-1]

response = requests.get(url)
response

print("hello world")
# Out:
# ---------------------------------------------------------------------------
#
# gaierror                                  Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#
#     197 try:
#
# --> 198     sock = connection.create_connection(
#
#     199         (self._dns_host, self.port),
#
#     200         self.timeout,
#
#     201         source_address=self.source_address,
#
#     202         socket_options=self.socket_options,
#
#     203     )
#
#     204 except socket.gaierror as e:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#
# ...

# %%
url = df["link"].to_list()[-1]

try:
    response = requests.get(url)
    response
    
except:
    
    print("something went wrong")


print("hello world")
# Out:
# something error
# hello world

# %%
## Assignment

# %%
'''
1. what is pagination in webscraping?
2. what is example via BS4?
3. how to extract data from a website(https://www.yello.ae/category/computer-services) till page 5 via bs4.
'''

# %%
## Assignment 21-oct-24


# 1. extract name,address and profile link of each company from https://www.yello.ae/category/computer-services and save into csv
'''
2. 
Repeat Q1 for 
https://www.yello.ae/category/computer-services/1
https://www.yello.ae/category/computer-services/2
https://www.yello.ae/category/computer-services/3
https://www.yello.ae/category/computer-services/4
https://www.yello.ae/category/computer-services/5

and save the data into CSV with attributes/columns (name,address,profile link and extracted from)
'''
'''
name | profile link | address | extracted from
xyz  | www.xyz.com  | kaachi  | https://www.yello.ae/category/computer-services/1
.
.
.

xyz31  | www.xyz31.com  | kaachi  | https://www.yello.ae/category/computer-services/2
'''

# %% [markdown]
# # last
